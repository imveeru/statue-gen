# %%
import random
import os
import sys

# %%
from CGen import *
from EA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=10,10,20
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome_edge(L,B,H)
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# (R,G,B,A) = (93,112,210,124)
# Roughness Factor = 4
# Number of vertices = 6
# Number of faces = 7
# New Bounding Box - (L,B,H) = (2.818192,9.829178,3.837962)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (170,16,212,148)
# Roughness Factor = 5
# Number of vertices = 12
# Number of faces = 41
# New Bounding Box - (L,B,H) = (7.318474,4.010936,12.56685)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (168,79,183,120)
# Roughness Factor = 1
# Number of vertices = 11
# Number of faces = 38
# New Bounding Box - (L,B,H) = (6.148981,8.699315,3.245113)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (40,43,147,121)
# Roughness Factor = 1
# Number of vertices = 7
# Number of faces = 9
# New Bounding Box - (L,B,H) = (3.552577,7.91906,19.880334)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (29,128,173,139)
# Roughness Factor = 5
# Number of vertices = 16
# Number of faces = 78
# New Bounding Box - (L,B,H) = (7.957747,8.726657,11.383257)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (57,87,114,113)
# Roughness Factor = 0
# Number of vertices = 5
# Number of faces = 3
# New Bounding Box - (L,B,H) = (2.10902,3.457813,19.518052)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (173,67,136,212)
# Roughness Factor = 0
# Number of vertices = 11
# Number of faces = 34
# New Bounding Box - (L,B,H) = (9.788118,4.346134,6.706888)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (127,171,53,204)
# Roughness Factor = 3
# Number of vertices = 4
# Number of faces = 3
# New Bounding Box - (L,B,H) = (9.345819,3.108997,3.509116)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (179,152,25,142)
# Roughness Factor = 4
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (4.613839,5.436093,1.917645)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (93,243,60,140)
# Roughness Factor = 4
# Number of vertices = 4
# Number of faces = 2
# New Bounding Box - (L,B,H) = (3.282809,9.30869,8.956647)
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 9.82 ms

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    NEW_SHAPE=C[6]
    FILE_NUM=str(i)
    fitness_0.append(new_fitness(FACES,RO,VERTS,NEW_SHAPE))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[1914.142685854693,
#   42368.89738167189,
#   345.2866485800679,
#   610.2138963478051,
#   80687.23157286258,
#   153.79509603552088,
#   334.6603180940783,
#   301.0703039367975,
#   312.5330417884385,
#   799.0117425816384]]

# %%
BEST_FITNESS
# Out:
# [80687.23157286258]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[new_fitness(model[5][1],model[4],model[5][0],model[6]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate_edge(c1,L,B,H)
        m2=mutate_edge(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [1914.142685854693, 42368.89738167189, 345.2866485800679, 610.2138963478051, 80687.23157286258, 153.79509603552088, 334.6603180940783, 301.0703039367975, 312.5330417884385, 799.0117425816384]
#
# Statue-4 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4034.8973816718967, 72.53304178843847, 2974.286648580068, 583.2138963478051, 42368.89738167189, 610.2138963478051, 486.6603180940783, 1040.8973816718967, 573.8973816718967, 2208.231572862571]
#
# Statue-4 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2854.8973816718967, 10880.897381671897, 5365.2138963478055, 2974.286648580068, 42563.21389634781, 1043.8973816718967, 2688.8973816718967, 42368.89738167189, 14978.897381671897, 913.2866485800679]
#
# Statue-4 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <listcomp>(.0)
#
# E:\Research\Statue Generator\EA_MC.py in new_fitness(FACES, RO, VERTICES, SHAPE)
#     103
#     104 def new_fitness(FACES,RO,VERTICES,SHAPE):
# --> 105     return len(FACES)*(4**RO)+len(VERTICES)+SHAPE[1]+(SHAPE[0]*SHAPE[1]*SHAPE[2])
#     106
#     107 def fractal_dimension(FACES):
#
# TypeError: object of type 'NoneType' has no len()

# %%
print(len(ALL_FITNESS))
# Out:
# 24

# %%
len(PARAMS)
# Out:
# 5001

# %%
C=PARAMS[5000][1]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.3607843137254902, 0.3843137254901961, 0.5764705882352941, 44)'

# %%
print(FACES)
# Out:
# [(15, 0, 2, 6, 10, 11, 12, 14, 17, 19, 20, 22, 23, 24, 26, 27, 32, 35, 37, 39, 40, 41, 42, 43), (28, 2, 3, 6, 8, 9, 10, 11, 14, 15, 18, 20, 21, 22, 23, 26, 27, 32, 34, 35, 36, 38, 39, 40, 41, 42), (20, 1, 3, 5, 6, 8, 9, 10, 11, 13, 14, 18, 21, 22, 23, 24
 9, 10, 11, 12, 13, 14, 15, 16, 18, 19, 20, 22, 23, 26, 27, 28, 31, 32, 33, 36, 37, 41, 42), (17, 2, 4, 5, 6, 7, 8, 11, 12, 13, 18, 19, 20, 21, 22, 26, 28, 29, 31, 32, 33, 35, 36, 37, 39, 41), (18, 2, 3, 4, 9, 10, 12, 14, 16, 17, 24, 26, 27, 28, 31, 32, 34, 35, 38, 40), (37, 3, 5, 8, 9, 13, 14, 20, 23, 25, 26, 27, 28, 30, 31, 33, 35, 41, 42), (18, 6, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 19, 20, 22, 24, 25, 26, 27, 30, 33, 35, 39), (33, 2, 8, 9, 12, 13, 14, 15, 18, 19, 20, 21, 25, 26, 27, 28, 30, 32, 34, 35, 37, 40), (17, 0, 1, 7, 8, 9, 10, 12, 13, 16, 19, 21, 23, 27, 28, 29, 32, 33, 35, 36, 38, 40, 43), (25, 1, 2, 4, 9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 21, 22, 26, 27, 28, 30, 33, 36, 40, 41, 42), (24, 1, 2, 3, 5, 12, 13, 14, 15, 16, 18, 19, 20, 23, 25, 27, 28, 30, 31, 35, 37, 40, 41, 42), (2, 8, 9, 10, 14, 19, 20, 23, 24, 26, 32, 35, 36, 37, 38, 42, 43), (20, 0, 1, 2, 3, 4, 7, 9, 10, 14, 17, 18, 21, 28, 29, 30, 31, 33, 34, 35, 37, 38, 39, 40, 41, 42, 43), (3, 0, 1, 2, 4, 5, 10, 12, 13, 14, 18, 22, 25, 29, 33, 35, 38, 39, 40, 42), (37, 0, 1, 5, 10, 11, 14, 16, 17, 18, 19, 20, 21, 23, 26, 27, 28, 29, 31, 35, 36, 39, 40, 41, 42, 43), (10, 4, 5, 6, 11, 12, 13, 15, 16, 19, 20, 23, 26, 27, 28, 29, 30, 33, 34, 37, 39, 43), (22, 0, 1, 2, 4, 6, 8, 9, 11, 12, 14, 15, 18, 19, 21, 24, 25, 27, 28, 29, 34, 35, 36, 37, 41, 42), (2, 3, 5, 6, 9, 15, 16, 21, 22, 24, 26, 29, 30, 32, 33, 35, 37, 38, 39, 41, 42, 43), (7, 1, 2, 3, 4, 6, 10, 11, 12, 13, 19, 20, 22, 24, 28, 29, 30, 31, 33, 35, 39, 40, 41, 42, 43), (29, 0, 1, 3, 7, 8, 11, 12, 14, 16, 18, 19, 20,  ...

# %%
get_stats(C)
# Out:
# (R,G,B,A) = (118,235,49,47)
# Roughness Factor = 5
# Number of vertices = 9
# Number of faces = 22
# New Bounding Box - (L,B,H) = (2.963628,4.176417,17.093498)

# %%
print(VERTS)
# Out:
# [[1.031523472143756, 16.167210212890442, 3.3570046480258946], [0.48940563305866835, 8.065852128427467, 3.1953882973085097], [2.2238480933002864, 15.132833465979997, 3.5223095433309823], [1.1689540488963606, 1.3078304866087953, 0.622713446305037], [1.6306702823398032, 5.3828712693408765, 1.2892775578435371], [2.5365329365479266, 0.07088511180646002, 1.520836770496152], [1.588278336508309, 16.700088382087777, 2.863290301790338], [1.5280808997922204, 12.845216328410634, 0.4207651816151519], [1.4868116880460691, 11.956267489039844, 2.9031258461493983]]

# %%
RO
# Out:
# 4

# %%
with open(f'E:\Research\Statue gen output\\OUTPUT_12_VARY_LBH_onlyin_MUTATION.txt', 'w') as f:
        f.writelines(str(PARAMS))
