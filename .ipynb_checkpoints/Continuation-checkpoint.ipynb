# %%
import random
import os
import sys
import time
import numpy as np
import math

# %%
from ConvexCGen import *
from ConvexEA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %%
def shannon_entropy(file_path):
    with open(file_path, "rb") as f:
        bytes = f.read()
    prob = [float(bytes.count(b)) / len(bytes) for b in set(bytes)]
    entropy = -sum([p * math.log(p) / math.log(2.0) for p in prob])
    return round(entropy,6)

# %%
def gen_blender(ARR,GEN_NUM):
    
    os.mkdir(OUTPUT_PATH+"\\GEN_"+str(GEN_NUM))
    
    for i,C in enumerate(ARR):

        RO=C[0]
        VERTS=C[1][0]
        FACES=C[1][1]
        MATERIALS=C[1][2]
        FILE_NUM=str(i)
        
        with open(f'{OUTPUT_PATH}\\GEN_{GEN_NUM}\\VERTS_G{GEN_NUM}_S{i}.txt', 'w') as f:
            f.writelines(str(VERTS))
        
        with open(f'{OUTPUT_PATH}\\GEN_{GEN_NUM}\\FACES_G{GEN_NUM}_S{i}.txt', 'w') as f:
            f.writelines(str(FACES))
            
        with open(f'{OUTPUT_PATH}\\GEN_{GEN_NUM}\\MATERIALS_G{GEN_NUM}_S{i}.txt', 'w') as f:
            f.writelines(str(MATERIALS))

        subprocess.run(["blender", "--background", "--python","convexGeneratePopulation.py",FILE_NUM,f'VERTS_G{GEN_NUM}_S{i}.txt',f'FACES_G{GEN_NUM}_S{i}.txt',f'MATERIALS_G{GEN_NUM}_S{i}.txt',str(RO),str(OUTPUT_PATH+"\\GEN_"+str(GEN_NUM))],capture_output=True,shell=True)
        #time.sleep(60)
        
        #print(f'Statue {i} Saved!')

# %%
L,B,H=10,10,20
POPULATION_SIZE=10

# %%
with open("E:\Research\Statue gen output\CONVEX_HULL_Entropy_100Gen.txt", 'r') as f:
    PARAMS = f.readlines()

# %%
from ast import literal_eval

# %%
PARAMS=literal_eval(PARAMS[0])

# %%
len(PARAMS)
# Out:
# 101

# %%
# %%time

ALL_FITNESS=[]
BEST_FITNESS=[]
GEN_NUM=len(PARAMS)
GENERATIONS=len(PARAMS)

for _ in range(GENERATIONS,1001):
    
    PATH_FOR_PREV_GEN=OUTPUT_PATH+"\\GEN_"+str(GEN_NUM-1)
    FITNESS=[]
    
    for i in range(POPULATION_SIZE):
        VERTS=PARAMS[GEN_NUM-1][i][1][0]
        FACES=PARAMS[GEN_NUM-1][i][1][1]
        
        gr=golden_ratio(np.array(VERTS),np.array(FACES))
        gr=gr/100
        
        entropy=shannon_entropy(PATH_FOR_PREV_GEN+f"\\STATUE_{i}.blend")
        entropy=entropy/8
        
        fitness=gr+(1/entropy)
        FITNESS.append(round(fitness,6))
    
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'Statue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    #generate blender file
    gen_blender(MODELS,GEN_NUM)
    
    print(f"Generation {GEN_NUM} generated successfully!")
    print("-"*120)
    
    GEN_NUM+=1
# Out:
# Statue-8 has the best fitness value in 100 generation.
# Generation 101 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 101 generation.
# Generation 102 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 102 generation.
# Generation 103 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 103 generation.
# Generation 104 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 104 generation.
# Generation 105 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 105 generation.
# Generation 106 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 106 generation.
# Generation 107 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 107 generation.
# Generation 108 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 108 generation.
# Generation 109 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 109 generation.
# Generation 110 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 110 generation.
# Generation 111 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 111 generation.
# Generation 112 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 112 generation.
# Generation 113 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 113 generation.
# Generation 114 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 114 generation.
# Generation 115 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 115 generation.
# Generation 116 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 116 generation.
# Generation 117 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 117 generation.
# Generation 118 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 118 generation.
# Generation 119 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 119 generation.
# Generation 120 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 120 generation.
# Generation 121 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 121 generation.
# Generation 122 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 122 generation.
# Generation 123 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 123 generation.
# Generation 124 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 124 generation.
# Generation 125 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 125 generation.
# Generation 126 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 126 generation.
# Generation 127 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 127 generation.
# Generation 128 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 128 generation.
# Generation 129 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 129 generation.
# Generation 130 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 130 generation.
# Generation 131 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 131 generation.
# Generation 132 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 132 generation.
# Generation 133 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 133 generation.
# Generation 134 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 134 generation.
# Generation 135 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 135 generation.
# Generation 136 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 136 generation.
# Generation 137 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 137 generation.
# Generation 138 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 138 generation.
# Generation 139 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 139 generation.
# Generation 140 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 140 generation.
# Generation 141 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 141 generation.
# Generation 142 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 142 generation.
# Generation 143 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 143 generation.
# Generation 144 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 144 generation.
# Generation 145 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 145 generation.
# Generation 146 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 146 generation.
# Generation 147 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 147 generation.
# Generation 148 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 148 generation.
# Generation 149 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 149 generation.
# Generation 150 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 150 generation.
# Generation 151 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 151 generation.
# Generation 152 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 152 generation.
# Generation 153 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 153 generation.
# Generation 154 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 154 generation.
# Generation 155 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 155 generation.
# Generation 156 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 156 generation.
# Generation 157 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 157 generation.
# Generation 158 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 158 generation.
# Generation 159 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 159 generation.
# Generation 160 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 160 generation.
# Generation 161 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 161 generation.
# Generation 162 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 162 generation.
# Generation 163 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 163 generation.
# Generation 164 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 164 generation.
# Generation 165 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 165 generation.
# Generation 166 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 166 generation.
# Generation 167 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 167 generation.
# Generation 168 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 168 generation.
# Generation 169 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 169 generation.
# Generation 170 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 170 generation.
# Generation 171 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 171 generation.
# Generation 172 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 172 generation.
# Generation 173 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 173 generation.
# Generation 174 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 174 generation.
# Generation 175 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 175 generation.
# Generation 176 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 176 generation.
# Generation 177 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 177 generation.
# Generation 178 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 178 generation.
# Generation 179 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 179 generation.
# Generation 180 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 180 generation.
# Generation 181 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 181 generation.
# Generation 182 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 182 generation.
# Generation 183 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 183 generation.
# Generation 184 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 184 generation.
# Generation 185 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 185 generation.
# Generation 186 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 186 generation.
# Generation 187 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 187 generation.
# Generation 188 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 188 generation.
# Generation 189 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 189 generation.
# Generation 190 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 190 generation.
# Generation 191 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 191 generation.
# Generation 192 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 192 generation.
# Generation 193 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 193 generation.
# Generation 194 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 194 generation.
# Generation 195 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 195 generation.
# Generation 196 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 196 generation.
# Generation 197 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 197 generation.
# Generation 198 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 198 generation.
# Generation 199 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 199 generation.
# Generation 200 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 200 generation.
# Generation 201 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 201 generation.
# Generation 202 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 202 generation.
# Generation 203 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 203 generation.
# Generation 204 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 204 generation.
# Generation 205 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 205 generation.
# Generation 206 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 206 generation.
# Generation 207 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 207 generation.
# Generation 208 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 208 generation.
# Generation 209 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 209 generation.
# Generation 210 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 210 generation.
# Generation 211 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 211 generation.
# Generation 212 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 212 generation.
# Generation 213 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 213 generation.
# Generation 214 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 214 generation.
# Generation 215 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 215 generation.
# Generation 216 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 216 generation.
# Generation 217 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 217 generation.
# Generation 218 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 218 generation.
# Generation 219 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 219 generation.
# Generation 220 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 220 generation.
# Generation 221 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 221 generation.
# Generation 222 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 222 generation.
# Generation 223 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 223 generation.
# Generation 224 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 224 generation.
# Generation 225 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 225 generation.
# Generation 226 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 226 generation.
# Generation 227 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 227 generation.
# Generation 228 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 228 generation.
# Generation 229 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 229 generation.
# Generation 230 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 230 generation.
# Generation 231 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 231 generation.
# Generation 232 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 232 generation.
# Generation 233 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 233 generation.
# Generation 234 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 234 generation.
# Generation 235 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 235 generation.
# Generation 236 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 236 generation.
# Generation 237 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 237 generation.
# Generation 238 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 238 generation.
# Generation 239 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 239 generation.
# Generation 240 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 240 generation.
# Generation 241 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 241 generation.
# Generation 242 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 242 generation.
# Generation 243 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 243 generation.
# Generation 244 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 244 generation.
# Generation 245 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 245 generation.
# Generation 246 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 246 generation.
# Generation 247 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 247 generation.
# Generation 248 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 248 generation.
# Generation 249 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 249 generation.
# Generation 250 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 250 generation.
# Generation 251 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 251 generation.
# Generation 252 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 252 generation.
# Generation 253 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 253 generation.
# Generation 254 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 254 generation.
# Generation 255 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 255 generation.
# Generation 256 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 256 generation.
# Generation 257 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 257 generation.
# Generation 258 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 258 generation.
# Generation 259 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 259 generation.
# Generation 260 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 260 generation.
# Generation 261 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 261 generation.
# Generation 262 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 262 generation.
# Generation 263 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 263 generation.
# Generation 264 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 264 generation.
# Generation 265 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 265 generation.
# Generation 266 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 266 generation.
# Generation 267 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 267 generation.
# Generation 268 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 268 generation.
# Generation 269 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 269 generation.
# Generation 270 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 270 generation.
# Generation 271 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 271 generation.
# Generation 272 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 272 generation.
# Generation 273 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 273 generation.
# Generation 274 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 274 generation.
# Generation 275 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 275 generation.
# Generation 276 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 276 generation.
# Generation 277 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 277 generation.
# Generation 278 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 278 generation.
# Generation 279 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 279 generation.
# Generation 280 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 280 generation.
# Generation 281 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 281 generation.
# Generation 282 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 282 generation.
# Generation 283 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 283 generation.
# Generation 284 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 284 generation.
# Generation 285 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 285 generation.
# Generation 286 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 286 generation.
# Generation 287 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 287 generation.
# Generation 288 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 288 generation.
# Generation 289 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 289 generation.
# Generation 290 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 290 generation.
# Generation 291 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 291 generation.
# Generation 292 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 292 generation.
# Generation 293 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 293 generation.
# Generation 294 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 294 generation.
# Generation 295 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 295 generation.
# Generation 296 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 296 generation.
# Generation 297 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 297 generation.
# Generation 298 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 298 generation.
# Generation 299 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 299 generation.
# Generation 300 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 300 generation.
# Generation 301 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 301 generation.
# Generation 302 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 302 generation.
# Generation 303 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 303 generation.
# Generation 304 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 304 generation.
# Generation 305 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 305 generation.
# Generation 306 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 306 generation.
# Generation 307 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 307 generation.
# Generation 308 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 308 generation.
# Generation 309 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 309 generation.
# Generation 310 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 310 generation.
# Generation 311 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 311 generation.
# Generation 312 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 312 generation.
# Generation 313 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 313 generation.
# Generation 314 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 314 generation.
# Generation 315 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 315 generation.
# Generation 316 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 316 generation.
# Generation 317 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 317 generation.
# Generation 318 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 318 generation.
# Generation 319 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 319 generation.
# Generation 320 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 320 generation.
# Generation 321 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 321 generation.
# Generation 322 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 322 generation.
# Generation 323 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 323 generation.
# ...
# Statue-0 has the best fitness value in 926 generation.
# Generation 927 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 927 generation.
# Generation 928 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 928 generation.
# Generation 929 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 929 generation.
# Generation 930 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 930 generation.
# Generation 931 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 931 generation.
# Generation 932 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 932 generation.
# Generation 933 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 933 generation.
# Generation 934 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 934 generation.
# Generation 935 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 935 generation.
# Generation 936 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 936 generation.
# Generation 937 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 937 generation.
# Generation 938 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 938 generation.
# Generation 939 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 939 generation.
# Generation 940 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 940 generation.
# Generation 941 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 941 generation.
# Generation 942 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 942 generation.
# Generation 943 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 943 generation.
# Generation 944 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 944 generation.
# Generation 945 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 945 generation.
# Generation 946 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 946 generation.
# Generation 947 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 947 generation.
# Generation 948 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 948 generation.
# Generation 949 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 949 generation.
# Generation 950 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 950 generation.
# Generation 951 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 951 generation.
# Generation 952 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 952 generation.
# Generation 953 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 953 generation.
# Generation 954 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 954 generation.
# Generation 955 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 955 generation.
# Generation 956 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 956 generation.
# Generation 957 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 957 generation.
# Generation 958 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 958 generation.
# Generation 959 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 959 generation.
# Generation 960 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 960 generation.
# Generation 961 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 961 generation.
# Generation 962 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 962 generation.
# Generation 963 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 963 generation.
# Generation 964 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 964 generation.
# Generation 965 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 965 generation.
# Generation 966 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 966 generation.
# Generation 967 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 967 generation.
# Generation 968 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 968 generation.
# Generation 969 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 969 generation.
# Generation 970 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 970 generation.
# Generation 971 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 971 generation.
# Generation 972 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 972 generation.
# Generation 973 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 973 generation.
# Generation 974 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 974 generation.
# Generation 975 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 975 generation.
# Generation 976 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 976 generation.
# Generation 977 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 977 generation.
# Generation 978 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 978 generation.
# Generation 979 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 979 generation.
# Generation 980 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 980 generation.
# Generation 981 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 981 generation.
# Generation 982 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 982 generation.
# Generation 983 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 983 generation.
# Generation 984 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-1 has the best fitness value in 984 generation.
# Generation 985 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-9 has the best fitness value in 985 generation.
# Generation 986 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-7 has the best fitness value in 986 generation.
# Generation 987 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 987 generation.
# Generation 988 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 988 generation.
# Generation 989 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 989 generation.
# Generation 990 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-4 has the best fitness value in 990 generation.
# Generation 991 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-8 has the best fitness value in 991 generation.
# Generation 992 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-5 has the best fitness value in 992 generation.
# Generation 993 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-0 has the best fitness value in 993 generation.
# Generation 994 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 994 generation.
# Generation 995 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 995 generation.
# Generation 996 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-6 has the best fitness value in 996 generation.
# Generation 997 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 997 generation.
# Generation 998 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-2 has the best fitness value in 998 generation.
# Generation 999 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Statue-3 has the best fitness value in 999 generation.
# Generation 1000 generated successfully!
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 8h 34min 23s

# %%
len(PARAMS)
# Out:
# 1001

# %%
# %%time
PATH_FOR_PREV_GEN=OUTPUT_PATH+"\\GEN_"+str(1000)
FINAL_FITNESS=[]

for i in range(POPULATION_SIZE):
    VERTS=PARAMS[1000][i][1][0]
    FACES=PARAMS[1000][i][1][1]

    gr=golden_ratio(np.array(VERTS),np.array(FACES))
    gr=gr/100

    entropy=shannon_entropy(PATH_FOR_PREV_GEN+f"\\STATUE_{i}.blend")
    entropy=entropy/8

    FINAL_FITNESS.append(round(gr+entropy,6))
# Out:
# Wall time: 3.92 s

# %%
FINAL_FITNESS
# Out:
# [0.325124,
#  0.327676,
#  0.326975,
#  0.32648,
#  0.326184,
#  0.326084,
#  0.324121,
#  0.326102,
#  0.436865,
#  0.326961]

# %%
ALL_FITNESS.append(FINAL_FITNESS)

# %%
FINAL_FITNESS.index(max(FINAL_FITNESS))
# Out:
# 8

# %% [markdown]
# ## Plot fitness

# %%
import matplotlib.pyplot as plt
def plot_fitness(fitness):
    
    best_values=[]
    for g in fitness:
        best_values.append(max(g))
    
    plt.figure(figsize=(20,10))
    plt.plot(best_values)
    plt.xlabel("Generation")
    plt.ylabel("Fitness")
    plt.show()

# %%
plot_fitness(ALL_FITNESS)

# %%
best_values=[]
for g in ALL_FITNESS:
    best_values.append(max(g))

# %%
plot()
