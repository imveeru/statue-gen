# %%
import random
import os
import sys

# %%
from CGen import *
from EA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=6,7,9
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome(L,B,H,random.random())
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# (R,G,B,A) = (54,233,81,140)
# Roughness Factor = 5
# Number of vertices = 6
# Number of faces = 9
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (213,165,56,203)
# Roughness Factor = 5
# Number of vertices = 16
# Number of faces = 65
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (120,18,46,249)
# Roughness Factor = 4
# Number of vertices = 10
# Number of faces = 25
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (147,235,168,160)
# Roughness Factor = 2
# Number of vertices = 19
# Number of faces = 85
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (75,168,222,153)
# Roughness Factor = 4
# Number of vertices = 7
# Number of faces = 11
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (161,163,105,144)
# Roughness Factor = 0
# Number of vertices = 19
# Number of faces = 76
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (142,157,40,64)
# Roughness Factor = 4
# Number of vertices = 11
# Number of faces = 25
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (181,191,189,217)
# Roughness Factor = 1
# Number of vertices = 14
# Number of faces = 46
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (233,128,151,215)
# Roughness Factor = 3
# Number of vertices = 17
# Number of faces = 69
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (235,199,219,156)
# Roughness Factor = 4
# Number of vertices = 17
# Number of faces = 72
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 10 ms

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    FILE_NUM=str(i)
    fitness_0.append(face_count(FACES,RO))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[9216, 66560, 6400, 1360, 2816, 76, 6400, 184, 4416, 18432]]

# %%
BEST_FITNESS
# Out:
# [66560]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[face_count(model[5][1],model[4]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [9216, 66560, 6400, 1360, 2816, 76, 6400, 184, 4416, 18432]
#
# Statue-1 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [512, 4608, 70656, 1792, 200, 29, 6400, 9, 100, 9984]
#
# Statue-2 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19, 17664, 1792, 15872, 56, 66560, 1600, 288, 32, 1536]
#
# Statue-5 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [66560, 6912, 72, 2624, 69632, 3456, 188, 17664, 1104, 15872]
#
# Statue-4 has the best fitness value in 3 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1104, 2816, 69, 16640, 17664, 2624, 69632, 73728, 15872, 15872]
#
# Statue-7 has the best fitness value in 4 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15872, 276, 640, 6144, 18432, 992, 112, 1728, 256, 68]
#
# Statue-4 has the best fitness value in 5 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [62, 640, 1728, 6144, 73728, 22, 1088, 276, 992, 82]
#
# Statue-4 has the best fitness value in 6 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73728, 256, 2, 12032, 1088, 640, 640, 976, 22528, 3968]
#
# Statue-0 has the best fitness value in 7 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 40, 18432, 512, 1344, 36864, 73728, 56, 62, 98304]
#
# Statue-9 has the best fitness value in 8 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [576, 8192, 256, 35840, 1344, 3968, 4352, 18432, 48, 200]
#
# Statue-3 has the best fitness value in 9 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1, 104, 144, 20480, 63, 512, 8192, 768, 3968, 35840]
#
# Statue-9 has the best fitness value in 10 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6656, 5568, 8192, 10240, 72, 8960, 19200, 3072, 20480, 8192]
#
# Statue-8 has the best fitness value in 11 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8960, 40, 10240, 10240, 19200, 35, 15360, 0, 1664, 76800]
#
# Statue-9 has the best fitness value in 12 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [416, 4, 15360, 12032, 75, 22272, 15360, 6400, 0, 7680]
#
# Statue-5 has the best fitness value in 13 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [184, 89088, 30720, 15, 15, 22272, 17408, 1392, 3840, 4]
#
# Statue-1 has the best fitness value in 14 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [160, 280, 240, 22272, 59392, 89088, 15, 3840, 53248, 15]
#
# Statue-5 has the best fitness value in 15 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [108, 280, 208, 6144, 3840, 2304, 59392, 22272, 12032, 59392]
#
# Statue-6 has the best fitness value in 16 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 59392, 144, 35840, 928, 5568, 89, 15616, 22272, 14848]
#
# Statue-1 has the best fitness value in 17 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [384, 25600, 22272, 32, 22272, 59392, 16128, 1792, 22272, 4352]
#
# Statue-5 has the best fitness value in 18 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1856, 14336, 11776, 3008, 8960, 348, 6656, 928, 4032, 6400]
#
# Statue-1 has the best fitness value in 19 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [36864, 8, 96, 400, 6400, 28672, 5440, 11776, 128, 6400]
#
# Statue-0 has the best fitness value in 20 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6400, 28, 448, 236, 640, 16640, 2816, 768, 36864, 4096]
#
# Statue-8 has the best fitness value in 21 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 400, 4, 62, 4096, 400, 212, 6400, 256, 4160]
#
# Statue-7 has the best fitness value in 22 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [53, 10240, 640, 400, 13, 212, 64, 2496, 256, 400]
#
# Statue-1 has the best fitness value in 23 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15, 2496, 30720, 20, 13312, 10240, 2496, 5952, 10, 1856]
#
# Statue-2 has the best fitness value in 24 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30720, 1280, 13312, 10240, 1488, 372, 30720, 10240, 2496, 13312]
#
# Statue-0 has the best fitness value in 25 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [240, 2496, 960, 13312, 24576, 24576, 4224, 30720, 13312, 30720]
#
# Statue-7 has the best fitness value in 26 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8192, 6144, 24576, 24, 13312, 1536, 8192, 51200, 24, 30720]
#
# Statue-7 has the best fitness value in 27 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 13312, 6144, 288, 5120, 13312, 30720, 6912, 32768, 8192]
#
# Statue-8 has the best fitness value in 28 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 30720, 3328, 72704, 2944, 13312, 1280, 25600, 120, 15360]
#
# Statue-3 has the best fitness value in 29 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49152, 120, 18176, 240, 25600, 80, 23296, 2, 3, 13312]
#
# Statue-0 has the best fitness value in 30 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 1360, 60416, 23296, 48, 30, 6400, 20480, 284, 23296]
#
# Statue-2 has the best fitness value in 31 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 284, 96, 340, 480, 1392, 25, 1, 91, 23296]
#
# Statue-9 has the best fitness value in 32 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1392, 5376, 144, 1392, 16128, 48, 1072, 96, 32, 6]
#
# Statue-4 has the best fitness value in 33 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [768, 1392, 268, 768, 64, 22272, 83968, 56320, 3840, 144]
#
# Statue-6 has the best fitness value in 34 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 3, 5376, 77, 256, 800, 16, 20224, 3904, 24576]
#
# Statue-9 has the best fitness value in 35 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16384, 4928, 20224, 976, 24576, 3, 3, 37, 24576, 1792]
#
# Statue-4 has the best fitness value in 36 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24576, 24576, 6144, 65536, 1264, 51, 1536, 10240, 10752, 256]
#
# Statue-3 has the best fitness value in 37 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24576, 96, 7680, 1536, 3264, 6144, 3072, 43008, 316, 672]
#
# Statue-7 has the best fitness value in 38 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 23552, 6336, 48, 80, 8448, 1536, 13824, 6144, 24576]
#
# Statue-9 has the best fitness value in 39 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1472, 78848, 3328, 23552, 6144, 528, 464, 5632, 6336, 24576]
#
# Statue-1 has the best fitness value in 40 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22272, 26624, 24, 15872, 308, 34816, 24576, 24, 16, 22]
#
# Statue-5 has the best fitness value in 41 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [308, 1232, 9728, 416, 24576, 27, 1296, 6144, 24576, 56]
#
# Statue-4 has the best fitness value in 42 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80, 22784, 14, 83968, 352, 72704, 6144, 308, 104, 816]
#
# Statue-3 has the best fitness value in 43 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22528, 72704, 52224, 27648, 384, 1136, 10240, 30720, 82, 1424]
#
# Statue-1 has the best fitness value in 44 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 2048, 1600, 2688, 216, 66560, 5696, 5120, 58368, 39936]
#
# Statue-5 has the best fitness value in 45 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1600, 69632, 5504, 15360, 33792, 23552, 1280, 66560, 1728, 5440]
#
# Statue-1 has the best fitness value in 46 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12, 1728, 5120, 69632, 17408, 69632, 15360, 6912, 92, 33792]
#
# Statue-3 has the best fitness value in 47 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1344, 4096, 13312, 44032, 5120, 112, 5120, 384, 8192, 80]
#
# Statue-3 has the best fitness value in 48 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20, 28, 20, 2048, 33792, 4544, 2048, 64512, 8192, 256]
#
# Statue-7 has the best fitness value in 49 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9, 8192, 46080, 14336, 8192, 1136, 38912, 24, 8192, 31744]
#
# Statue-2 has the best fitness value in 50 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 8, 2048, 496, 45056, 40960, 1280, 37888, 14336, 46080]
#
# Statue-9 has the best fitness value in 51 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 49152, 2880, 45056, 14, 31744, 300, 9472, 80896, 53248]
#
# Statue-8 has the best fitness value in 52 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1728, 1200, 53248, 3072, 87040, 2304, 3072, 49152, 880, 400]
#
# Statue-4 has the best fitness value in 53 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2432, 768, 1472, 15360, 32, 12288, 6144, 768, 1152, 93184]
#
# Statue-9 has the best fitness value in 54 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 49152, 43008, 8448, 8192, 65536, 768, 960, 1152, 768]
#
# Statue-5 has the best fitness value in 55 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1152, 1152, 64512, 49152, 42, 33792, 1024, 43008, 37888, 768]
#
# Statue-2 has the best fitness value in 56 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10752, 43008, 0, 16128, 40960, 1152, 33792, 48128, 2368, 43008]
#
# Statue-7 has the best fitness value in 57 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1792, 1, 12288, 47, 2560, 40960, 16, 42, 30720, 12032]
#
# Statue-5 has the best fitness value in 58 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 30720, 10752, 3072, 19968, 81920, 18432, 1792, 3264, 56320]
#
# Statue-5 has the best fitness value in 59 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1248, 75, 8704, 43008, 18432, 7424, 41984, 34816, 79872, 128]
#
# Statue-8 has the best fitness value in 60 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 41984, 11264, 34, 464, 164, 2176, 49152, 544, 2624]
#
# Statue-7 has the best fitness value in 61 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3456, 544, 11264, 1328, 2048, 3648, 21504, 384, 11264, 4480]
#
# Statue-6 has the best fitness value in 62 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 16, 47104, 832, 2048, 6144, 37888, 21504, 14592, 0]
#
# Statue-2 has the best fitness value in 63 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 21504, 2048, 20224, 21504, 148, 1024, 14592, 64, 47104]
#
# Statue-9 has the best fitness value in 64 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 21504, 21504, 84, 81920, 0, 248, 47104, 47104, 21504]
#
# Statue-4 has the best fitness value in 65 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 40960, 84, 21504, 88064, 1344, 21, 228, 54272, 47104]
#
# Statue-4 has the best fitness value in 66 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 61440, 21504, 52224, 21504, 47104, 272, 848, 54272, 14336]
#
# Statue-1 has the best fitness value in 67 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 14336, 4096, 75776, 21504, 68, 3840, 204, 53, 272]
#
# Statue-3 has the best fitness value in 68 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 75776, 14336, 960, 37, 4864, 44032, 71680, 30720, 1]
#
# Statue-1 has the best fitness value in 69 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [164, 5, 12288, 35840, 8192, 7168, 3840, 30720, 512, 300]
#
# Statue-3 has the best fitness value in 70 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [560, 8960, 560, 35840, 8, 41984, 35, 3200, 8960, 3328]
#
# Statue-5 has the best fitness value in 71 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 656, 768, 3200, 72, 35840, 83968, 17664, 80, 3328]
#
# Statue-6 has the best fitness value in 72 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3712, 4224, 51200, 20992, 83968, 83968, 80, 3200, 70656, 560]
#
# Statue-4 has the best fitness value in 73 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 17664, 48, 70656, 74752, 17664, 80, 20992, 800, 17664]
#
# Statue-4 has the best fitness value in 74 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52, 69, 4672, 1920, 22528, 276, 28672, 70656, 276, 35840]
#
# Statue-7 has the best fitness value in 75 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [276, 30, 276, 84, 1856, 276, 1920, 1920, 1344, 832]
#
# Statue-6 has the best fitness value in 76 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16, 704, 512, 17664, 30, 1856, 7424, 38, 4032, 1920]
#
# Statue-3 has the best fitness value in 77 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7424, 6912, 1216, 21248, 512, 1920, 17664, 464, 53, 1008]
#
# Statue-3 has the best fitness value in 78 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 3712, 4032, 1216, 1920, 17664, 1328, 4032, 276, 1216]
#
# Statue-5 has the best fitness value in 79 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21248, 232, 240, 16128, 1040, 36, 276, 196, 3200, 1216]
#
# Statue-0 has the best fitness value in 80 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21248, 14592, 3072, 192, 16128, 196, 240, 1040, 4160, 800]
#
# Statue-0 has the best fitness value in 81 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [83, 176, 14080, 13312, 4160, 12288, 800, 50, 336, 960]
#
# Statue-2 has the best fitness value in 82 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2560, 13312, 65, 960, 260, 3968, 14592, 256, 800, 13312]
#
# Statue-6 has the best fitness value in 83 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [84992, 3648, 800, 240, 200, 2560, 13312, 3584, 20992, 2560]
#
# Statue-0 has the best fitness value in 84 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3584, 10240, 10240, 1280, 20992, 23552, 20992, 128, 14592, 83968]
#
# Statue-9 has the best fitness value in 85 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 1280, 5888, 5248, 1312, 2304, 12, 23552, 3072, 328]
#
# Statue-7 has the best fitness value in 86 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12, 1312, 152, 2304, 2304, 23552, 768, 66560, 9216, 576]
#
# Statue-7 has the best fitness value in 87 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [768, 3, 36, 9216, 4096, 576, 40, 36, 1216, 9216]
#
# Statue-3 has the best fitness value in 88 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 112, 576, 144, 292, 25600, 528, 6, 576, 1216]
#
# Statue-5 has the best fitness value in 89 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 576, 1216, 280, 1232, 268, 688, 292, 40, 144]
#
# Statue-4 has the best fitness value in 90 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1232, 4928, 1232, 64, 72, 2752, 4864, 1072, 144, 43]
#
# Statue-1 has the best fitness value in 91 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 384, 3520, 144, 9, 512, 11008, 2752, 4864, 43]
#
# Statue-6 has the best fitness value in 92 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [304, 32, 1024, 21504, 76, 16, 512, 76, 4, 172]
#
# Statue-3 has the best fitness value in 93 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [236, 19456, 172, 2048, 352, 21504, 688, 512, 3584, 17408]
#
# Statue-5 has the best fitness value in 94 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16640, 512, 80, 1600, 19456, 304, 86016, 5632, 4, 80896]
#
# Statue-6 has the best fitness value in 95 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [100, 86016, 16640, 16, 19456, 9472, 20224, 24576, 72704, 16640]
#
# Statue-1 has the best fitness value in 96 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [316, 1024, 16640, 88, 1344, 5056, 16640, 24576, 21504, 76]
#
# Statue-7 has the best fitness value in 97 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24576, 86016, 24576, 1344, 16, 26624, 16640, 16640, 260, 384]
#
# Statue-1 has the best fitness value in 98 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 26624, 260, 24576, 16640, 26624, 40, 1040, 336, 26624]
#
# Statue-1 has the best fitness value in 99 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [26624, 256, 16, 1024, 24, 25600, 416, 96, 26624, 5120]
#
# Statue-0 has the best fitness value in 100 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 16384, 67, 3072, 26624, 2112, 1536, 416, 6144, 256]
#
# Statue-4 has the best fitness value in 101 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [132, 192, 16, 104, 28672, 11264, 56, 384, 34, 21504]
#
# Statue-4 has the best fitness value in 102 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [78848, 11264, 11264, 93184, 21504, 21504, 3072, 216, 128, 43008]
#
# Statue-3 has the best fitness value in 103 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [78848, 52, 18432, 69, 21504, 78848, 70656, 42, 43008, 1024]
#
# Statue-0 has the best fitness value in 104 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [124, 6144, 49152, 65536, 19712, 2688, 6656, 15360, 43008, 3]
#
# Statue-3 has the best fitness value in 105 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49152, 22, 3072, 2688, 65536, 34816, 240, 9472, 96256, 672]
#
# Statue-8 has the best fitness value in 106 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1536, 236, 1024, 38912, 65536, 2688, 15360, 156, 32, 0]
#
# Statue-4 has the best fitness value in 107 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 256, 576, 16384, 38912, 65536, 30, 96, 1024, 272]
#
# Statue-5 has the best fitness value in 108 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [272, 2752, 38912, 20, 320, 1536, 3072, 65536, 272, 768]
#
# Statue-7 has the best fitness value in 109 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 80, 3520, 1856, 9216, 38912, 3072, 1024, 38912, 96]
#
# Statue-5 has the best fitness value in 110 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5, 1856, 1024, 2048, 38912, 1024, 3520, 38912, 4992, 6144]
#
# Statue-4 has the best fitness value in 111 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38912, 38912, 12288, 1024, 2048, 8192, 96, 1072, 5184, 16384]
#
# Statue-0 has the best fitness value in 112 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 8192, 11264, 12, 1184, 38912, 86016, 2432, 1024, 2048]
#
# Statue-6 has the best fitness value in 113 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 11264, 512, 1024, 21504, 8192, 11264, 1184, 28, 86016]
#
# Statue-9 has the best fitness value in 114 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 5376, 6144, 41984, 768, 704, 11264, 12, 640, 320]
#
# Statue-3 has the best fitness value in 115 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3648, 2048, 8, 15, 176, 3200, 704, 256, 41984, 6144]
#
# Statue-8 has the best fitness value in 116 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3200, 2816, 84992, 3328, 41, 11264, 96, 2816, 176, 51200]
#
# Statue-2 has the best fitness value in 117 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176, 332, 56320, 11264, 0, 2816, 344, 256, 2816, 176]
#
# Statue-2 has the best fitness value in 118 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5, 768, 62464, 0, 56320, 11, 11, 264, 56320, 57344]
#
# Statue-2 has the best fitness value in 119 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 91136, 8960, 15360, 62464, 46080, 768, 14336, 22528, 44]
#
# Statue-1 has the best fitness value in 120 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2880, 17408, 76, 71680, 91136, 3264, 46080, 60416, 3584, 5696]
#
# Statue-4 has the best fitness value in 121 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [28, 768, 91136, 5120, 14336, 1088, 46080, 17408, 3776, 5120]
#
# Statue-2 has the best fitness value in 122 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1088, 192, 13312, 17408, 22784, 4992, 7168, 8192, 69632, 180]
#
# Statue-8 has the best fitness value in 123 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [53248, 8, 8192, 58368, 960, 3136, 63488, 4992, 128, 3072]
#
# Statue-6 has the best fitness value in 124 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [60, 54272, 77824, 63488, 3072, 224, 80, 3072, 768, 24]
#
# Statue-2 has the best fitness value in 125 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30, 224, 63488, 62, 77824, 2048, 7168, 86016, 62, 4]
#
# Statue-7 has the best fitness value in 126 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23, 86016, 16, 31744, 77824, 248, 52224, 77824, 3968, 80]
#
# Statue-1 has the best fitness value in 127 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [77824, 640, 76, 248, 48128, 12, 51200, 86016, 168, 192]
#
# Statue-7 has the best fitness value in 128 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51200, 51200, 86016, 19456, 188, 94, 168, 248, 22528, 51200]
#
# Statue-2 has the best fitness value in 129 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3200, 152, 12800, 50, 51200, 21504, 3968, 1472, 352, 19456]
#
# Statue-4 has the best fitness value in 130 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8192, 152, 7, 3328, 6144, 800, 56320, 11264, 51200, 8960]
#
# Statue-6 has the best fitness value in 131 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [152, 8192, 48, 64512, 512, 8192, 6144, 3520, 11264, 76]
#
# Statue-3 has the best fitness value in 132 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [220, 32768, 25600, 32768, 10752, 6144, 8, 6144, 2048, 768]
#
# Statue-1 has the best fitness value in 133 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [672, 1456, 8, 32768, 11, 24576, 14080, 43008, 168, 128]
#
# Statue-7 has the best fitness value in 134 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [544, 17408, 18944, 25600, 3072, 32768, 316, 42, 10752, 304]
#
# Statue-5 has the best fitness value in 135 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [316, 4, 1792, 55, 244, 20224, 3072, 18944, 8704, 176]
#
# Statue-5 has the best fitness value in 136 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [288, 316, 28, 5632, 240, 12032, 94208, 2048, 1264, 10240]
#
# Statue-6 has the best fitness value in 137 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1264, 77824, 320, 21248, 80896, 32, 44032, 10240, 12032, 14592]
#
# Statue-4 has the best fitness value in 138 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1264, 80896, 4288, 19456, 10, 316, 55296, 12032, 3072, 15360]
#
# Statue-1 has the best fitness value in 139 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10752, 4096, 132, 55296, 20, 4864, 28, 1184, 256, 55296]
#
# Statue-3 has the best fitness value in 140 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80, 3456, 56320, 55296, 15104, 256, 9216, 1184, 128, 2368]
#
# Statue-2 has the best fitness value in 141 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [236, 296, 40960, 0, 9216, 55296, 5888, 316, 3456, 14592]
#
# Statue-5 has the best fitness value in 142 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21760, 352, 40960, 10240, 13568, 132, 17408, 160, 228, 640]
#
# Statue-2 has the best fitness value in 143 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [85, 5120, 8, 22528, 17408, 100, 10240, 912, 10240, 78848]
#
# Statue-9 has the best fitness value in 144 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 78848, 10240, 20480, 22528, 100, 58368, 16, 63488, 17408]
#
# Statue-1 has the best fitness value in 145 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [86, 2432, 18432, 63488, 3072, 9, 5120, 20480, 1232, 21504]
#
# Statue-3 has the best fitness value in 146 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1232, 2240, 83968, 4928, 5120, 64512, 288, 248, 4352, 9216]
#
# Statue-2 has the best fitness value in 147 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [560, 4032, 144, 1536, 656, 184, 20992, 22, 5248, 3]
#
# Statue-6 has the best fitness value in 148 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11776, 1312, 1008, 164, 2240, 1536, 1664, 2432, 9, 1024]
#
# Statue-0 has the best fitness value in 149 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [608, 1280, 1024, 38, 3328, 1008, 11776, 18432, 3328, 11776]
#
# Statue-7 has the best fitness value in 150 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38912, 976, 64512, 2560, 11776, 18944, 296, 6656, 256, 608]
#
# Statue-2 has the best fitness value in 151 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15104, 14336, 3072, 51200, 5120, 1008, 94208, 2, 2560, 4736]
#
# Statue-6 has the best fitness value in 152 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2560, 560, 35840, 3072, 704, 50, 9216, 20992, 81920, 5120]
#
# Statue-8 has the best fitness value in 153 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3520, 81920, 82, 11520, 81920, 208, 35840, 704, 704, 22016]
#
# Statue-1 has the best fitness value in 154 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65, 4608, 108, 47104, 19, 9216, 4480, 992, 67584, 6]
#
# Statue-8 has the best fitness value in 155 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1040, 67584, 32, 576, 2304, 2304, 128, 5120, 4608, 0]
#
# Statue-1 has the best fitness value in 156 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20224, 2496, 4608, 67584, 10240, 2304, 67584, 67584, 1040, 6656]
#
# Statue-3 has the best fitness value in 157 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 416, 33792, 20224, 66, 368, 20480, 67584, 67584, 4608]
#
# Statue-0 has the best fitness value in 158 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 67584, 20480, 67584, 48, 67584, 320, 54, 4224, 43008]
#
# Statue-1 has the best fitness value in 159 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18432, 67584, 67584, 20480, 67584, 29696, 4864, 120, 264, 43008]
#
# Statue-1 has the best fitness value in 160 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 264, 13312, 66, 2048, 72, 1088, 60, 18176, 2]
#
# Statue-0 has the best fitness value in 161 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 72704, 18176, 1136, 16896, 46, 3328, 1088, 67584, 5504]
#
# Statue-1 has the best fitness value in 162 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18176, 2880, 2304, 64, 896, 49, 18176, 72704, 22016, 344]
#
# Statue-7 has the best fitness value in 163 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 18176, 64, 12288, 9, 128, 3328, 3072, 1376, 35840]
#
# Statue-9 has the best fitness value in 164 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 2240, 3328, 4544, 3072, 18176, 208, 204, 2048, 4352]
#
# Statue-0 has the best fitness value in 165 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [77824, 128, 1536, 58, 1136, 128, 4608, 4544, 220, 50176]
#
# Statue-0 has the best fitness value in 166 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18176, 30720, 256, 1424, 17664, 2944, 1536, 284, 1216, 1536]
#
# Statue-1 has the best fitness value in 167 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17664, 30720, 46, 1216, 30720, 6, 3840, 24, 3072, 18176]
#
# Statue-1 has the best fitness value in 168 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 30720, 30, 736, 21504, 2048, 0, 5312, 38912, 18176]
#
# Statue-8 has the best fitness value in 169 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12, 5312, 30720, 3072, 112, 30720, 18176, 30720, 7, 1056]
#
# Statue-2 has the best fitness value in 170 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [50, 17408, 16384, 5120, 2688, 30720, 480, 72704, 480, 192]
#
# Statue-7 has the best fitness value in 171 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13312, 30720, 4352, 16384, 480, 448, 16384, 1088, 21504, 17408]
#
# Statue-1 has the best fitness value in 172 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [480, 16384, 0, 17408, 10, 30720, 1792, 30720, 79872, 16384]
#
# Statue-8 has the best fitness value in 173 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30720, 30720, 17408, 16, 1920, 16384, 4096, 17408, 27648, 27648]
#
# Statue-0 has the best fitness value in 174 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1920, 2624, 960, 27, 1920, 30, 87040, 27648, 1024, 86016]
#
# Statue-6 has the best fitness value in 175 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [87040, 108, 18176, 87040, 5120, 704, 64, 83968, 21760, 1920]
#
# Statue-0 has the best fitness value in 176 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [83968, 340, 4864, 2048, 1024, 63488, 4096, 27, 52, 10240]
#
# Statue-0 has the best fitness value in 177 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80896, 7168, 83968, 10240, 128, 11776, 63488, 63488, 62, 140]
#
# Statue-2 has the best fitness value in 178 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 63488, 83968, 1312, 512, 184, 3968, 576, 80896, 20992]
#
# Statue-2 has the best fitness value in 179 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3584, 20992, 320, 512, 16, 1312, 3968, 34816, 83968, 25600]
#
# Statue-8 has the best fitness value in 180 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 17664, 5120, 544, 34816, 34816, 25, 83968, 34816, 21248]
#
# Statue-7 has the best fitness value in 181 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17664, 19200, 544, 8704, 69, 83968, 34816, 4096, 2048, 332]
#
# Statue-5 has the best fitness value in 182 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [82, 79872, 3328, 12288, 14336, 17664, 21504, 1536, 2560, 256]
#
# Statue-1 has the best fitness value in 183 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56, 7168, 576, 66560, 17408, 15360, 1, 4992, 91, 1536]
#
# Statue-3 has the best fitness value in 184 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 128, 17408, 10752, 448, 48128, 15360, 7168, 91, 12288]
#
# Statue-5 has the best fitness value in 185 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 7168, 10752, 48128, 23040, 48128, 60416, 26624, 4096, 1920]
#
# Statue-6 has the best fitness value in 186 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 28672, 1440, 88064, 3008, 8, 12, 26624, 12032, 7168]
#
# Statue-3 has the best fitness value in 187 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3008, 512, 47, 28, 52224, 1280, 288, 1376, 3072, 3008]
#
# Statue-4 has the best fitness value in 188 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2368, 3008, 624, 48, 3008, 74752, 48128, 204, 22016, 19456]
#
# Statue-5 has the best fitness value in 189 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1376, 9984, 13056, 3008, 74752, 74752, 60416, 3008, 48, 1536]
#
# Statue-4 has the best fitness value in 190 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [60416, 152, 51200, 6656, 74752, 336, 13056, 1168, 832, 1536]
#
# Statue-4 has the best fitness value in 191 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [832, 1536, 6656, 6656, 4096, 13056, 1456, 5632, 73, 188]
#
# Statue-5 has the best fitness value in 192 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5376, 6656, 26, 17408, 20, 26, 5, 544, 16, 13056]
#
# Statue-3 has the best fitness value in 193 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 14592, 19, 6656, 26, 16128, 26, 28672, 17408, 23808]
#
# Statue-7 has the best fitness value in 194 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 14592, 0, 7168, 95232, 10752, 17408, 16128, 8, 3648]
#
# Statue-4 has the best fitness value in 195 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 88, 23552, 4544, 128, 3072, 16128, 272, 448, 14592]
#
# Statue-2 has the best fitness value in 196 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [284, 14592, 8192, 480, 64512, 10496, 8192, 3072, 71, 2368]
#
# Statue-4 has the best fitness value in 197 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13312, 10496, 15, 10240, 2368, 10496, 63, 58368, 32768, 11264]
#
# Statue-7 has the best fitness value in 198 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15104, 2368, 10496, 32768, 1232, 13312, 560, 448, 312, 832]
#
# Statue-3 has the best fitness value in 199 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3776, 1232, 20480, 92160, 336, 140, 1232, 1232, 32768, 400]
#
# Statue-3 has the best fitness value in 200 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 32768, 4928, 3968, 1792, 1280, 92160, 92160, 20480, 23552]
#
# Statue-6 has the best fitness value in 201 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15872, 2944, 32768, 184, 4928, 65536, 92160, 62, 768, 336]
#
# Statue-6 has the best fitness value in 202 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65536, 4928, 14336, 16384, 768, 8192, 74752, 4, 1024, 92160]
#
# ...
# [16640, 5376, 20480, 49152, 84, 304, 25600, 66560, 12288, 22784]
#
# Statue-7 has the best fitness value in 933 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [66560, 66560, 25600, 1216, 16640, 16640, 1024, 32768, 25600, 36864]
#
# Statue-0 has the best fitness value in 934 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 36864, 25600, 45056, 6400, 66560, 2304, 2048, 1216, 59392]
#
# Statue-0 has the best fitness value in 935 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24576, 2304, 59392, 90112, 1088, 4160, 23040, 67584, 3072, 2048]
#
# Statue-3 has the best fitness value in 936 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4352, 264, 5632, 12, 3072, 18688, 67584, 64, 1056, 24576]
#
# Statue-6 has the best fitness value in 937 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 944, 76, 12, 1056, 53248, 67584, 960, 18688, 3840]
#
# Statue-0 has the best fitness value in 938 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [264, 18432, 272, 73, 3072, 18944, 67584, 16896, 67584, 15]
#
# Statue-6 has the best fitness value in 939 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30720, 15872, 3, 67584, 67584, 216, 18432, 83968, 9216, 96]
#
# Statue-7 has the best fitness value in 940 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176, 18, 192, 28, 4224, 7680, 4224, 3456, 29696, 268]
#
# Statue-8 has the best fitness value in 941 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [464, 1856, 12288, 70, 480, 32, 24, 464, 640, 30720]
#
# Statue-9 has the best fitness value in 942 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2304, 30720, 30720, 15104, 1856, 29696, 1856, 1344, 256, 40]
#
# Statue-1 has the best fitness value in 943 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30720, 28672, 30, 1856, 10240, 30, 30720, 1792, 74752, 236]
#
# Statue-8 has the best fitness value in 944 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 120, 292, 4672, 14336, 1792, 59, 7168, 32, 30720]
#
# Statue-9 has the best fitness value in 945 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [896, 16896, 62464, 72704, 14592, 4672, 24, 896, 192, 896]
#
# Statue-3 has the best fitness value in 946 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [25600, 312, 62464, 384, 112, 4096, 4544, 912, 4672, 88064]
#
# Statue-9 has the best fitness value in 947 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [912, 5184, 4096, 5504, 6656, 16384, 18688, 1344, 324, 67584]
#
# Statue-9 has the best fitness value in 948 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1344, 5184, 3584, 4672, 20, 3, 47, 5184, 784, 18688]
#
# Statue-9 has the best fitness value in 949 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 34, 256, 47, 1536, 5568, 5184, 1168, 1536, 4672]
#
# Statue-5 has the best fitness value in 950 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [82944, 4672, 4160, 1296, 1296, 288, 20736, 96, 1264, 16]
#
# Statue-0 has the best fitness value in 951 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37, 1296, 224, 4672, 32, 1280, 60, 36, 96, 32]
#
# Statue-3 has the best fitness value in 952 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34, 5184, 8448, 2304, 4672, 132, 2624, 4672, 144, 960]
#
# Statue-2 has the best fitness value in 953 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [116, 960, 41, 1344, 136, 96, 1024, 73, 27, 164]
#
# Statue-3 has the best fitness value in 954 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [136, 128, 1344, 108, 1, 16384, 34, 1344, 448, 52]
#
# Statue-5 has the best fitness value in 955 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [336, 34816, 4032, 240, 4160, 1344, 432, 512, 16384, 108]
#
# Statue-1 has the best fitness value in 956 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [27, 260, 1008, 2176, 34816, 16384, 4160, 34816, 16640, 7168]
#
# Statue-4 has the best fitness value in 957 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 2176, 9728, 80, 13312, 14336, 624, 34816, 16640, 66560]
#
# Statue-9 has the best fitness value in 958 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16640, 21504, 16640, 56, 1536, 2048, 14336, 43008, 66560, 52]
#
# Statue-8 has the best fitness value in 959 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8192, 43008, 84992, 4352, 2048, 128, 1040, 66560, 43008, 16640]
#
# Statue-2 has the best fitness value in 960 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11008, 77824, 16640, 5312, 20992, 20, 2304, 16640, 66560, 66560]
#
# Statue-1 has the best fitness value in 961 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6144, 11264, 17152, 66560, 216, 77824, 76, 72, 164, 12]
#
# Statue-5 has the best fitness value in 962 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4864, 168, 22272, 17152, 5568, 1792, 216, 16384, 212, 23040]
#
# Statue-9 has the best fitness value in 963 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1792, 24064, 23040, 192, 1984, 960, 1104, 624, 192, 5568]
#
# Statue-1 has the best fitness value in 964 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [832, 1792, 192, 1984, 6144, 69, 1104, 38912, 23040, 96256]
#
# Statue-9 has the best fitness value in 965 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23040, 52, 108, 1104, 13312, 38912, 79872, 98304, 5632, 23040]
#
# Statue-7 has the best fitness value in 966 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [312, 4096, 24, 4032, 13312, 79872, 79872, 2048, 5632, 69632]
#
# Statue-5 has the best fitness value in 967 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 70656, 132, 38912, 39936, 1984, 252, 52, 19968, 64]
#
# Statue-1 has the best fitness value in 968 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32768, 78, 3968, 12, 17664, 31744, 69, 7424, 64, 71]
#
# Statue-0 has the best fitness value in 969 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17664, 72704, 1024, 4416, 70656, 31, 8192, 2560, 17664, 17664]
#
# Statue-1 has the best fitness value in 970 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17664, 72704, 100, 17664, 72704, 108, 17664, 8192, 2368, 70656]
#
# Statue-1 has the best fitness value in 971 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13056, 17664, 12544, 83968, 16384, 71, 54, 72704, 152, 22]
#
# Statue-3 has the best fitness value in 972 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38912, 328, 69, 72704, 13056, 26624, 62, 69632, 20992, 9728]
#
# Statue-3 has the best fitness value in 973 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72704, 15360, 36, 72704, 328, 1024, 50176, 37888, 288, 71]
#
# Statue-0 has the best fitness value in 974 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [100, 54272, 128, 62464, 77824, 72704, 50176, 1024, 3136, 72704]
#
# Statue-4 has the best fitness value in 975 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 72704, 304, 1024, 128, 61, 94208, 72704, 14848, 12544]
#
# Statue-6 has the best fitness value in 976 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 19456, 4544, 43008, 304, 64, 12288, 16384, 94208, 284]
#
# Statue-8 has the best fitness value in 977 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 168, 304, 94208, 43008, 16384, 232, 6144, 80, 19456]
#
# Statue-3 has the best fitness value in 978 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2688, 256, 6656, 448, 1216, 1024, 19456, 1280, 1024, 80]
#
# Statue-6 has the best fitness value in 979 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [42, 19456, 4096, 20480, 1536, 19456, 1280, 104, 1072, 1024]
#
# Statue-3 has the best fitness value in 980 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [76, 61440, 256, 76800, 316, 16384, 3072, 2304, 37888, 5120]
#
# Statue-3 has the best fitness value in 981 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [148, 37888, 848, 9216, 3072, 304, 76800, 292, 2368, 9216]
#
# Statue-6 has the best fitness value in 982 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 192, 144, 9216, 304, 3072, 75, 944, 15360, 2368]
#
# Statue-8 has the best fitness value in 983 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [86016, 62464, 9216, 144, 59, 12, 37888, 60, 1024, 59]
#
# Statue-0 has the best fitness value in 984 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58, 4160, 9216, 18432, 336, 69632, 86016, 248, 61, 3840]
#
# Statue-6 has the best fitness value in 985 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 18688, 40960, 4352, 84, 2304, 336, 69632, 9216, 992]
#
# Statue-7 has the best fitness value in 986 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40960, 9216, 84992, 24576, 40960, 10240, 69632, 40960, 14336, 69632]
#
# Statue-2 has the best fitness value in 987 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40960, 38912, 69632, 384, 7168, 20, 90112, 6144, 28672, 16384]
#
# Statue-6 has the best fitness value in 988 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [87040, 64, 67584, 3072, 90112, 384, 14336, 69632, 608, 30720]
#
# Statue-4 has the best fitness value in 989 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [89088, 1328, 160, 5440, 1088, 11776, 7168, 14336, 16640, 64]
#
# Statue-0 has the best fitness value in 990 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5440, 44032, 87, 22272, 6, 17920, 224, 83968, 12032, 3584]
#
# Statue-7 has the best fitness value in 991 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 2048, 688, 14336, 83968, 17920, 256, 172, 24, 5248]
#
# Statue-4 has the best fitness value in 992 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [83968, 43, 35840, 13312, 5248, 43, 14, 896, 16, 13]
#
# Statue-0 has the best fitness value in 993 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 2752, 172, 1312, 560, 9472, 13312, 56, 13312, 64512]
#
# Statue-9 has the best fitness value in 994 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32768, 268, 7168, 56, 1312, 560, 19456, 1280, 84992, 4096]
#
# Statue-8 has the best fitness value in 995 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [63488, 39936, 7168, 0, 47104, 43008, 256, 84992, 6144, 55]
#
# Statue-7 has the best fitness value in 996 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1856, 15616, 384, 63488, 4096, 15872, 46, 84992, 448, 46]
#
# Statue-7 has the best fitness value in 997 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [896, 84992, 1280, 496, 448, 6, 15872, 90112, 46, 464]
#
# Statue-7 has the best fitness value in 998 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 1024, 13568, 1280, 320, 5, 7424, 48, 2240, 15360]
#
# Statue-9 has the best fitness value in 999 generation.
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 2.79 s

# %%
print(len(ALL_FITNESS))
# Out:
# 1001

# %%
len(PARAMS)
# Out:
# 1001

# %%
C=PARAMS[1000][9]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.44313725490196076, 0.7372549019607844, 0.43529411764705883, 213)'

# %%
print(FACES)
# Out:
# [(1, 0, 4, 5, 7, 10, 12, 14, 15, 16), (9, 0, 1, 3, 4, 5, 6, 7, 11, 13, 14, 15, 16), (1, 3, 4, 5, 6, 8, 9, 10, 12, 15), (0, 2, 3, 4, 5, 7, 8, 9, 11, 14, 15, 16), (2, 0, 4, 6, 8, 9, 10, 14, 16), (3, 0, 1, 5, 7, 8, 11, 12, 13, 14, 15), (7, 2, 3, 4, 5, 8, 9, 12, 13, 16), (0, 4, 8, 9, 13, 15, 16), (3, 0, 1, 2, 4, 6, 7, 8, 12, 13, 14, 16), (0, 1, 2, 4, 5, 7, 9, 10, 11, 12, 14, 16), (11, 2, 4, 5, 7, 9, 10, 13, 15), (4, 1, 2, 3, 6, 7, 8, 9, 11, 13), (2, 0, 1, 5, 8, 10, 14), (0, 1, 2, 3, 4, 6, 8, 9, 10, 11), (4, 1, 2, 6, 7, 8, 9, 10, 15), (6, 4, 7, 8, 9, 12, 14, 15), (9, 1, 2, 4, 5, 6, 8, 12, 13, 14), (3, 5, 6, 10, 13, 14, 16), (5, 1, 3, 4, 6, 7, 9, 10, 12, 13, 14, 15, 16), (12, 0, 3, 4, 10, 11), (2, 5, 6, 8, 10, 11, 13, 14, 16), (7, 5, 6, 8, 10, 11, 13, 15, 16), (5, 0, 1, 3, 6, 7, 9, 14), (7, 4, 8, 9, 10, 12, 16), (6, 0, 4, 5, 8, 9, 10, 11, 12, 13), (6, 3, 4, 5, 7, 14, 15), (14, 0, 2, 4, 5, 7, 9, 11, 15), (7, 5, 6, 10, 11, 13, 15), (7, 1, 4, 5, 9, 11, 12, 13, 15), (4, 0, 3, 6, 7, 10, 12, 15), (8, 0, 2, 3, 7, 9, 10, 12, 16), (10, 1, 5, 9, 12, 13, 15, 16), (0, 1, 3, 4, 7, 8, 9, 10, 12, 15), (10, 1, 2, 3, 4, 5, 8, 11, 16), (4, 0, 1, 3, 6, 7, 9, 11, 13, 15), (11, 4, 5, 6), (0, 1, 2, 3, 6, 8, 10, 13, 14, 15), (5, 2, 6, 8, 10, 12, 14, 15), (1, 0, 2, 3, 6, 7, 8, 10), (3, 1, 6, 10, 11, 12, 14), (5, 0, 6, 7, 9, 10, 11, 14), (1, 5, 6, 7, 8, 9, 10, 11, 13, 15), (1, 7, 9, 10, 11, 15), (3, 1, 2, 4, 5, 6, 8, 9, 12, 13, 15), (3, 0, 1, 6, 10, 12, 13, 15, 16), (1, 2, 3, 9, 10, 16), (6, 2, 4, 9, 10, 11, 14, 15, 16), (4, 0, 1, 3, 10, 11, 13, 15), (1, 2, 8, 10, 11, 12, 14, 16), (3, 0, 2, 4, 5, 6, 8, 9, 10, 11, 13, 14), (4, 2, 3, 5, 6, 10, 11, 14, 15, 16), (8, 0, 2, 3, 4, 5, 12, 15), (8, 0, 5, 7, 9, 11, 12, 14), (3, 0, 5, 6, 7, 10, 11, 12, 14), (10, 1, 2, 4, 5, 7, 11, 13, 14, 16), (13, 1, 3, 9, 10), (13, 0, 1, 2, 3, 4, 5, 7, 8, 9, 11, 12, 14, 15, 16), (2, 0, 6, 7, 12, 13, 15, 16), (9, 1, 3, 6, 8, 10, 11, 12, 14, 15, 16), (2, 0, 1, 6, 7, 8, 12, 14, 15, 16), (7, 1, 2, 3, 8, 9, 11, 12, 13), (9, 1, 4, 5, 6, 8, 11, 12, 15), (2, 4, 5, 7, 12, 13, 14, 15, 16), (15, 0, 1, 2, 5, 6, 7, 8, 11, 12, 13, 14, 16), (1, 2, 3, 4, 9, 10, 13, 15), (4, 0, 1, 5, 7, 8, 9, 10, 12, 13, 14, 16), (3, 0, 1, 2, 4, 5, 7, 8, 9, 11, 13, 15), (6, 2, 5, 7, 8, 13, 14)]

# %%
print(VERTS)
# Out:
# [[2.53137222148046, 3.8282496705108375, 5.367998030325927], [5.338771443528676, 0.5630128779859889, 4.6041239010707935], [2.083039004886203, 2.1321082893687713, 4.606693858179463], [2.7295402783171667, 1.955248311757038, 1.943652978869875], [1.797861555820141, 8.235492228586612, 6.039127412424675], [1.2771422192137682, 7.771328840956178, 6.064779566773068], [0.3763423814826319, 0.9951573155416641, 1.5168907186546474], [1.974274870839398, 2.812296096352145, 4.390977528026327], [1.559275278808333, 2.543874682574566, 2.1116455524159767], [0.07830721368495941, 4.923836615747824, 3.305669920191801], [1.272912411683482, 6.648359973202975, 2.103398987932994], [0.7671946780840908, 4.147784204090969, 6.712205742159719], [5.5432422208547525, 3.218752646278347, 1.258224691585164], [0.8709214590499057, 0.19676452806520783, 5.459530260443377], [5.690681748500135, 7.263580599651602, 0.9226515175570357], [1.1865213846509859, 6.110776172665925, 1.5224564559641527], [5.164083654556549, 1.9927054524058918, 3.5216709846807768]]

# %%
RO
# Out:
# 3

# %%
with open(f'E:\\Research\\Statue Generator\\OUTPUT_6.txt', 'w') as f:
        f.writelines(str(PARAMS))
