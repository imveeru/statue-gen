# %%
import random
import os
import sys

# %%
from ConvexCGen import *

# %%
generate_rgbaRo(10)
# Out:
# ([[0.15729239148097574,
#    0.1588451168320545,
#    0.026856396449266517,
#    0.6146608914009195],
#   [0.3867701853209998,
#    0.8179749484604252,
#    0.6590841390509814,
#    0.8479814869104911],
#   [0.017481143834324087,
#    0.645404835918894,
#    0.04545096589359221,
#    0.04374015859369407],
#   [0.7264580318431407,
#    0.8749538845796758,
#    0.014513324371863923,
#    0.058743385968519024],
#   [0.5096521579697887,
#    0.687286111963945,
#    0.2968691083199213,
#    0.8800908465807161],
#   [0.664693951211644,
#    0.5404530335964592,
#    0.6208891075501443,
#    0.9467559087797638],
#   [0.7236233622251595,
#    0.30704755675472406,
#    0.7663853740931619,
#    0.6457725731242491],
#   [0.21588390391324874,
#    0.16969116376858095,
#    0.34678808599619293,
#    0.13964610445635461],
#   [0.5527445238712173,
#    0.5601925885760947,
#    0.7142651734877127,
#    0.5929515983794047],
#   [0.2072293210140601,
#    0.9869677165128958,
#    0.3922775505948045,
#    0.4089327769588633]],
#  3)

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=10,10,20
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome(L,B,H)
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# Roughness Factor = 2
# Number of vertices = 6
# Number of faces = 6
# Number of materials = 6
# New Bounding Box - (L,B,H) = (2.972451,7.6743,8.784011)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 2
# Number of vertices = 20
# Number of faces = 24
# Number of materials = 24
# New Bounding Box - (L,B,H) = (5.089252,6.43161,12.782743)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 4
# Number of vertices = 4
# Number of faces = 4
# Number of materials = 4
# New Bounding Box - (L,B,H) = (1.346486,1.30431,13.634081)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 2
# Number of vertices = 10
# Number of faces = 12
# Number of materials = 12
# New Bounding Box - (L,B,H) = (3.194048,6.889454,19.225384)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 2
# Number of vertices = 10
# Number of faces = 14
# Number of materials = 14
# New Bounding Box - (L,B,H) = (5.895528,6.107101,6.161853)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 5
# Number of vertices = 5
# Number of faces = 6
# Number of materials = 6
# New Bounding Box - (L,B,H) = (5.859157,7.146388,1.980795)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 2
# Number of vertices = 4
# Number of faces = 4
# Number of materials = 4
# New Bounding Box - (L,B,H) = (8.43191,1.558943,11.045139)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 6
# Number of vertices = 16
# Number of faces = 22
# Number of materials = 22
# New Bounding Box - (L,B,H) = (1.850856,9.092942,15.532687)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 1
# Number of vertices = 4
# Number of faces = 4
# Number of materials = 4
# New Bounding Box - (L,B,H) = (1.314201,4.230762,10.564476)
# -----------------------------------------------------------------------------------------------------------------------------
# Roughness Factor = 2
# Number of vertices = 13
# Number of faces = 16
# Number of materials = 16
# New Bounding Box - (L,B,H) = (6.425121,4.615526,11.680655)
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 87.8 ms

# %%
PARAMS[0][2][1]
# Out:
# [[[0.7438867346219276, 2.921939717251883, 0.3331403423179965],
#   [0.235883473485, 6.954435123903247, 0.3076542336002029],
#   [1.3152994341434177, 11.395751421889472, 1.2661802291139772],
#   [0.015551348050951203, 9.639958312782333, 0.7122357958953818]],
#  [(0, 2, 3), (1, 2, 3), (0, 1, 3), (0, 1, 2)],
#  [[0.6481545286193681,
#    0.33367591471155245,
#    0.24157534745732934,
#    0.5072670099109478],
#   [0.44043632139702116,
#    0.3820584341866524,
#    0.9432451305712676,
#    0.4577654651255231],
#   [0.6273761194753384,
#    0.5986510239129359,
#    0.7240946075702338,
#    0.8884061589493328],
#   [0.4058672412490031,
#    0.5588118436040109,
#    0.7618391103671409,
#    0.5925030469375077]]]

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    NEW_SHAPE=C[6]
    FILE_NUM=str(i)
    fitness_0.append(new_fitness(FACES,RO,VERTS,NEW_SHAPE))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[87, 5416, 2919, 1093, 14937, 187, 396, 14535, 1421, 405]]

# %%
BEST_FITNESS
# Out:
# [14937]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[new_fitness(model[5][1],model[4],model[5][0],model[6]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [87, 5416, 2919, 1093, 14937, 187, 396, 14535, 1421, 405]
#
# Statue-4 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1630, 396, 72371, 11367, 21613, 108354, 5416, 2244, 147, 133388]
#
# Statue-9 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24108, 34316, 28098, 108354, 68992, 9824, 527, 1616, 34316, 72371]
#
# Statue-3 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1470, 133388, 844, 19203, 1421, 39082, 12548, 108354, 1616, 9764]
#
# Statue-1 has the best fitness value in 3 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1764, 1421, 17529, 190, 19203, 9764, 429378, 34316, 92735, 512]
#
# Statue-6 has the best fitness value in 4 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [98182, 74024, 2819, 2332, 1709, 31114, 4519, 138544, 1700, 1544]
#
# Statue-7 has the best fitness value in 5 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23657, 9199, 7755, 5864, 52519, 12575, 43301, 2119, 4655, 53045]
#
# Statue-9 has the best fitness value in 6 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52519, 1577, 107636, 13749, 2119, 11813, 1323, 14261, 259384, 42092]
#
# Statue-8 has the best fitness value in 7 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [272, 52519, 1597, 7862, 3324, 1527, 52519, 14119, 280705, 17464]
#
# Statue-8 has the best fitness value in 8 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72064, 16312, 52519, 255289, 52519, 10680, 206133, 411784, 4513, 280705]
#
# Statue-7 has the best fitness value in 9 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15926, 780, 411784, 263296, 4513, 411784, 31791, 255289, 411784, 206133]
#
# Statue-2 has the best fitness value in 10 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [98368, 1391, 93502, 1023, 5481, 1038, 411784, 292153, 25864, 69177]
#
# Statue-6 has the best fitness value in 11 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22533, 488586, 16673, 24391, 43117, 1744, 69177, 1391, 67384, 5736]
#
# Statue-1 has the best fitness value in 12 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1744, 2368, 69177, 69177, 981, 20099, 10861, 5464, 781, 109961]
#
# Statue-9 has the best fitness value in 13 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [69177, 2397, 357, 261, 566, 38705, 265528, 280705, 8041, 20099]
#
# Statue-7 has the best fitness value in 14 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9510, 70273, 186674, 52021, 304442, 1775, 69177, 38705, 38705, 21609]
#
# Statue-4 has the best fitness value in 15 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20282, 186674, 38705, 27508, 4513, 1531, 347452, 2054, 117571, 2054]
#
# Statue-6 has the best fitness value in 16 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2054, 38705, 1634, 347452, 1531, 1311, 10865, 38705, 1637, 1828]
#
# Statue-3 has the best fitness value in 17 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1913, 22972, 68904, 7715, 2054, 17465, 1475, 117059, 390463, 2819]
#
# Statue-8 has the best fitness value in 18 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47666, 132400, 5353, 1382, 44850, 22972, 7715, 2465, 117059, 1564]
#
# Statue-1 has the best fitness value in 19 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6828, 1456, 3155, 44850, 33071, 44850, 1811, 132400, 1586, 75050]
#
# Statue-7 has the best fitness value in 20 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [44850, 30275, 33840, 191796, 19195, 178482, 126255, 120111, 30766, 1733]
#
# Statue-3 has the best fitness value in 21 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [126255, 191796, 1477, 3179, 2331, 9135, 1791, 30275, 1441, 33840]
#
# Statue-1 has the best fitness value in 22 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [126255, 1973, 126255, 1815, 28718, 1435, 45349, 2080, 470339, 3179]
#
# Statue-8 has the best fitness value in 23 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [126255, 181556, 1750, 2553, 483651, 45349, 5922, 3001, 126255, 356670]
#
# Statue-4 has the best fitness value in 24 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2036, 1489, 121923, 24865, 359743, 1308, 483651, 266554, 483651, 46388]
#
# Statue-6 has the best fitness value in 25 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [135472, 1373, 2331, 483651, 50228, 483651, 483651, 483651, 4838, 483651]
#
# Statue-3 has the best fitness value in 26 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14965, 21793, 95295, 483651, 50741, 483651, 483651, 76075, 1339, 483651]
#
# Statue-3 has the best fitness value in 27 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1710, 11553, 6433, 76075, 344381, 51509, 95295, 20011, 440641, 4501]
#
# Statue-8 has the best fitness value in 28 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6433, 1615, 440641, 17192, 1774, 51509, 344381, 1766, 87101, 44081]
#
# Statue-2 has the best fitness value in 29 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13877, 12723, 14631, 44081, 2681, 10545, 2209, 2333, 44081, 1325]
#
# Statue-3 has the best fitness value in 30 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12723, 1701, 44081, 27457, 52276, 50485, 46899, 3043, 14631, 26433]
#
# Statue-4 has the best fitness value in 31 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13621, 4516, 2101, 1509, 20769, 52276, 1676, 27437, 183603, 1334]
#
# Statue-8 has the best fitness value in 32 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [391488, 3744, 381246, 3328, 8996, 13606, 86846, 21033, 2043, 6434]
#
# Statue-0 has the best fitness value in 33 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [217398, 2553, 1312, 343358, 30510, 86846, 1394, 343358, 1334, 37936]
#
# Statue-3 has the best fitness value in 34 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [87358, 1421, 2258, 1582, 1806, 38449, 1323, 41010, 307515, 6686]
#
# Statue-8 has the best fitness value in 35 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [140593, 1493, 86846, 1421, 2678, 19497, 307515, 68154, 1356, 55093]
#
# Statue-6 has the best fitness value in 36 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [26156, 1543, 10033, 5865, 1599, 1493, 2678, 307515, 86846, 55093]
#
# Statue-7 has the best fitness value in 37 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20475, 10033, 2177, 307515, 307515, 1605, 14773, 2678, 307515, 40229]
#
# Statue-3 has the best fitness value in 38 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14773, 94508, 307515, 14773, 88363, 1563, 216373, 77883, 3255, 2178]
#
# Statue-2 has the best fitness value in 39 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51494, 216373, 216373, 2173, 104769, 1731, 1638, 94508, 1638, 250168]
#
# Statue-9 has the best fitness value in 40 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [219446, 175411, 122157, 1543, 1351, 63544, 216373, 2102, 11557, 1351]
#
# Statue-0 has the best fitness value in 41 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3633, 212276, 216373, 14966, 1453, 4051, 1351, 1309, 3111, 1567]
#
# Statue-2 has the best fitness value in 42 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [101954, 2429, 5817, 11763, 3633, 8493, 2086, 55862, 1538, 184627]
#
# Statue-9 has the best fitness value in 43 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19257, 55862, 2202, 13748, 5705, 280889, 219446, 110146, 5817, 101954]
#
# Statue-5 has the best fitness value in 44 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [248120, 2027, 1547, 19257, 11552, 4127, 48422, 2186, 73017, 50996]
#
# Statue-0 has the best fitness value in 45 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13748, 2457, 73017, 418113, 1416, 4127, 50996, 258360, 5160, 4436]
#
# Statue-3 has the best fitness value in 46 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15912, 73017, 258360, 4436, 13748, 53813, 418113, 13748, 1909, 174387]
#
# Statue-6 has the best fitness value in 47 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [174387, 288057, 14453, 2519, 2108, 12147, 70201, 27393, 111938, 124740]
#
# Statue-1 has the best fitness value in 48 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16424, 2519, 70201, 9140, 9060, 288057, 124740, 10096, 288057, 70201]
#
# Statue-5 has the best fitness value in 49 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2457, 128304, 1767, 288057, 124740, 68904, 276793, 288057, 5528, 9140]
#
# Statue-3 has the best fitness value in 50 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128304, 9264, 106796, 1569, 39203, 68408, 5817, 91436, 159026, 1617]
#
# Statue-8 has the best fitness value in 51 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1427, 1484, 2320, 18104, 1535, 1341, 159026, 68408, 389439, 3683]
#
# Statue-8 has the best fitness value in 52 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [68408, 1535, 269624, 343357, 1342, 2320, 269624, 12403, 2331, 2981]
#
# Statue-3 has the best fitness value in 53 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12403, 12403, 18104, 2331, 2331, 70202, 27776, 11045, 5528, 1830]
#
# Statue-5 has the best fitness value in 54 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3159, 21564, 5528, 1370, 11045, 85291, 18104, 2453, 2222, 12403]
#
# Statue-5 has the best fitness value in 55 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17273, 68408, 5528, 300346, 50740, 406848, 1353, 19193, 269624, 3942]
#
# Statue-5 has the best fitness value in 56 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2611, 406848, 26688, 2384, 56616, 4885, 68408, 17273, 26915, 1416]
#
# Statue-1 has the best fitness value in 57 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [406848, 1740, 31791, 17273, 4885, 56616, 10609, 1536, 2915, 228661]
#
# Statue-0 has the best fitness value in 58 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [228661, 17273, 3231, 1634, 102720, 3364, 332093, 2915, 123183, 1586]
#
# Statue-6 has the best fitness value in 59 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [123183, 249144, 2722, 2554, 1401, 5921, 2928, 2331, 402753, 41252]
#
# Statue-8 has the best fitness value in 60 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5921, 123183, 113965, 8943, 249144, 87357, 2506, 5930, 147761, 3615]
#
# Statue-4 has the best fitness value in 61 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13350, 15351, 37937, 147761, 1765, 36133, 147761, 130350, 232758, 1472]
#
# Statue-8 has the best fitness value in 62 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [130350, 232758, 118083, 1820, 3085, 295226, 1725, 46374, 57399, 232758]
#
# Statue-5 has the best fitness value in 63 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [74810, 233784, 232758, 1861, 2441, 1830, 1803, 27940, 2238, 130350]
#
# Statue-1 has the best fitness value in 64 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1655, 2554, 49446, 232758, 232758, 13171, 114242, 2457, 287034, 1444]
#
# Statue-8 has the best fitness value in 65 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58165, 232758, 2683, 2454, 232758, 4950, 2128, 1392, 38181, 1684]
#
# Statue-1 has the best fitness value in 66 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1424, 39729, 232758, 1893, 297275, 1655, 2016, 17448, 16937, 4950]
#
# Statue-4 has the best fitness value in 67 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1560, 154929, 9765, 295226, 5153, 6699, 2157, 293179, 1601, 4452]
#
# Statue-3 has the best fitness value in 68 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19706, 25890, 6057, 199988, 154929, 17961, 4384, 1448, 394559, 1929]
#
# Statue-8 has the best fitness value in 69 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [154929, 70953, 210229, 40229, 10929, 5705, 154929, 25890, 1698, 1800]
#
# Statue-2 has the best fitness value in 70 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6507, 176435, 5673, 322876, 154929, 5673, 70953, 154929, 39729, 10929]
#
# Statue-3 has the best fitness value in 71 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176435, 154929, 500036, 154929, 1454, 2596, 23294, 3428, 10929, 1404]
#
# Statue-2 has the best fitness value in 72 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24107, 154929, 251192, 27939, 301371, 500036, 5405, 282937, 479556, 1479]
#
# Statue-5 has the best fitness value in 73 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [479556, 1580, 282937, 301371, 500036, 28962, 158002, 32516, 2332, 479556]
#
# Statue-4 has the best fitness value in 74 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [106796, 301371, 358717, 25891, 475459, 20091, 130351, 2332, 112962, 479556]
#
# Statue-9 has the best fitness value in 75 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [106796, 1690, 120900, 396608, 2972, 479556, 128303, 130351, 91434, 301371]
#
# Statue-5 has the best fitness value in 76 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [301371, 76347, 120900, 84266, 1324, 301371, 128303, 286011, 120900, 301371]
#
# Statue-0 has the best fitness value in 77 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [120900, 5545, 15926, 1759, 301371, 330044, 6027, 293178, 416065, 41522]
#
# Statue-8 has the best fitness value in 78 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35108, 1396, 48422, 15926, 7454, 36132, 18217, 31236, 15926, 443714]
#
# Statue-9 has the best fitness value in 79 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [461124, 3428, 15926, 15926, 405824, 1647, 1585, 3492, 15926, 48422]
#
# Statue-0 has the best fitness value in 80 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1352, 461124, 15926, 1562, 228662, 21793, 38181, 15911, 3492, 9455]
#
# Statue-1 has the best fitness value in 81 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3492, 441665, 3471, 148785, 3359, 250168, 61736, 2470, 510276, 1371]
#
# Statue-8 has the best fitness value in 82 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [111425, 36132, 510276, 3471, 7793, 194868, 148785, 485700, 9455, 21794]
#
# Statue-2 has the best fitness value in 83 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [387390, 66856, 28865, 1313, 9455, 1585, 194868, 192819, 485700, 36132]
#
# Statue-8 has the best fitness value in 84 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [61494, 36132, 4323, 387390, 28865, 212278, 97854, 2145, 1399, 20770]
#
# Statue-3 has the best fitness value in 85 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [97342, 1719, 387390, 2158, 61494, 97854, 27969, 394561, 38192, 2850]
#
# Statue-7 has the best fitness value in 86 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5094, 394561, 3009, 16247, 97854, 2850, 444739, 387390, 1732, 1369]
#
# Statue-6 has the best fitness value in 87 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [331069, 1374, 3079, 2850, 61494, 25470, 10532, 5094, 25470, 387390]
#
# Statue-9 has the best fitness value in 88 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [97854, 4070, 204085, 241974, 1719, 1719, 7459, 387390, 25470, 8878]
#
# Statue-7 has the best fitness value in 89 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1719, 241974, 336190, 2851, 25470, 7183, 1531, 7374, 8878, 97854]
#
# Statue-2 has the best fitness value in 90 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [27780, 97854, 2979, 1708, 6574, 6634, 11551, 5222, 18722, 336190]
#
# Statue-9 has the best fitness value in 91 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [336190, 1843, 1373, 1310, 35632, 97854, 18722, 97854, 27780, 5222]
#
# Statue-0 has the best fitness value in 92 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35107, 19241, 35632, 5352, 1436, 7956, 25470, 6574, 336190, 336190]
#
# Statue-8 has the best fitness value in 93 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [336190, 2650, 1864, 73001, 336190, 209206, 377151, 289082, 13811, 73001]
#
# Statue-6 has the best fitness value in 94 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3355, 6574, 44325, 102702, 17697, 377151, 169267, 336190, 5834, 33060]
#
# Statue-5 has the best fitness value in 95 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1584, 11827, 83244, 336190, 29988, 239927, 268601, 33060, 1951, 11827]
#
# Statue-3 has the best fitness value in 96 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1501, 239927, 249144, 465218, 1754, 185651, 83244, 85054, 268601, 169267]
#
# Statue-3 has the best fitness value in 97 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1799, 185651, 11045, 8623, 3158, 1662, 1726, 216373, 3614, 169267]
#
# Statue-7 has the best fitness value in 98 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1308, 169267, 1401, 3955, 30338, 216373, 8623, 3357, 19745, 1495]
#
# Statue-5 has the best fitness value in 99 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1601, 11827, 46375, 62263, 30338, 55093, 216373, 216373, 43315, 11827]
#
# Statue-6 has the best fitness value in 100 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1311, 2173, 41253, 3955, 14625, 62263, 216373, 1823, 399679, 8594]
#
# Statue-8 has the best fitness value in 101 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7040, 216373, 62263, 4641, 28674, 28461, 41253, 25890, 5405, 41253]
#
# Statue-1 has the best fitness value in 102 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1473, 1313, 8109, 1356, 98603, 62263, 110658, 62263, 326972, 216373]
#
# Statue-8 has the best fitness value in 103 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [25388, 1367, 98603, 16567, 1530, 28461, 1431, 326972, 10096, 8752]
#
# Statue-7 has the best fitness value in 104 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23339, 16567, 25388, 7340, 8109, 25643, 31023, 16680, 28461, 326972]
#
# Statue-9 has the best fitness value in 105 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14389, 1658, 1363, 1749, 6177, 25388, 43058, 16680, 26157, 4774]
#
# Statue-6 has the best fitness value in 106 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1371, 11762, 62760, 1724, 14389, 14389, 38961, 92459, 13349, 110146]
#
# Statue-9 has the best fitness value in 107 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38961, 110146, 1570, 83773, 110146, 54565, 184627, 62760, 110146, 1629]
#
# Statue-6 has the best fitness value in 108 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16935, 110146, 17193, 110146, 13093, 28546, 110146, 62760, 110146, 26368]
#
# Statue-1 has the best fitness value in 109 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1380, 8996, 62760, 85565, 3046, 16167, 2425, 1887, 62760, 5289]
#
# Statue-3 has the best fitness value in 110 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1570, 32036, 260409, 301371, 5289, 64809, 3046, 5817, 16167, 1395]
#
# Statue-3 has the best fitness value in 111 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32036, 2634, 5288, 39205, 2511, 32036, 1570, 6299, 441666, 1402]
#
# Statue-8 has the best fitness value in 112 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32036, 32036, 27939, 9504, 5288, 7360, 10789, 331069, 1495, 250167]
#
# Statue-7 has the best fitness value in 113 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46643, 331069, 386368, 163121, 1341, 118061, 152881, 6429, 77097, 467266]
#
# Statue-9 has the best fitness value in 114 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8626, 16567, 105792, 7020, 1349, 2331, 21563, 386368, 319804, 118061]
#
# Statue-7 has the best fitness value in 115 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [90172, 4565, 2603, 1323, 2976, 28205, 4517, 220470, 319804, 18938]
#
# Statue-8 has the best fitness value in 116 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [90172, 319804, 18938, 89406, 18938, 4758, 1745, 230710, 4565, 4517]
#
# Statue-1 has the best fitness value in 117 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8772, 25890, 80956, 6074, 30253, 230710, 90172, 2584, 21373, 1865]
#
# Statue-5 has the best fitness value in 118 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49716, 117570, 21373, 63800, 10096, 31492, 2584, 2584, 59960, 1387]
#
# Statue-1 has the best fitness value in 119 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1585, 3183, 5930, 5240, 117570, 9764, 13094, 1312, 319804, 59960]
#
# Statue-8 has the best fitness value in 120 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [59960, 199988, 170291, 16936, 117570, 5802, 1364, 1394, 1448, 28204]
#
# Statue-1 has the best fitness value in 121 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [59960, 5405, 199988, 16936, 5224, 28204, 9503, 1391, 5383, 1392]
#
# Statue-2 has the best fitness value in 122 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4967, 69930, 2336, 97855, 63784, 2347, 28204, 28204, 199988, 4436]
#
# Statue-8 has the best fitness value in 123 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4775, 199988, 1389, 63784, 102977, 63784, 28204, 8129, 35108, 1526]
#
# Statue-1 has the best fitness value in 124 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4775, 35108, 1489, 135472, 2473, 1341, 199988, 102977, 1564, 63784]
#
# Statue-6 has the best fitness value in 125 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9764, 1317, 199988, 437569, 1742, 135472, 135472, 98603, 1330, 102977]
#
# Statue-3 has the best fitness value in 126 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1742, 1771, 52519, 3424, 7204, 28609, 431425, 1973, 9712, 102977]
#
# Statue-6 has the best fitness value in 127 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52519, 7204, 33220, 1519, 110401, 52519, 5064, 106817, 28609, 1482]
#
# Statue-4 has the best fitness value in 128 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52519, 52519, 14119, 52519, 1369, 3049, 4918, 403776, 83517, 28609]
#
# Statue-7 has the best fitness value in 129 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18105, 357695, 58678, 28609, 255289, 52519, 5592, 4918, 4918, 298298]
#
# Statue-1 has the best fitness value in 130 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58678, 120110, 1564, 289082, 437569, 174386, 3163, 1558, 105772, 255289]
#
# Statue-4 has the best fitness value in 131 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [105772, 2209, 289082, 3163, 174386, 437569, 437569, 105772, 40229, 64055]
#
# Statue-5 has the best fitness value in 132 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [289082, 482627, 117038, 3697, 105772, 1499, 2617, 232758, 117571, 437569]
#
# Statue-1 has the best fitness value in 133 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19322, 18810, 4131, 268602, 466243, 1771, 7455, 9509, 4383, 34095]
#
# Statue-4 has the best fitness value in 134 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1453, 68154, 6946, 45350, 6430, 2077, 9509, 6956, 4131, 8611]
#
# Statue-1 has the best fitness value in 135 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1338, 15798, 3163, 8611, 100927, 2077, 18042, 6956, 23842, 8611]
#
# Statue-4 has the best fitness value in 136 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [399679, 1582, 147760, 100927, 7889, 6956, 1402, 1394, 2915, 11044]
#
# Statue-0 has the best fitness value in 137 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7889, 1371, 84541, 26915, 40228, 1900, 6956, 453955, 91436, 2037]
#
# Statue-7 has the best fitness value in 138 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40228, 114499, 1412, 8419, 113731, 91436, 2764, 116012, 108845, 2037]
#
# Statue-7 has the best fitness value in 139 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38181, 377152, 442690, 23852, 1497, 2634, 116012, 56615, 2102, 55592]
#
# Statue-2 has the best fitness value in 140 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1713, 377152, 241975, 56615, 240951, 1532, 53302, 49446, 442690, 2331]
#
# Statue-8 has the best fitness value in 141 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1713, 73001, 56615, 1708, 53302, 442690, 2331, 1365, 240951, 1497]
#
# Statue-5 has the best fitness value in 142 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1569, 240951, 65832, 133424, 44325, 95533, 1436, 1708, 442690, 171315]
#
# Statue-8 has the best fitness value in 143 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1569, 383296, 171315, 1995, 95533, 4897, 1497, 1372, 442690, 442690]
#
# Statue-8 has the best fitness value in 144 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [433473, 442690, 75066, 442690, 373054, 265528, 11955, 2836, 442690, 68921]
#
# Statue-1 has the best fitness value in 145 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [367933, 1767, 8242, 10993, 111682, 433473, 244023, 74299, 9198, 318780]
#
# Statue-5 has the best fitness value in 146 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1824, 69929, 18721, 11763, 13600, 244023, 1643, 2283, 10993, 52533]
#
# Statue-5 has the best fitness value in 147 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38180, 69929, 120110, 5665, 1824, 18721, 1365, 373054, 107073, 4384]
#
# Statue-7 has the best fitness value in 148 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2332, 1352, 18489, 1564, 1312, 2555, 18617, 5405, 78396, 1705]
#
# Statue-8 has the best fitness value in 149 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2332, 1631, 2697, 1422, 336188, 1437, 2579, 118851, 114989, 5239]
#
# Statue-4 has the best fitness value in 150 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [336188, 1338, 5914, 141616, 1589, 16680, 294202, 261432, 336188, 196916]
#
# Statue-0 has the best fitness value in 151 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10096, 127279, 98604, 294202, 336188, 88363, 38181, 1667, 336188, 196916]
#
# Statue-4 has the best fitness value in 152 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1624, 127279, 1340, 221494, 109870, 98604, 196916, 196916, 1504, 1360]
#
# Statue-3 has the best fitness value in 153 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5921, 4384, 13600, 2096, 446786, 21886, 275770, 98604, 414018, 3085]
#
# Statue-4 has the best fitness value in 154 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [117828, 1555, 55861, 1331, 2080, 3809, 446786, 2410, 5835, 112706]
#
# Statue-6 has the best fitness value in 155 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3106, 77115, 1974, 5835, 446786, 1887, 446786, 18490, 5835, 2410]
#
# Statue-4 has the best fitness value in 156 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1781, 446786, 2463, 446786, 1606, 3310, 5406, 411969, 2828, 114498]
#
# Statue-1 has the best fitness value in 157 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8306, 446786, 411969, 1402, 4128, 218422, 5406, 3310, 1312, 59687]
#
# Statue-1 has the best fitness value in 158 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [480579, 411969, 1350, 411969, 2247, 390463, 126254, 3358, 1518, 8306]
#
# Statue-0 has the best fitness value in 159 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1796, 411968, 434497, 32558, 1629, 6378, 232760, 17911, 480579, 21794]
#
# Statue-8 has the best fitness value in 160 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2333, 434497, 232760, 1316, 213301, 8531, 27008, 1334, 6250, 232760]
#
# Statue-1 has the best fitness value in 161 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2333, 134448, 434497, 232760, 176434, 4952, 294202, 27008, 1562, 396606]
#
# Statue-2 has the best fitness value in 162 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [252217, 13601, 14624, 3357, 5405, 25664, 8113, 434497, 134448, 230711]
#
# Statue-7 has the best fitness value in 163 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9648, 134448, 25664, 5320, 210228, 1371, 1758, 2864, 134448, 230711]
#
# Statue-9 has the best fitness value in 164 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51495, 3408, 210228, 1371, 25664, 34083, 5320, 24866, 8173, 8478]
#
# Statue-2 has the best fitness value in 165 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [390464, 8478, 8045, 3363, 1325, 3555, 4596, 1350, 34083, 301370]
#
# Statue-0 has the best fitness value in 166 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34083, 35108, 390464, 10533, 13620, 1309, 98624, 34083, 49204, 1338]
#
# Statue-2 has the best fitness value in 167 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [28963, 82218, 34083, 25664, 1765, 10533, 27694, 29988, 2815, 1387]
#
# Statue-1 has the best fitness value in 168 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21628, 27694, 7202, 1738, 9503, 29988, 1802, 1443, 1397, 314684]
#
# Statue-9 has the best fitness value in 169 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1319, 2884, 113219, 1354, 12594, 2620, 3359, 1429, 3621, 3650]
#
# Statue-2 has the best fitness value in 170 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9503, 74043, 1363, 2884, 3621, 438594, 2473, 1727, 1472, 3621]
#
# Statue-5 has the best fitness value in 171 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23485, 2374, 1623, 5883, 23230, 191796, 8110, 1472, 5405, 1563]
#
# Statue-5 has the best fitness value in 172 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23485, 292155, 5883, 4308, 23485, 19515, 191796, 6877, 293178, 2530]
#
# Statue-8 has the best fitness value in 173 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2076, 6556, 19515, 2725, 48948, 293178, 1308, 25857, 19515, 6955]
#
# Statue-5 has the best fitness value in 174 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1501, 1806, 26111, 13236, 1501, 3871, 1532, 25919, 2135, 22204]
#
# Statue-2 has the best fitness value in 175 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1779, 12018, 124206, 4070, 25727, 4308, 4084, 1325, 6556, 124206]
#
# Statue-2 has the best fitness value in 176 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1670, 15655, 1456, 17015, 1317, 44082, 6123, 124206, 2076, 446785]
#
# Statue-9 has the best fitness value in 177 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24447, 35108, 112705, 31363, 1780, 319804, 2589, 339260, 58663, 5929]
#
# Statue-7 has the best fitness value in 178 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46132, 112705, 84028, 3101, 403775, 3085, 372030, 272697, 203061, 22460]
#
# Statue-4 has the best fitness value in 179 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1704, 7716, 1618, 55591, 69177, 7150, 46132, 68905, 2397, 272697]
#
# Statue-9 has the best fitness value in 180 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4381, 3356, 26916, 6429, 1704, 272697, 272697, 400702, 1990, 68905]
#
# Statue-7 has the best fitness value in 181 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2916, 185651, 1321, 272697, 79145, 170290, 170290, 1629, 319805, 69177]
#
# Statue-8 has the best fitness value in 182 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [69177, 272697, 79145, 21245, 3970, 1416, 3970, 170290, 11045, 69177]
#
# Statue-1 has the best fitness value in 183 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73531, 272697, 256312, 4389, 11045, 1925, 2328, 1398, 37156, 182579]
#
# Statue-1 has the best fitness value in 184 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [272697, 1665, 4163, 7231, 240952, 47396, 1367, 36132, 1350, 5851]
#
# Statue-0 has the best fitness value in 185 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5851, 9076, 112194, 4436, 47396, 1860, 36132, 2312, 7231, 400704]
#
# Statue-9 has the best fitness value in 186 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2254, 2036, 13941, 2312, 1324, 46131, 93485, 32260, 36132, 5224]
#
# Statue-6 has the best fitness value in 187 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [66856, 3365, 3342, 2308, 1437, 2036, 46131, 13941, 119876, 2765]
#
# Statue-8 has the best fitness value in 188 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [66856, 119876, 475460, 1438, 2344, 30980, 2928, 23934, 2121, 4647]
#
# Statue-2 has the best fitness value in 189 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6557, 242999, 119876, 4211, 5288, 11185, 18472, 197940, 3200, 1576]
#
# Statue-1 has the best fitness value in 190 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1454, 1408, 1573, 6557, 1571, 5608, 33328, 15479, 475460, 10534]
#
# Statue-8 has the best fitness value in 191 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4904, 1502, 30980, 1571, 40753, 1828, 1573, 57911, 1588, 5608]
#
# Statue-7 has the best fitness value in 192 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11441, 3793, 58664, 30980, 85052, 1504, 2144, 2722, 4904, 26157]
#
# Statue-4 has the best fitness value in 193 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48435, 336188, 6315, 85052, 1531, 1878, 85052, 37169, 30980, 85052]
#
# Statue-1 has the best fitness value in 194 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [95039, 48435, 2333, 1340, 1629, 2144, 1878, 5127, 1736, 22315]
#
# ...
# [1831, 54581, 127556, 24867, 1841, 246070, 10788, 65592, 183604, 12595]
#
# Statue-5 has the best fitness value in 4936 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [181555, 1443, 54581, 16680, 10788, 16630, 1731, 127556, 1573, 449858]
#
# Statue-9 has the best fitness value in 4937 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34350, 34863, 449858, 9712, 16680, 1309, 2529, 1501, 113474, 10788]
#
# Statue-2 has the best fitness value in 4938 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1323, 34863, 449858, 10533, 34863, 1908, 19497, 60215, 29378, 3098]
#
# Statue-2 has the best fitness value in 4939 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3044, 212277, 34863, 135471, 1579, 2344, 60215, 19497, 449858, 60215]
#
# Statue-8 has the best fitness value in 4940 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3044, 449858, 212277, 2015, 14517, 1529, 120900, 4629, 1461, 4134]
#
# Statue-1 has the best fitness value in 4941 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [314683, 449858, 2015, 1860, 1784, 1784, 2021, 14517, 1820, 212277]
#
# Statue-1 has the best fitness value in 4942 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33060, 206133, 60712, 332093, 6235, 212277, 1316, 449858, 7391, 1860]
#
# Statue-7 has the best fitness value in 4943 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1820, 209205, 212277, 332093, 1860, 449858, 2589, 492868, 83005, 40228]
#
# Statue-7 has the best fitness value in 4944 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [113474, 10224, 332093, 40228, 332093, 332093, 22013, 83005, 240951, 26669]
#
# Statue-2 has the best fitness value in 4945 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [42290, 84029, 1664, 1569, 164145, 113474, 40228, 47397, 2914, 202038]
#
# Statue-9 has the best fitness value in 4946 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [42033, 4197, 2977, 113474, 202038, 84029, 113474, 202038, 51510, 202038]
#
# Statue-4 has the best fitness value in 4947 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [189748, 202038, 2157, 3617, 202038, 1530, 202038, 1699, 8354, 25645]
#
# Statue-1 has the best fitness value in 4948 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48436, 191795, 189748, 1472, 202038, 13878, 22571, 13108, 450883, 449858]
#
# Statue-8 has the best fitness value in 4949 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8354, 1585, 450883, 7454, 450883, 13108, 68904, 403776, 4307, 449858]
#
# Statue-2 has the best fitness value in 4950 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [403776, 1877, 8354, 3493, 68904, 1564, 2044, 48436, 341309, 403776]
#
# Statue-0 has the best fitness value in 4951 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2044, 341309, 1707, 1705, 2401, 26496, 51493, 7404, 2044, 3358]
#
# Statue-1 has the best fitness value in 4952 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2014, 1366, 2044, 4582, 7404, 2560, 203060, 1355, 273721, 2669]
#
# Statue-8 has the best fitness value in 4953 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13940, 469315, 5593, 51764, 1704, 42277, 4380, 3042, 2120, 133424]
#
# Statue-1 has the best fitness value in 4954 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65832, 1647, 42277, 2120, 13940, 3042, 2120, 30595, 2568, 83004]
#
# Statue-9 has the best fitness value in 4955 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1323, 8478, 61736, 1676, 19514, 1448, 21756, 30595, 1659, 7715]
#
# Statue-2 has the best fitness value in 4956 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4711, 97581, 202038, 19706, 1338, 4326, 8478, 2331, 1814, 10277]
#
# Statue-2 has the best fitness value in 4957 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1352, 28963, 19322, 24703, 37157, 1308, 4005, 1625, 71976, 412992]
#
# Statue-9 has the best fitness value in 4958 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [71976, 71976, 206133, 412992, 8227, 7714, 228662, 4005, 1785, 1352]
#
# Statue-3 has the best fitness value in 4959 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [108866, 3356, 1321, 4649, 59191, 46643, 206133, 228662, 2850, 1565]
#
# Statue-7 has the best fitness value in 4960 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [206133, 3356, 2952, 12581, 437569, 106796, 99903, 1331, 1508, 3057]
#
# Statue-4 has the best fitness value in 4961 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4533, 106796, 2952, 37156, 3358, 106796, 1440, 27072, 2883, 28973]
#
# Statue-1 has the best fitness value in 4962 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32047, 1757, 1876, 211253, 1371, 471363, 91436, 106796, 28973, 1724]
#
# Statue-5 has the best fitness value in 4963 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1806, 53813, 21820, 12576, 111917, 25132, 309563, 80443, 2806, 1377]
#
# Statue-6 has the best fitness value in 4964 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [92734, 111917, 309563, 13599, 211253, 1564, 2543, 2016, 211253, 80443]
#
# Statue-2 has the best fitness value in 4965 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [27940, 192819, 2543, 20603, 6177, 309563, 43826, 2589, 16936, 1340]
#
# Statue-5 has the best fitness value in 4966 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [192819, 1496, 17704, 1355, 49203, 171314, 1732, 3103, 11954, 78395]
#
# Statue-0 has the best fitness value in 4967 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [192819, 2510, 1926, 1372, 113474, 16423, 3103, 49203, 1843, 3103]
#
# Statue-0 has the best fitness value in 4968 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1330, 1339, 3098, 113474, 1378, 2077, 322876, 1309, 165170, 3098]
#
# Statue-6 has the best fitness value in 4969 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [165170, 2072, 41254, 3098, 3098, 42290, 2405, 28717, 1308, 165170]
#
# Statue-0 has the best fitness value in 4970 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [42290, 287034, 384320, 28717, 3098, 8354, 1784, 41254, 41254, 93484]
#
# Statue-2 has the best fitness value in 4971 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1354, 1942, 42290, 168241, 93484, 41254, 287034, 113474, 69929, 8173]
#
# Statue-6 has the best fitness value in 4972 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [287034, 197939, 299322, 168241, 113474, 475460, 93484, 33326, 2764, 42290]
#
# Statue-5 has the best fitness value in 4973 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [197939, 1629, 1811, 299322, 206133, 222517, 2454, 299322, 168241, 180531]
#
# Statue-3 has the best fitness value in 4974 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [435522, 1629, 490820, 168241, 299322, 299322, 95531, 21291, 21793, 206133]
#
# Statue-2 has the best fitness value in 4975 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [109377, 396608, 21291, 490820, 139568, 24875, 13600, 299322, 2084, 206133]
#
# Statue-3 has the best fitness value in 4976 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [206133, 10526, 2039, 19962, 1311, 8996, 81195, 1629, 490820, 35888]
#
# Statue-8 has the best fitness value in 4977 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [36133, 123716, 6571, 3207, 490820, 3364, 8996, 308540, 2133, 43313]
#
# Statue-4 has the best fitness value in 4978 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1563, 308540, 123716, 1501, 8686, 8868, 2540, 477507, 123716, 1453]
#
# Statue-7 has the best fitness value in 4979 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [477507, 1371, 1826, 121668, 123716, 130351, 1845, 482628, 308540, 20540]
#
# Statue-7 has the best fitness value in 4980 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1405, 1697, 3615, 1733, 37156, 168241, 2636, 185650, 1350, 8868]
#
# Statue-7 has the best fitness value in 4981 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10276, 6524, 31010, 225591, 2636, 2246, 1510, 47410, 2636, 333116]
#
# Statue-9 has the best fitness value in 4982 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1394, 13606, 207157, 11057, 1628, 6524, 1440, 333116, 1343, 1664]
#
# Statue-7 has the best fitness value in 4983 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40241, 333116, 207157, 11057, 2636, 8686, 40241, 1619, 156977, 2636]
#
# Statue-1 has the best fitness value in 4984 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1664, 117059, 255288, 40241, 1481, 1937, 11057, 1534, 141617, 156977]
#
# Statue-2 has the best fitness value in 4985 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [117059, 24866, 117059, 84266, 16673, 1860, 100161, 1720, 6299, 36401]
#
# Statue-0 has the best fitness value in 4986 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [118083, 7521, 1407, 100161, 22397, 1780, 23595, 2590, 1617, 84266]
#
# Statue-0 has the best fitness value in 4987 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58679, 7327, 6891, 4380, 1736, 16168, 118083, 118083, 60471, 1416]
#
# Statue-6 has the best fitness value in 4988 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2259, 14375, 16168, 118083, 118083, 118083, 44594, 19898, 3171, 1313]
#
# Statue-3 has the best fitness value in 4989 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [118083, 87357, 1422, 118083, 8643, 118083, 9251, 118083, 118083, 468291]
#
# Statue-9 has the best fitness value in 4990 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [118083, 13093, 468291, 468291, 2908, 48948, 118083, 8162, 1803, 61494]
#
# Statue-2 has the best fitness value in 4991 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8643, 468291, 101697, 325948, 8643, 13093, 468291, 1803, 4641, 21290]
#
# Statue-1 has the best fitness value in 4992 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [118083, 14624, 117571, 1829, 21793, 108845, 6177, 13093, 21290, 8643]
#
# Statue-0 has the best fitness value in 4993 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23842, 32035, 1503, 1490, 340286, 269625, 309563, 135472, 21290, 189748]
#
# Statue-4 has the best fitness value in 4994 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1634, 181554, 404800, 13108, 135472, 1380, 17696, 1356, 353598, 340286]
#
# Statue-2 has the best fitness value in 4995 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4146, 205109, 13108, 2197, 37169, 62760, 363838, 404800, 22819, 1339]
#
# Statue-7 has the best fitness value in 4996 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [404800, 205109, 20732, 1469, 360766, 5111, 4517, 2920, 62760, 4517]
#
# Statue-0 has the best fitness value in 4997 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [29634, 9502, 134447, 5111, 7454, 2129, 2302, 404800, 2810, 1640]
#
# Statue-7 has the best fitness value in 4998 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [78122, 7454, 8049, 1847, 25130, 1640, 1473, 179507, 4307, 15160]
#
# Statue-7 has the best fitness value in 4999 generation.
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 40.7 s

# %%
print(len(ALL_FITNESS))
# Out:
# 5001

# %%
len(PARAMS)
# Out:
# 5001

# %%
C=PARAMS[0][4]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.8941176470588236, 0.054901960784313725, 0.9803921568627451, 96)'

# %%
print(FACES)
# Out:
# [(2, 4, 5, 6, 8, 10, 11, 12, 13, 16), (7, 1, 3, 6, 8, 10, 12, 14, 15), (1, 2, 3, 4, 9, 13, 15), (0, 1, 2, 5, 7, 9, 12, 14, 15), (1, 2, 7, 8), (6, 1, 3, 7, 8, 12, 14, 15), (7, 0, 6, 8, 12, 13), (8, 6, 7, 10, 11, 16), (5, 1, 2, 6, 7, 9, 11, 15), (0, 1, 2, 3, 6, 7, 8, 9, 11, 15, 16), (2, 0, 1, 5, 7, 8, 9, 12, 13, 14, 16), (4, 1, 5, 8, 9, 10, 12, 13), (2, 3, 5, 7, 8, 10, 13), (0, 1, 5, 6, 7, 8, 10, 12, 13, 15, 16), (3, 1, 5, 7, 10), (5, 1, 2, 6, 7, 8, 9, 10, 11, 13, 14, 16), (1, 5, 10, 11, 12, 14, 16), (2, 0, 3, 4, 5, 6, 10, 13, 16), (5, 1, 2, 4, 6, 11, 12, 14, 15), (6, 0, 5, 9, 12, 16), (4, 0, 1, 2, 3, 9, 10), (1, 0, 2, 3, 6, 8, 10, 14, 15), (11, 1, 2, 3, 7, 8, 12, 14, 15, 16), (12, 2, 6, 7, 9, 11, 13, 14, 15, 16), (2, 0, 1, 5, 8, 9, 10, 15), (7, 2, 3, 6, 8, 13), (7, 0, 2, 3, 4, 8, 12), (13, 3, 4, 7, 8, 11, 14, 15), (3, 0, 1, 2, 4, 5, 8, 9, 10, 13, 15), (3, 0, 1, 2, 4, 7, 9, 14, 15, 16), (2, 0, 1, 9, 10, 12, 14, 15), (14, 0, 1, 3, 9, 10, 11, 12, 13), (6, 4, 7, 8, 10, 13, 15, 16), (10, 1, 2, 4, 6, 13, 14, 16), (5, 3, 6, 9, 11, 15), (8, 1, 2, 3, 6, 11, 13, 15, 16), (9, 0, 2, 3, 4, 5, 6, 10, 12), (3, 1, 5, 6, 10, 11, 12, 15, 16), (10, 0, 1, 5, 7, 8, 9, 11, 12), (9, 0, 1, 3, 4, 6, 7, 10, 14, 15), (12, 2, 4, 5, 6, 8, 9, 10, 13, 15, 16), (13, 0, 7, 8, 9, 10, 11, 12, 15, 16), (11, 4, 5, 6, 8, 10, 14, 15, 16), (9, 1, 2, 3, 13, 14, 15), (1, 3, 5, 8, 9, 16), (1, 0, 2, 3, 4, 6, 7, 8, 9, 10, 12, 15), (0, 2, 3, 5, 7, 9, 11, 15), (4, 0, 1, 8, 9, 13, 14, 15), (5, 0, 1, 2, 3, 4, 8, 9, 11, 12, 14, 15), (6, 0, 1, 3, 4, 7, 8, 10, 12, 15, 16), (12, 0, 2, 5, 6, 7, 15, 16), (6, 0, 2, 3, 4, 5, 9, 11, 13, 15, 16), (0, 1, 5, 6, 7, 8, 9, 10, 13, 15), (1, 3, 4, 9, 11, 12, 14), (0, 3, 4, 6, 8, 11, 14), (3, 0, 4, 6, 9, 11, 13, 16), (1, 3, 4, 5, 10, 12, 15, 16)]

# %%
print(VERTS)
# Out:
# [[2.4383340988354645, 9.641111147252383, 5.995322473657193], [1.9709164832373958, 8.172096048281638, 5.729289399431758], [0.8039154992138782, 8.963252417569048, 5.921981824102655], [1.538273567700064, 9.474600662881313, 2.481865085593207], [3.868535707863057, 2.9560298992061727, 1.950251038034124], [3.691388525441258, 0.8223107234516991, 7.323738898139608], [0.33425891095772853, 6.603327842125967, 3.95290256213545], [1.5516880182874049, 8.112432683311043, 5.305291966011452], [0.6506313602800944, 4.482997932842991, 1.6554766185378895], [2.2822177953426217, 5.750786053100483, 4.246381896917852], [3.2323803991083007, 0.310974401255697, 2.6160233803797084], [1.8284707351729268, 7.046270960270011, 3.4099978824542125], [2.7211429073860858, 8.05631181636597, 5.017845770870113], [3.3401074577045464, 8.609643165543517, 6.475286463445506], [2.541016566364304, 2.420338037405675, 7.688334003717102], [0.7300243262490924, 1.551334649641487, 6.302568734146298], [3.129209530859064, 3.1783039776125346, 4.815688837313436]]

# %%
RO
# Out:
# 4

# %%
with open(f'E:\Research\Statue gen output\\OUTPUT_12_VARY_LBH_onlyin_MUTATION.txt', 'w') as f:
        f.writelines(str(PARAMS))
