# %%
import random
import os
import sys

# %%
from CGen import *
from EA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=10,10,20
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome(L,B,H)
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# (R,G,B,A) = (35,1,157,62)
# Roughness Factor = 2
# Number of vertices = 6
# Number of faces = 5
# New Bounding Box - (L,B,H) = (10,3,19)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (123,63,234,182)
# Roughness Factor = 3
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (10,1,4)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (138,149,1,162)
# Roughness Factor = 3
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (9,6,15)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (249,4,164,80)
# Roughness Factor = 4
# Number of vertices = 9
# Number of faces = 19
# New Bounding Box - (L,B,H) = (5,9,18)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (170,84,50,206)
# Roughness Factor = 2
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (9,2,14)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (48,117,233,162)
# Roughness Factor = 5
# Number of vertices = 5
# Number of faces = 4
# New Bounding Box - (L,B,H) = (2,9,7)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (119,185,12,29)
# Roughness Factor = 4
# Number of vertices = 4
# Number of faces = 1
# New Bounding Box - (L,B,H) = (10,8,18)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (198,186,176,57)
# Roughness Factor = 3
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (8,8,3)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (26,28,236,200)
# Roughness Factor = 5
# Number of vertices = 3
# Number of faces = 1
# New Bounding Box - (L,B,H) = (6,10,4)
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (33,62,248,6)
# Roughness Factor = 1
# Number of vertices = 5
# Number of faces = 2
# New Bounding Box - (L,B,H) = (5,3,20)
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 2.99 ms

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    NEW_SHAPE=C[6]
    FILE_NUM=str(i)
    fitness_0.append(new_fitness(FACES,RO,VERTS,NEW_SHAPE))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[659, 108, 883, 5692, 273, 4236, 1708, 267, 1277, 316]]

# %%
BEST_FITNESS
# Out:
# [5692]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[new_fitness(model[5][1],model[4],model[5][0],model[6]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [659, 108, 883, 5692, 273, 4236, 1708, 267, 1277, 316]
#
# Statue-3 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4236, 659, 883, 945, 1516, 4236, 1164, 1168, 284, 322]
#
# Statue-0 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7058, 950, 156, 159, 284, 160, 1165, 396, 105, 1164]
#
# Statue-0 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1682, 27794, 396, 7058, 388, 846, 171, 173, 141, 4239]
#
# Statue-1 has the best fitness value in 3 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [204, 3471, 394, 27794, 144, 846, 7058, 842, 2613, 1682]
#
# Statue-3 has the best fitness value in 4 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3471, 394, 3126, 7570, 3213, 910, 27794, 6971, 3471, 165]
#
# Statue-6 has the best fitness value in 5 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1164, 156, 909, 25403, 2363, 7570, 394, 27794, 7570, 6714]
#
# Statue-7 has the best fitness value in 6 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22673, 5177, 1334, 6971, 142, 25403, 7570, 2189, 22674, 4237]
#
# Statue-5 has the best fitness value in 7 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9363, 1308, 10383, 6457, 205, 842, 15504, 1977, 22674, 171]
#
# Statue-8 has the best fitness value in 8 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [395, 6457, 35986, 188, 658, 6457, 1785, 9358, 842, 848]
#
# Statue-2 has the best fitness value in 9 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4236, 718, 6457, 4664, 165, 1843, 2233, 7308, 35986, 28818]
#
# Statue-8 has the best fitness value in 10 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35986, 2386, 38035, 718, 2188, 237, 588, 14480, 6457, 4236]
#
# Statue-2 has the best fitness value in 11 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2386, 6457, 7311, 4236, 38035, 2187, 183, 169, 588, 14480]
#
# Statue-4 has the best fitness value in 12 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [183, 7311, 154, 1040, 21649, 6457, 739, 847, 19599, 171]
#
# Statue-4 has the best fitness value in 13 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [150, 21305, 5521, 1075, 166, 23353, 913, 1040, 27794, 1162]
#
# Statue-8 has the best fitness value in 14 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [267, 10382, 7309, 1162, 21305, 1489, 254, 2868, 481, 481]
#
# Statue-4 has the best fitness value in 15 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6285, 1656, 2170, 1162, 948, 25402, 845, 1145, 908, 400]
#
# Statue-5 has the best fitness value in 16 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [139, 143, 15160, 914, 910, 1145, 1784, 975, 31891, 25402]
#
# Statue-8 has the best fitness value in 17 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1075, 8083, 6970, 1064, 880, 20280, 6203, 833, 1243, 15160]
#
# Statue-5 has the best fitness value in 18 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [880, 20280, 838, 1163, 7226, 142, 1076, 1205, 884, 1048]
#
# Statue-1 has the best fitness value in 19 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [846, 7226, 4408, 960, 838, 880, 911, 1163, 880, 1163]
#
# Statue-1 has the best fitness value in 20 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [883, 7226, 880, 7226, 1163, 3383, 835, 885, 7226, 880]
#
# Statue-1 has the best fitness value in 21 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [926, 6970, 1075, 3383, 3383, 7226, 875, 1016, 1226, 823]
#
# Statue-5 has the best fitness value in 22 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1016, 1721, 7226, 2868, 1146, 3383, 3383, 3452, 828, 984]
#
# Statue-2 has the best fitness value in 23 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7226, 13112, 11324, 992, 3383, 9276, 7226, 3383, 948, 869]
#
# Statue-1 has the best fitness value in 24 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7226, 824, 835, 1484, 837, 26426, 852, 836, 7226, 3383]
#
# Statue-5 has the best fitness value in 25 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [868, 4917, 863, 18232, 823, 7226, 7226, 836, 909, 8507]
#
# Statue-3 has the best fitness value in 26 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5176, 914, 926, 7226, 837, 852, 829, 1077, 868, 8507]
#
# Statue-9 has the best fitness value in 27 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [868, 859, 1075, 868, 827, 837, 830, 9275, 6458, 883]
#
# Statue-7 has the best fitness value in 28 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [838, 26427, 1097, 2868, 868, 1355, 837, 849, 5946, 859]
#
# Statue-1 has the best fitness value in 29 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1355, 842, 3126, 1355, 7995, 917, 1017, 2868, 19257, 897]
#
# Statue-8 has the best fitness value in 30 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1355, 2868, 3126, 1065, 3893, 2619, 7995, 7995, 855, 897]
#
# Statue-6 has the best fitness value in 31 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3893, 824, 3126, 3893, 3897, 855, 7991, 839, 3893, 1589]
#
# Statue-6 has the best fitness value in 32 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5177, 3897, 7991, 7991, 820, 13113, 854, 3893, 3897, 824]
#
# Statue-5 has the best fitness value in 33 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [869, 824, 7991, 13113, 820, 823, 7991, 7991, 15161, 13113]
#
# Statue-8 has the best fitness value in 34 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3897, 837, 1075, 15160, 873, 18233, 851, 851, 873, 5941]
#
# Statue-5 has the best fitness value in 35 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18233, 18233, 1141, 30523, 828, 18233, 3897, 880, 1077, 820]
#
# Statue-3 has the best fitness value in 36 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2871, 18233, 964, 30523, 18233, 14136, 3897, 30523, 901, 18233]
#
# Statue-3 has the best fitness value in 37 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30523, 35644, 14135, 842, 1075, 30523, 21307, 1142, 18232, 35644]
#
# Statue-1 has the best fitness value in 38 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [914, 27451, 12088, 1076, 1031, 1372, 9532, 824, 5946, 30523]
#
# Statue-9 has the best fitness value in 39 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2358, 8507, 1372, 5946, 914, 13112, 823, 914, 823, 12088]
#
# Statue-5 has the best fitness value in 40 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5946, 868, 1844, 13112, 943, 1843, 5946, 2102, 964, 2869]
#
# Statue-3 has the best fitness value in 41 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5946, 37692, 842, 1844, 12087, 21306, 836, 836, 890, 5946]
#
# Statue-1 has the best fitness value in 42 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37692, 27451, 834, 8251, 20281, 2106, 12087, 13111, 21305, 820]
#
# Statue-0 has the best fitness value in 43 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [823, 2105, 8251, 972, 21305, 834, 918, 826, 21306, 20281]
#
# Statue-8 has the best fitness value in 44 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [972, 905, 1589, 837, 1846, 1590, 20281, 1291, 20281, 2358]
#
# Statue-6 has the best fitness value in 45 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20281, 37692, 20281, 845, 956, 7738, 20281, 1590, 31548, 2102]
#
# Statue-1 has the best fitness value in 46 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [934, 12088, 3127, 37692, 10039, 7738, 1846, 841, 858, 7990]
#
# Statue-3 has the best fitness value in 47 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12088, 827, 7990, 1076, 7995, 1846, 12088, 835, 7990, 1846]
#
# Statue-0 has the best fitness value in 48 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [835, 883, 834, 10300, 850, 14136, 863, 23355, 868, 2869]
#
# Statue-7 has the best fitness value in 49 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14136, 14136, 1843, 1075, 952, 6459, 825, 2869, 959, 1075]
#
# Statue-0 has the best fitness value in 50 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2869, 6459, 835, 885, 8508, 1843, 5177, 829, 1331, 1075]
#
# Statue-4 has the best fitness value in 51 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [884, 2869, 1331, 2869, 7990, 852, 824, 8508, 6459, 2869]
#
# Statue-7 has the best fitness value in 52 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1331, 4665, 23355, 829, 3639, 6459, 17208, 5942, 1016, 6971]
#
# Statue-2 has the best fitness value in 53 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6971, 26426, 8507, 1331, 17208, 849, 851, 1013, 824, 14136]
#
# Statue-1 has the best fitness value in 54 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2428, 851, 1075, 6971, 14136, 852, 2363, 1013, 2875, 828]
#
# Statue-4 has the best fitness value in 55 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1593, 7990, 6971, 9019, 823, 2363, 27452, 1656, 7227, 1844]
#
# Statue-6 has the best fitness value in 56 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1076, 7227, 896, 1588, 7990, 1844, 1227, 948, 27450, 1012]
#
# Statue-8 has the best fitness value in 57 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7227, 823, 1075, 27450, 5176, 4919, 20282, 1588, 33595, 930]
#
# Statue-8 has the best fitness value in 58 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12087, 33595, 4919, 2427, 1843, 820, 2102, 30524, 5176, 2868]
#
# Statue-1 has the best fitness value in 59 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [887, 12087, 3639, 827, 1076, 828, 5176, 1843, 21306, 3639]
#
# Statue-8 has the best fitness value in 60 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [828, 2869, 1075, 3639, 21306, 1143, 839, 852, 834, 7739]
#
# Statue-4 has the best fitness value in 61 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1527, 1844, 2868, 835, 1332, 853, 829, 820, 22328, 11064]
#
# Statue-8 has the best fitness value in 62 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1076, 2869, 1844, 22328, 1013, 1845, 967, 2868, 2868, 1076]
#
# Statue-3 has the best fitness value in 63 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2615, 908, 828, 2492, 16185, 1844, 2869, 824, 1000, 16184]
#
# Statue-4 has the best fitness value in 64 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [851, 1844, 823, 822, 5944, 821, 935, 845, 822, 886]
#
# Statue-4 has the best fitness value in 65 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1076, 1075, 1145, 983, 2869, 2426, 926, 3383, 851, 851]
#
# Statue-7 has the best fitness value in 66 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3383, 1977, 21305, 3383, 1145, 1333, 836, 1913, 983, 1000]
#
# Statue-2 has the best fitness value in 67 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1113, 21305, 829, 853, 11063, 905, 11063, 5177, 1113, 1913]
#
# Statue-1 has the best fitness value in 68 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1324, 1113, 5433, 2868, 1097, 935, 17209, 842, 1226, 827]
#
# Statue-6 has the best fitness value in 69 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1113, 893, 2171, 2868, 5941, 952, 837, 1113, 821, 1420]
#
# Statue-4 has the best fitness value in 70 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [948, 836, 1097, 5941, 952, 1031, 893, 6203, 1141, 848]
#
# Statue-7 has the best fitness value in 71 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [836, 841, 826, 2812, 1141, 2299, 843, 28475, 1096, 901]
#
# Statue-7 has the best fitness value in 72 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [841, 1977, 1195, 1843, 1850, 821, 864, 10039, 2812, 841]
#
# Statue-7 has the best fitness value in 73 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [859, 820, 3324, 1528, 1324, 2360, 884, 828, 1843, 8764]
#
# Statue-9 has the best fitness value in 74 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [883, 1208, 859, 1146, 1332, 2358, 3324, 868, 1161, 884]
#
# Statue-6 has the best fitness value in 75 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [984, 883, 867, 1161, 8252, 835, 906, 3894, 2358, 1161]
#
# Statue-4 has the best fitness value in 76 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [847, 1161, 867, 2358, 931, 889, 870, 3894, 2358, 909]
#
# Statue-7 has the best fitness value in 77 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [832, 1031, 884, 820, 2870, 1845, 889, 6966, 852, 869]
#
# Statue-7 has the best fitness value in 78 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1784, 884, 835, 839, 1332, 17209, 3384, 1142, 6966, 4917]
#
# Statue-5 has the best fitness value in 79 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1076, 836, 824, 1075, 884, 1064, 4918, 11064, 885, 1142]
#
# Statue-7 has the best fitness value in 80 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1075, 934, 884, 1075, 843, 7996, 7227, 884, 11064, 4918]
#
# Statue-8 has the best fitness value in 81 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [948, 26427, 26427, 940, 5177, 835, 827, 20281, 10300, 1270]
#
# Statue-1 has the best fitness value in 82 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1844, 1847, 3640, 927, 1593, 26427, 1978, 2870, 940, 10300]
#
# Statue-5 has the best fitness value in 83 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2234, 10300, 2554, 976, 1849, 1333, 940, 7227, 824, 38716]
#
# Statue-9 has the best fitness value in 84 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2554, 2554, 10300, 2554, 852, 26427, 1333, 1081, 2170, 852]
#
# Statue-5 has the best fitness value in 85 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2107, 828, 1227, 2554, 966, 1258, 884, 853, 821, 1227]
#
# Statue-3 has the best fitness value in 86 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2554, 1258, 853, 1227, 836, 1227, 1048, 6970, 884, 1227]
#
# Statue-7 has the best fitness value in 87 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [852, 1258, 1227, 15160, 853, 1436, 6970, 1843, 25402, 917]
#
# Statue-8 has the best fitness value in 88 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1227, 6970, 883, 1258, 850, 847, 2868, 885, 12088, 1129]
#
# Statue-8 has the best fitness value in 89 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1843, 922, 6970, 1843, 34620, 1129, 835, 855, 852, 922]
#
# Statue-4 has the best fitness value in 90 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [871, 922, 822, 823, 20282, 19258, 1129, 836, 1129, 869]
#
# Statue-4 has the best fitness value in 91 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [859, 19258, 1129, 1076, 19258, 12088, 869, 20282, 19258, 1129]
#
# Statue-7 has the best fitness value in 92 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1843, 5689, 20281, 844, 862, 902, 1978, 1114, 898, 1843]
#
# Statue-2 has the best fitness value in 93 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [29499, 1242, 823, 20281, 984, 959, 901, 37692, 1978, 7991]
#
# Statue-7 has the best fitness value in 94 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1399, 7990, 2939, 3892, 898, 24379, 859, 37692, 9015, 1332]
#
# Statue-7 has the best fitness value in 95 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2299, 31548, 2868, 831, 37692, 836, 2939, 9015, 1270, 7990]
#
# Statue-4 has the best fitness value in 96 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1849, 18233, 959, 2299, 2868, 10044, 2939, 1657, 883, 934]
#
# Statue-1 has the best fitness value in 97 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1033, 1657, 2299, 889, 852, 838, 1913, 12087, 1399, 18233]
#
# Statue-9 has the best fitness value in 98 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1657, 22330, 934, 18233, 12087, 2555, 18233, 1399, 1844, 1657]
#
# Statue-1 has the best fitness value in 99 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1657, 1657, 834, 886, 5943, 22330, 877, 22330, 880, 22330]
#
# Statue-5 has the best fitness value in 100 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5943, 1657, 9017, 22330, 6202, 1657, 1162, 23354, 1843, 22330]
#
# Statue-7 has the best fitness value in 101 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18233, 9014, 23354, 9017, 1075, 823, 949, 2234, 35644, 2102]
#
# Statue-8 has the best fitness value in 102 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12087, 3388, 1334, 26428, 7740, 23354, 24378, 9014, 953, 35644]
#
# Statue-9 has the best fitness value in 103 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7484, 6966, 862, 11068, 7740, 35644, 26428, 24378, 853, 901]
#
# Statue-5 has the best fitness value in 104 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1846, 24378, 35644, 6714, 1291, 35644, 1844, 820, 5945, 6966]
#
# Statue-2 has the best fitness value in 105 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35644, 2298, 849, 21305, 1275, 24378, 905, 35644, 29499, 5945]
#
# Statue-0 has the best fitness value in 106 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35644, 24378, 1205, 11063, 883, 964, 3004, 9532, 5941, 7995]
#
# Statue-0 has the best fitness value in 107 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14136, 5177, 950, 32571, 35644, 1075, 35644, 35644, 3382, 1332]
#
# Statue-4 has the best fitness value in 108 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [964, 41788, 6201, 3127, 843, 6971, 3640, 1388, 9532, 820]
#
# Statue-1 has the best fitness value in 109 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [826, 4665, 1194, 1075, 6201, 832, 41788, 1388, 41788, 3127]
#
# Statue-6 has the best fitness value in 110 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6201, 853, 1075, 1076, 828, 41788, 6201, 1075, 1843, 41788]
#
# Statue-5 has the best fitness value in 111 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31547, 7227, 31548, 846, 846, 849, 6201, 23356, 2101, 876]
#
# Statue-2 has the best fitness value in 112 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2748, 12089, 948, 16185, 1270, 31547, 9014, 872, 1784, 857]
#
# Statue-5 has the best fitness value in 113 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1398, 2105, 2812, 31547, 11064, 964, 869, 836, 31547, 883]
#
# Statue-3 has the best fitness value in 114 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11064, 31547, 7483, 2812, 1913, 11064, 31547, 931, 1843, 31547]
#
# Statue-1 has the best fitness value in 115 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31547, 947, 31547, 2869, 1913, 7483, 839, 3639, 31547, 11064]
#
# Statue-0 has the best fitness value in 116 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [851, 9014, 1527, 2869, 11064, 11064, 1356, 948, 31547, 835]
#
# Statue-8 has the best fitness value in 117 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [853, 822, 856, 984, 31547, 29500, 830, 999, 9014, 862]
#
# Statue-4 has the best fitness value in 118 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8507, 821, 9014, 19258, 11064, 830, 851, 2868, 948, 949]
#
# Statue-3 has the best fitness value in 119 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2615, 11064, 39740, 820, 11064, 14136, 1844, 851, 8507, 918]
#
# Statue-2 has the best fitness value in 120 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [851, 1464, 6714, 8507, 1307, 10556, 948, 6714, 2869, 36668]
#
# Statue-9 has the best fitness value in 121 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1016, 2869, 6714, 10556, 8764, 31548, 823, 3260, 1340, 855]
#
# Statue-5 has the best fitness value in 122 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2876, 1720, 9020, 1194, 948, 10039, 838, 886, 834, 1333]
#
# Statue-5 has the best fitness value in 123 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [838, 1846, 1720, 9020, 832, 20282, 1013, 956, 1194, 10039]
#
# Statue-5 has the best fitness value in 124 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12088, 9015, 5178, 10039, 1463, 2102, 12088, 9020, 926, 956]
#
# Statue-0 has the best fitness value in 125 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12088, 18233, 12088, 1399, 922, 9015, 1000, 12088, 832, 1335]
#
# Statue-1 has the best fitness value in 126 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3640, 1335, 2868, 35644, 1076, 820, 1205, 1528, 4916, 18233]
#
# Statue-3 has the best fitness value in 127 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18233, 884, 1463, 5942, 868, 842, 1844, 1844, 827, 3004]
#
# Statue-0 has the best fitness value in 128 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [837, 884, 1097, 3383, 37692, 1242, 25403, 5941, 859, 1844]
#
# Statue-4 has the best fitness value in 129 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [869, 821, 1844, 37692, 8251, 972, 846, 1242, 2101, 5942]
#
# Statue-3 has the best fitness value in 130 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [822, 902, 856, 5942, 1163, 37692, 824, 4152, 1081, 7482]
#
# Statue-5 has the best fitness value in 131 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [911, 1163, 827, 2940, 827, 1849, 5942, 885, 999, 1163]
#
# Statue-6 has the best fitness value in 132 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1145, 835, 855, 831, 869, 1013, 5942, 918, 4917, 1244]
#
# Statue-6 has the best fitness value in 133 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5942, 5942, 823, 835, 884, 1082, 1244, 885, 855, 885]
#
# Statue-0 has the best fitness value in 134 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1015, 870, 883, 835, 2492, 869, 855, 885, 1271, 827]
#
# Statue-4 has the best fitness value in 135 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [884, 821, 1590, 3895, 1015, 2492, 931, 1843, 27452, 2042]
#
# Statue-8 has the best fitness value in 136 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1075, 2492, 18234, 1844, 27452, 1113, 1591, 1015, 833, 7484]
#
# Statue-4 has the best fitness value in 137 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1076, 27452, 2492, 871, 1843, 2492, 3004, 1012, 38716, 1076]
#
# Statue-8 has the best fitness value in 138 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2555, 3004, 5689, 2811, 7484, 1720, 884, 2870, 2492, 38716]
#
# Statue-9 has the best fitness value in 139 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1269, 3004, 4665, 976, 38716, 7484, 824, 3893, 6967, 976]
#
# Statue-4 has the best fitness value in 140 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2234, 2492, 35644, 3894, 2870, 38716, 4151, 1844, 1097, 33596]
#
# Statue-5 has the best fitness value in 141 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1243, 865, 12087, 38716, 6966, 964, 956, 4151, 1655, 1590]
#
# Statue-3 has the best fitness value in 142 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6966, 956, 1590, 893, 964, 1655, 852, 38716, 3128, 10300]
#
# Statue-7 has the best fitness value in 143 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6966, 10300, 2869, 3894, 13111, 7483, 6966, 893, 1843, 3384]
#
# Statue-4 has the best fitness value in 144 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6966, 1206, 1243, 6966, 29499, 13111, 10300, 13111, 8251, 7483]
#
# Statue-4 has the best fitness value in 145 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1335, 13111, 8251, 1076, 8251, 13111, 29499, 13111, 7483, 4152]
#
# Statue-6 has the best fitness value in 146 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8251, 8251, 2868, 43836, 1099, 2614, 13111, 932, 855, 29499]
#
# Statue-3 has the best fitness value in 147 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1843, 855, 4408, 3516, 996, 856, 27452, 13111, 16185, 29499]
#
# Statue-9 has the best fitness value in 148 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [29499, 43836, 2868, 4665, 4408, 13111, 1244, 28475, 7484, 7740]
#
# Statue-1 has the best fitness value in 149 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13111, 2358, 29499, 1500, 4408, 825, 29499, 939, 870, 939]
#
# Statue-2 has the best fitness value in 150 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1243, 7995, 855, 43836, 1275, 29499, 29499, 1589, 2358, 14138]
#
# Statue-3 has the best fitness value in 151 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [939, 939, 876, 7995, 830, 43836, 7739, 1206, 1270, 918]
#
# Statue-5 has the best fitness value in 152 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [876, 830, 43836, 918, 2619, 950, 1275, 828, 11580, 1146]
#
# Statue-2 has the best fitness value in 153 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [870, 11580, 11580, 1292, 1656, 1146, 996, 1784, 11580, 1113]
#
# Statue-1 has the best fitness value in 154 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [851, 6714, 1333, 1977, 824, 11580, 2869, 8252, 1336, 2613]
#
# Statue-5 has the best fitness value in 155 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [828, 6971, 6714, 3126, 8252, 1075, 1845, 23353, 828, 1977]
#
# Statue-7 has the best fitness value in 156 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [901, 15161, 1843, 1075, 1075, 17208, 2614, 1075, 10038, 1075]
#
# Statue-5 has the best fitness value in 157 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2234, 1075, 1275, 2614, 850, 999, 35643, 4409, 821, 1843]
#
# Statue-6 has the best fitness value in 158 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7226, 999, 6458, 2041, 4409, 1210, 823, 35643, 821, 6971]
#
# Statue-7 has the best fitness value in 159 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [844, 1260, 864, 13111, 3640, 7226, 2614, 2041, 6971, 4409]
#
# Statue-3 has the best fitness value in 160 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2614, 835, 1591, 31547, 1356, 19257, 1591, 7226, 4409, 10044]
#
# Statue-3 has the best fitness value in 161 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4409, 7227, 934, 10038, 839, 2614, 947, 19257, 24379, 19257]
#
# Statue-8 has the best fitness value in 162 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3895, 24379, 23353, 1076, 4917, 1843, 858, 33595, 1307, 835]
#
# Statue-7 has the best fitness value in 163 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3892, 931, 972, 24379, 5941, 919, 29500, 6202, 31547, 859]
#
# Statue-8 has the best fitness value in 164 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [823, 1845, 29500, 948, 841, 8507, 2747, 10812, 884, 906]
#
# Statue-2 has the best fitness value in 165 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7996, 822, 857, 29500, 884, 1307, 833, 5946, 821, 825]
#
# Statue-3 has the best fitness value in 166 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [836, 923, 1276, 4408, 885, 33596, 1146, 14135, 2101, 2747]
#
# Statue-5 has the best fitness value in 167 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2358, 886, 934, 949, 2747, 4408, 1141, 851, 15160, 849]
#
# Statue-8 has the best fitness value in 168 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [843, 1141, 884, 823, 828, 3004, 949, 1141, 851, 1372]
#
# Statue-5 has the best fitness value in 169 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [971, 1141, 843, 1372, 843, 2169, 5941, 1372, 19258, 914]
#
# Statue-8 has the best fitness value in 170 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3895, 826, 1528, 5941, 13112, 22329, 1032, 894, 5941, 1372]
#
# Statue-5 has the best fitness value in 171 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [838, 1843, 5941, 6201, 906, 5941, 12088, 21306, 909, 1331]
#
# Statue-7 has the best fitness value in 172 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1013, 884, 2101, 836, 828, 9276, 2106, 21306, 2106, 18232]
#
# Statue-7 has the best fitness value in 173 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [884, 820, 951, 843, 9020, 11064, 884, 21306, 949, 8507]
#
# Statue-7 has the best fitness value in 174 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10039, 947, 6715, 864, 949, 884, 2614, 835, 906, 8507]
#
# Statue-0 has the best fitness value in 175 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [850, 6715, 946, 6715, 6715, 855, 5690, 5941, 22329, 6715]
#
# Statue-8 has the best fitness value in 176 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [909, 869, 9019, 858, 6715, 22329, 838, 909, 22329, 850]
#
# Statue-5 has the best fitness value in 177 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6201, 22329, 2875, 1161, 22329, 22329, 909, 22329, 6201, 909]
#
# Statue-1 has the best fitness value in 178 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1141, 833, 22329, 934, 6201, 6201, 11062, 9020, 35644, 909]
#
# Statue-8 has the best fitness value in 179 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9015, 22329, 33596, 12088, 1141, 2362, 884, 33596, 9020, 6201]
#
# Statue-2 has the best fitness value in 180 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1161, 22329, 30523, 6201, 22329, 9020, 1340, 1075, 1075, 823]
#
# Statue-2 has the best fitness value in 181 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [860, 2233, 13112, 22329, 30523, 8251, 820, 6201, 852, 1076]
#
# Statue-4 has the best fitness value in 182 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [856, 1016, 10038, 837, 856, 22329, 6201, 13112, 1076, 24378]
#
# Statue-9 has the best fitness value in 183 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22329, 30524, 3896, 831, 948, 855, 13112, 872, 22329, 2870]
#
# Statue-1 has the best fitness value in 184 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1588, 1843, 13112, 2870, 6966, 863, 909, 846, 4664, 6966]
#
# Statue-2 has the best fitness value in 185 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2101, 1206, 1271, 2614, 967, 26425, 2869, 2869, 6966, 872]
#
# Statue-5 has the best fitness value in 186 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2869, 22329, 835, 2748, 823, 1206, 2358, 829, 6966, 6966]
#
# Statue-1 has the best fitness value in 187 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2869, 820, 836, 16185, 1206, 943, 1206, 833, 36668, 918]
#
# Statue-8 has the best fitness value in 188 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [918, 1075, 23353, 10039, 849, 21306, 16185, 1844, 1211, 16185]
#
# Statue-2 has the best fitness value in 189 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10039, 28476, 14136, 16185, 16185, 5942, 860, 23353, 23353, 31548]
#
# Statue-9 has the best fitness value in 190 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12088, 999, 825, 1844, 14136, 23353, 849, 12087, 12087, 5942]
#
# Statue-5 has the best fitness value in 191 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [842, 14135, 1177, 1259, 12088, 14136, 876, 6460, 834, 28475]
#
# Statue-9 has the best fitness value in 192 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [968, 1340, 851, 12088, 837, 28475, 1096, 823, 28475, 1844]
#
# Statue-5 has the best fitness value in 193 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18232, 824, 20280, 1340, 935, 1340, 36668, 918, 28475, 860]
#
# Statue-6 has the best fitness value in 194 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1340, 2040, 18232, 1912, 36668, 872, 9020, 860, 5176, 1340]
#
# Statue-4 has the best fitness value in 195 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3127, 33596, 2040, 2619, 24378, 1843, 1720, 7483, 7991, 1340]
#
# Statue-1 has the best fitness value in 196 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2868, 1720, 2619, 2619, 853, 7991, 1332, 1048, 2555, 2427]
#
# Statue-5 has the best fitness value in 197 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7991, 2868, 2555, 825, 1275, 939, 853, 2619, 822, 914]
#
# Statue-0 has the best fitness value in 198 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [855, 835, 13111, 7991, 7991, 854, 939, 2868, 7991, 853]
#
# Statue-2 has the best fitness value in 199 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [935, 927, 857, 2868, 10039, 4918, 1271, 1844, 7991, 935]
#
# Statue-4 has the best fitness value in 200 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24378, 19257, 10039, 1142, 2555, 7991, 1844, 821, 960, 20282]
#
# Statue-0 has the best fitness value in 201 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6965, 902, 860, 19257, 19257, 1075, 15160, 1271, 10039, 10039]
#
# Statue-3 has the best fitness value in 202 generation.
# ------------------------------------------------------------------------------------------------------------------------
# ...
#
# Statue-1 has the best fitness value in 4933 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3894, 1844, 1721, 984, 6966, 1721, 6458, 3894, 20282, 19256]
#
# Statue-8 has the best fitness value in 4934 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33595, 13112, 19256, 1130, 1356, 19256, 1721, 5433, 20282, 7482]
#
# Statue-0 has the best fitness value in 4935 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19256, 15160, 842, 884, 29499, 13112, 910, 1227, 1388, 32571]
#
# Statue-9 has the best fitness value in 4936 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13112, 16184, 919, 10039, 968, 27452, 4917, 883, 10040, 836]
#
# Statue-5 has the best fitness value in 4937 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5941, 7991, 2811, 832, 28475, 11064, 13112, 7992, 33596, 841]
#
# Statue-8 has the best fitness value in 4938 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16185, 870, 826, 23355, 845, 7990, 897, 869, 1013, 2555]
#
# Statue-3 has the best fitness value in 4939 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14136, 897, 16185, 1270, 1013, 851, 1013, 885, 7990, 1846]
#
# Statue-2 has the best fitness value in 4940 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23354, 14136, 9014, 2867, 1846, 1849, 23354, 1270, 1843, 11064]
#
# Statue-0 has the best fitness value in 4941 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23354, 853, 1032, 851, 3893, 23354, 23354, 3384, 23354, 5942]
#
# Statue-0 has the best fitness value in 4942 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16184, 880, 5942, 1017, 11063, 883, 828, 839, 37692, 2102]
#
# Statue-8 has the best fitness value in 4943 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11063, 2233, 11063, 918, 10044, 4664, 16184, 1130, 17209, 1142]
#
# Statue-8 has the best fitness value in 4944 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16184, 889, 3383, 5942, 10044, 3383, 8507, 37692, 4664, 17209]
#
# Statue-7 has the best fitness value in 4945 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37692, 10044, 17209, 8507, 827, 884, 5941, 17209, 37692, 37692]
#
# Statue-0 has the best fitness value in 4946 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [41788, 4407, 18233, 857, 37692, 8507, 8507, 18232, 4917, 1307]
#
# Statue-0 has the best fitness value in 4947 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [872, 31547, 1334, 825, 20281, 2868, 37692, 33596, 2868, 23354]
#
# Statue-6 has the best fitness value in 4948 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33596, 1178, 857, 1075, 852, 857, 2868, 2683, 8507, 972]
#
# Statue-0 has the best fitness value in 4949 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22330, 8507, 848, 1307, 1340, 1227, 1270, 948, 1589, 956]
#
# Statue-0 has the best fitness value in 4950 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2170, 824, 22330, 22330, 1270, 9275, 885, 1340, 1307, 8507]
#
# Statue-2 has the best fitness value in 4951 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2170, 883, 869, 9275, 1463, 22330, 22330, 1844, 1307, 948]
#
# Statue-5 has the best fitness value in 4952 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1721, 1844, 829, 15161, 22330, 5941, 22330, 11063, 9275, 9275]
#
# Statue-4 has the best fitness value in 4953 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2170, 835, 42812, 3892, 6202, 1843, 2939, 22330, 22330, 15161]
#
# Statue-2 has the best fitness value in 4954 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2170, 2868, 829, 854, 1843, 992, 835, 42812, 883, 9275]
#
# Statue-7 has the best fitness value in 4955 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20281, 855, 1843, 992, 823, 1075, 972, 1332, 11064, 833]
#
# Statue-0 has the best fitness value in 4956 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20281, 2619, 6714, 2101, 820, 8251, 1332, 1843, 1844, 853]
#
# Statue-0 has the best fitness value in 4957 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8251, 849, 901, 883, 836, 1913, 2101, 8251, 884, 2619]
#
# Statue-0 has the best fitness value in 4958 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [943, 1076, 2234, 9020, 842, 1913, 939, 1527, 1913, 884]
#
# Statue-3 has the best fitness value in 4959 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [939, 943, 828, 884, 5177, 884, 1977, 893, 914, 1527]
#
# Statue-4 has the best fitness value in 4960 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1162, 2234, 19257, 956, 838, 943, 3639, 1077, 893, 999]
#
# Statue-2 has the best fitness value in 4961 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9020, 1162, 1162, 1077, 2358, 3639, 885, 19257, 1194, 829]
#
# Statue-7 has the best fitness value in 4962 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [829, 13113, 2298, 835, 1276, 956, 22330, 835, 829, 1075]
#
# Statue-6 has the best fitness value in 4963 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1178, 2614, 22330, 983, 20281, 967, 5942, 13113, 7996, 23354]
#
# Statue-9 has the best fitness value in 4964 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3383, 23354, 901, 910, 5942, 3383, 1843, 2102, 5941, 864]
#
# Statue-1 has the best fitness value in 4965 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1271, 23354, 1075, 11063, 1843, 2041, 910, 29499, 1843, 983]
#
# Statue-7 has the best fitness value in 4966 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6202, 5433, 6458, 821, 1078, 7995, 983, 922, 5689, 1000]
#
# Statue-5 has the best fitness value in 4967 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20281, 1000, 939, 1592, 29499, 1211, 1077, 2869, 983, 868]
#
# Statue-4 has the best fitness value in 4968 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2619, 901, 825, 2299, 885, 5940, 25402, 16184, 2869, 1000]
#
# Statue-6 has the best fitness value in 4969 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1843, 25402, 868, 3893, 823, 5940, 4664, 2812, 18232, 1096]
#
# Statue-1 has the best fitness value in 4970 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [883, 825, 2427, 4664, 5177, 922, 1077, 2869, 883, 859]
#
# Statue-4 has the best fitness value in 4971 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3640, 5177, 9015, 4664, 884, 4664, 825, 1332, 5176, 927]
#
# Statue-2 has the best fitness value in 4972 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [822, 6970, 5690, 5177, 1332, 4664, 5176, 883, 1332, 5176]
#
# Statue-1 has the best fitness value in 4973 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1032, 893, 839, 4664, 938, 5946, 1333, 5689, 5690, 820]
#
# Statue-5 has the best fitness value in 4974 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [901, 2618, 7739, 1032, 892, 21306, 1130, 861, 2106, 839]
#
# Statue-5 has the best fitness value in 4975 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1588, 1845, 7739, 901, 5689, 1130, 854, 7739, 1075, 938]
#
# Statue-2 has the best fitness value in 4976 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6202, 1845, 7739, 1076, 1075, 2102, 1075, 12087, 5689, 1843]
#
# Statue-7 has the best fitness value in 4977 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1075, 2868, 1013, 2614, 3639, 897, 5432, 28475, 2102, 7739]
#
# Statue-7 has the best fitness value in 4978 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7739, 5942, 834, 3639, 842, 2428, 1843, 884, 24378, 5432]
#
# Statue-8 has the best fitness value in 4979 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7739, 1332, 6714, 869, 1194, 29499, 2428, 5177, 2555, 3383]
#
# Statue-5 has the best fitness value in 4980 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11063, 1270, 1077, 7990, 835, 2555, 2868, 893, 8508, 29499]
#
# Statue-9 has the best fitness value in 4981 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8508, 2868, 837, 1848, 824, 1275, 8508, 934, 29499, 23352]
#
# Statue-8 has the best fitness value in 4982 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7995, 1355, 884, 8508, 1206, 17208, 24379, 1844, 863, 1843]
#
# Statue-6 has the best fitness value in 4983 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [952, 2746, 1843, 20281, 931, 846, 24379, 24379, 8508, 1843]
#
# Statue-6 has the best fitness value in 4984 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [926, 4918, 1194, 1308, 1075, 24379, 4917, 858, 2746, 11063]
#
# Statue-5 has the best fitness value in 4985 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2299, 926, 838, 28474, 1206, 2811, 1194, 27450, 1012, 4918]
#
# Statue-3 has the best fitness value in 4986 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [918, 951, 34620, 2169, 1843, 4918, 24379, 926, 1843, 28474]
#
# Statue-2 has the best fitness value in 4987 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1292, 4918, 1077, 28474, 1843, 835, 2299, 2426, 1843, 34620]
#
# Statue-9 has the best fitness value in 4988 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [840, 1013, 2554, 1843, 876, 934, 1843, 34620, 2684, 6966]
#
# Statue-7 has the best fitness value in 4989 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [934, 1528, 9276, 34620, 15159, 30524, 9014, 1843, 13113, 1143]
#
# Statue-3 has the best fitness value in 4990 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15159, 36668, 9276, 944, 31548, 34620, 2868, 27451, 9276, 836]
#
# Statue-1 has the best fitness value in 4991 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1843, 3068, 22329, 9276, 931, 36668, 31548, 3895, 31548, 821]
#
# Statue-5 has the best fitness value in 4992 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4665, 1015, 31548, 36668, 2748, 950, 858, 1844, 36668, 9276]
#
# Statue-3 has the best fitness value in 4993 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2868, 9788, 1076, 831, 2876, 2748, 36668, 948, 31548, 5434]
#
# Statue-6 has the best fitness value in 4994 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22330, 6965, 858, 6715, 27450, 2868, 31548, 5434, 1012, 898]
#
# Statue-6 has the best fitness value in 4995 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1308, 5434, 1048, 31548, 7482, 2868, 15160, 2868, 14137, 1527]
#
# Statue-3 has the best fitness value in 4996 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1721, 5434, 7995, 5434, 824, 877, 21307, 17208, 4408, 27450]
#
# Statue-9 has the best fitness value in 4997 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [836, 27450, 1843, 1848, 7995, 17208, 27450, 1324, 833, 21307]
#
# Statue-1 has the best fitness value in 4998 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1588, 42812, 832, 1848, 1162, 11064, 1843, 1843, 9015, 1324]
#
# Statue-1 has the best fitness value in 4999 generation.
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 5.65 s

# %%
print(len(ALL_FITNESS))
# Out:
# 5001

# %%
len(PARAMS)
# Out:
# 5001

# %%
C=PARAMS[5000][2]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.49019607843137253, 0.41568627450980394, 0.9098039215686274, 186)'

# %%
print(FACES)
# Out:
# [(10, 6, 16), (5, 0, 3, 7, 13, 14, 16), (14, 0, 3, 4, 5, 6, 7, 9, 10, 11, 12, 13), (9, 0, 2, 4, 6, 11, 12, 13, 14, 15), (3, 1, 2, 4, 5, 7, 11, 15), (2, 1, 3, 4, 5, 7, 8, 12, 14), (1, 7, 9, 10, 11, 13, 16), (0, 2, 4, 5, 7, 8, 9, 12), (11, 3, 4, 6, 8, 10, 13, 16), (2, 0, 1, 5, 6, 7, 8, 9, 10, 12, 14, 15), (8, 2, 3, 4, 7, 11, 12, 14), (5, 1, 2, 3, 6, 7, 8, 9, 12, 13, 14, 16), (4, 1, 3, 6, 9, 10, 12, 14), (12, 1, 5, 6, 7, 8, 10, 11, 16), (11, 1, 2, 5, 8, 10, 12, 15, 16), (0, 1, 2, 3, 6, 7, 12, 13, 15, 16), (0, 1, 2, 4, 5, 8, 9, 13, 16), (4, 2, 5, 8, 9, 12, 13, 14, 15), (11, 2, 3, 5, 6, 7, 8, 10, 12, 13, 14), (13, 1, 4, 5, 6, 7, 8, 10, 14, 15), (0, 3, 4, 5, 7, 8, 12, 13, 14, 16), (1, 0, 2, 4, 10, 13, 15), (14, 0, 2, 3, 4, 6, 7, 8, 10, 11, 12, 13, 16), (0, 1, 4, 5, 6, 7, 10, 16), (4, 0, 2, 5, 8, 9, 10, 11, 15), (1, 0, 3, 4, 6, 8, 9, 10, 14, 15, 16), (4, 0, 2, 3, 5, 8, 9, 12, 14), (15, 3, 6, 7, 9, 12), (3, 1, 2, 4, 6, 7, 8, 12, 14, 16), (7, 0, 1, 2, 3, 4, 5, 6, 8, 10, 11, 14, 16), (2, 1, 3, 5, 6, 7, 10, 11, 12, 13, 14, 16), (4, 1, 3, 5, 12, 13, 15, 16), (1, 0, 4, 5, 6, 9, 13, 14, 16), (5, 0, 2, 3, 8, 12, 13, 15), (13, 1, 2, 3, 8, 10, 11, 12, 14, 16), (0, 1, 2, 3, 6, 7, 8, 11, 13, 14, 15), (13, 0, 2, 3, 4, 6, 7, 10, 11, 12, 14, 15, 16), (7, 1, 2, 3, 4, 5, 8, 9, 10, 12, 14, 16), (2, 0, 3, 5, 8, 13, 14), (11, 4, 6, 9, 10, 12, 13, 16), (1, 2, 3, 6, 8, 10, 11, 12, 14, 15, 16), (6, 0, 2, 3, 4, 5, 7, 10, 11, 12, 15, 16), (8, 0, 1, 2, 3, 4, 5, 6, 9, 10, 12), (12, 1, 2, 3, 8, 10, 13, 15, 16), (7, 2, 3, 4, 8, 9, 12, 13, 14), (3, 0, 2, 8, 10, 13, 14, 15), (10, 0, 2, 3, 4, 5, 6, 9, 11), (6, 0, 2, 4, 5, 9, 10, 11, 12, 14, 16), (4, 0, 3, 8, 9, 13, 14, 16), (1, 0, 2, 3, 4, 5, 8, 10, 11, 13, 14, 15, 16), (3, 2, 7, 10, 11, 15), (0, 3, 4, 5, 6, 9, 10, 11, 12, 14, 15, 16), (1, 3, 4, 5, 7, 9, 10, 11, 13, 15), (8, 0, 1, 2, 4, 7, 9, 10, 11, 12, 14, 15), (5, 1, 2, 3, 8, 11, 13, 14, 15, 16), (0, 1, 2, 4, 5, 7, 8, 9, 11, 12, 14, 15), (0, 1, 7, 8, 10, 11, 12, 13, 15), (3, 1, 4, 7, 8, 15, 16)]

# %%
print(VERTS)
# Out:
# [[1.5792212370911083, 3.626815838594333, 1.2895456991785093], [4.227785209915608, 0.5661685341509959, 2.054548172168446], [3.929780260390897, 3.2518190421833224, 4.091497754482774], [0.13121418739577173, 5.39964694664779, 1.3244547496449326], [4.217081998324008, 6.762222622724925, 2.495578136307296], [4.657656838799653, 2.313701885717026, 3.048402541802982], [3.4062862783542993, 0.008145684252848784, 2.2013444654769794], [1.1495028874298752, 6.6917281585719905, 4.868592923159983], [5.75388808960385, 2.8389028927303115, 6.842448852895897], [5.76236985265335, 6.603972762574957, 2.411499034321014], [5.543476757967323, 2.196657555810939, 2.9727862715836517], [4.915219216459716, 5.707932764693966, 3.0482244477147926], [4.771723522327745, 0.004654729235281874, 6.34172330616697], [2.2799221998672943, 3.179005742287191, 3.7493658363817906], [3.880974547869531, 5.898808745338238, 3.220164270832973], [4.635997555868375, 7.359026724298099, 5.397582614688076], [0.9177312979231373, 8.655078252745438, 3.759571436917368]]

# %%
RO
# Out:
# 5

# %%
with open(f'E:\\Research\\Statue Generator\\OUTPUT_8.txt', 'w') as f:
        f.writelines(str(PARAMS))
