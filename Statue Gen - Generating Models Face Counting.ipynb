# %%
import random
import os
import sys

# %%
from CGen import *
from EA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=6,7,9
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome(L,B,H,random.random())
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# (R,G,B,A) = (227,182,74,121)
# Roughness Factor = 1
# Number of vertices = 17
# Number of faces = 81
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (129,69,213,94)
# Roughness Factor = 3
# Number of vertices = 11
# Number of faces = 31
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (16,47,215,37)
# Roughness Factor = 1
# Number of vertices = 4
# Number of faces = 1
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (93,244,107,41)
# Roughness Factor = 5
# Number of vertices = 8
# Number of faces = 15
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (31,79,98,124)
# Roughness Factor = 4
# Number of vertices = 4
# Number of faces = 3
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (53,190,34,237)
# Roughness Factor = 1
# Number of vertices = 6
# Number of faces = 4
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (70,139,201,35)
# Roughness Factor = 3
# Number of vertices = 7
# Number of faces = 14
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (158,150,65,204)
# Roughness Factor = 2
# Number of vertices = 12
# Number of faces = 38
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (45,138,87,245)
# Roughness Factor = 4
# Number of vertices = 5
# Number of faces = 5
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (74,147,162,157)
# Roughness Factor = 5
# Number of vertices = 7
# Number of faces = 6
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 11 ms

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    FILE_NUM=str(i)
    fitness_0.append(face_count(FACES,RO))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[324, 1984, 4, 15360, 768, 16, 896, 608, 1280, 6144]]

# %%
BEST_FITNESS
# Out:
# [15360]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[face_count(model[5][1],model[4]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [324, 1984, 4, 15360, 768, 16, 896, 608, 1280, 6144]
#
# Statue-3 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16, 4096, 6144, 768, 15360, 15360, 1984, 324, 12288, 1024]
#
# Statue-4 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [768, 15360, 3072, 768, 3072, 12288, 33792, 27648, 5632, 60416]
#
# Statue-9 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 1536, 33, 256, 60, 33792, 58368, 33792, 1024, 12288]
#
# Statue-6 has the best fitness value in 3 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4608, 256, 1024, 90, 768, 33792, 1168, 47104, 33792, 12288]
#
# Statue-7 has the best fitness value in 4 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 3712, 12288, 768, 8448, 33792, 2048, 576, 17664, 5120]
#
# Statue-5 has the best fitness value in 5 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [960, 336, 132, 33792, 4096, 192, 10752, 2432, 14080, 17664]
#
# Statue-3 has the best fitness value in 6 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14080, 55, 30720, 80, 128, 15360, 14080, 59392, 14080, 768]
#
# Statue-7 has the best fitness value in 7 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 6144, 30720, 12288, 928, 236, 16640, 14336, 144, 13824]
#
# Statue-2 has the best fitness value in 8 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8704, 30720, 24, 30720, 1040, 16640, 12288, 82944, 16640, 65]
#
# Statue-7 has the best fitness value in 9 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4160, 8704, 1, 30720, 192, 41984, 12288, 12288, 62464, 1792]
#
# Statue-8 has the best fitness value in 10 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [528, 12288, 1600, 1792, 3072, 34816, 1920, 768, 1920, 608]
#
# Statue-5 has the best fitness value in 11 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16640, 6144, 34816, 49152, 3584, 34816, 1920, 44, 4096, 1920]
#
# Statue-3 has the best fitness value in 12 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18176, 68, 2048, 144, 6144, 192, 93184, 46080, 8448, 9984]
#
# Statue-6 has the best fitness value in 13 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [71, 5120, 192, 18176, 4096, 5504, 132, 368, 176, 132]
#
# Statue-3 has the best fitness value in 14 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [92, 4096, 10240, 5504, 176, 4, 18176, 192, 20480, 27648]
#
# Statue-9 has the best fitness value in 15 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [368, 2368, 20480, 34816, 43008, 13312, 192, 81920, 5440, 3968]
#
# Statue-7 has the best fitness value in 16 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10752, 42, 1360, 43008, 2304, 51, 32, 24, 25088, 20480]
#
# Statue-3 has the best fitness value in 17 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 2, 42, 10752, 168, 100352, 12, 2304, 6144, 256]
#
# Statue-5 has the best fitness value in 18 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4, 100352, 3840, 42, 10752, 288, 2304, 1, 2304, 47]
#
# Statue-1 has the best fitness value in 19 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 36, 960, 3840, 1344, 15360, 5376, 512, 2368, 60]
#
# Statue-5 has the best fitness value in 20 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [144, 4096, 5376, 5696, 15360, 15360, 1024, 9472, 240, 8960]
#
# Statue-4 has the best fitness value in 21 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [61440, 4608, 4, 26, 5376, 60416, 35840, 1024, 6912, 15360]
#
# Statue-0 has the best fitness value in 22 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 50176, 65536, 1728, 61440, 61440, 1536, 11264, 416, 61440]
#
# Statue-2 has the best fitness value in 23 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [372, 640, 160, 61440, 61440, 68, 61440, 11264, 3840, 5248]
#
# Statue-3 has the best fitness value in 24 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 3840, 60, 4, 60, 61440, 5632, 216, 128, 6144]
#
# Statue-5 has the best fitness value in 25 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15360, 60416, 4, 2, 60, 384, 960, 896, 57344, 43008]
#
# Statue-1 has the best fitness value in 26 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [944, 896, 5120, 528, 16384, 60, 57344, 2048, 60416, 56320]
#
# Statue-8 has the best fitness value in 27 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [57344, 60416, 39936, 13312, 57344, 3776, 14, 4096, 54272, 944]
#
# Statue-1 has the best fitness value in 28 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65536, 896, 1152, 56, 56, 23552, 57344, 60416, 4096, 7168]
#
# Statue-0 has the best fitness value in 29 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16384, 768, 65536, 3, 66560, 16384, 13312, 2112, 57344, 70656]
#
# Statue-9 has the best fitness value in 30 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6144, 4096, 19456, 4096, 3072, 8192, 57344, 48128, 10752, 1024]
#
# Statue-6 has the best fitness value in 31 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 15360, 43008, 76, 57344, 47, 768, 12032, 64512, 4096]
#
# Statue-8 has the best fitness value in 32 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 69632, 3072, 16128, 48128, 43008, 57344, 144, 98304, 168]
#
# Statue-8 has the best fitness value in 33 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 38912, 76, 16, 1024, 48128, 43008, 8192, 17408, 57344]
#
# Statue-9 has the best fitness value in 34 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [57344, 256, 2048, 10752, 65536, 2048, 896, 7168, 43008, 512]
#
# Statue-4 has the best fitness value in 35 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [57344, 65536, 448, 15360, 51200, 112, 5376, 320, 57344, 23552]
#
# Statue-1 has the best fitness value in 36 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 12288, 23552, 4096, 1920, 256, 3584, 800, 320, 23552]
#
# Statue-2 has the best fitness value in 37 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [96256, 17920, 23552, 1664, 14336, 256, 128, 1024, 5888, 12544]
#
# Statue-0 has the best fitness value in 38 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [53248, 17920, 94, 104, 17920, 17920, 12544, 23552, 17920, 3]
#
# Statue-0 has the best fitness value in 39 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [992, 13312, 208, 14080, 17920, 3840, 4608, 71680, 23552, 784]
#
# Statue-7 has the best fitness value in 40 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 35, 92, 43008, 17920, 1216, 11264, 23552, 17920, 3840]
#
# Statue-3 has the best fitness value in 41 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 1536, 2048, 23040, 5184, 29696, 23, 23552, 17920, 3840]
#
# Statue-5 has the best fitness value in 42 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24, 8192, 4608, 960, 25, 23552, 23040, 1280, 23, 4480]
#
# Statue-5 has the best fitness value in 43 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19200, 83, 128, 12, 18, 9728, 80, 1088, 23552, 2048]
#
# Statue-8 has the best fitness value in 44 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5312, 32, 7168, 18, 11264, 23552, 1792, 23552, 1088, 4480]
#
# Statue-5 has the best fitness value in 45 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2816, 30720, 83, 6912, 64, 23552, 7168, 59392, 39936, 7168]
#
# Statue-7 has the best fitness value in 46 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 64512, 1920, 4096, 6912, 4, 8, 2816, 92, 28]
#
# Statue-1 has the best fitness value in 47 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1008, 576, 240, 4096, 4096, 1280, 23, 76, 63, 92]
#
# Statue-3 has the best fitness value in 48 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 1280, 1, 1472, 26624, 3072, 79872, 640, 5120, 4096]
#
# Statue-6 has the best fitness value in 49 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 1072, 64, 79872, 1280, 3, 5120, 3, 3072, 79872]
#
# Statue-3 has the best fitness value in 50 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [28672, 1072, 144, 192, 1280, 2048, 64512, 5120, 80, 20]
#
# Statue-6 has the best fitness value in 51 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5, 3072, 64512, 37888, 56, 1280, 128, 3072, 192, 128]
#
# Statue-2 has the best fitness value in 52 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64512, 37, 3072, 37888, 176, 8192, 3072, 37888, 3072, 252]
#
# Statue-0 has the best fitness value in 53 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64512, 14336, 296, 57, 148, 176, 36, 3072, 6144, 37888]
#
# Statue-0 has the best fitness value in 54 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6144, 116, 6144, 296, 80, 176, 37888, 63, 592, 16128]
#
# Statue-6 has the best fitness value in 55 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [592, 2816, 6144, 96, 61, 3712, 592, 16128, 496, 10240]
#
# Statue-7 has the best fitness value in 56 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [59392, 592, 10, 848, 10240, 7, 10240, 37888, 3712, 232]
#
# Statue-0 has the best fitness value in 57 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [160, 64512, 15360, 688, 37888, 432, 3712, 37888, 9216, 148]
#
# Statue-1 has the best fitness value in 58 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 16128, 3840, 37888, 9472, 656, 37888, 2048, 37888, 37888]
#
# Statue-3 has the best fitness value in 59 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2368, 592, 24, 14336, 64, 37888, 256, 592, 37888, 8]
#
# Statue-5 has the best fitness value in 60 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 24576, 592, 2368, 1440, 34816, 512, 18432, 39, 2240]
#
# Statue-5 has the best fitness value in 61 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6, 136, 448, 12288, 480, 2048, 20480, 64, 2368, 2176]
#
# Statue-6 has the best fitness value in 62 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52224, 136, 320, 91136, 480, 7680, 20480, 5120, 20480, 28]
#
# Statue-3 has the best fitness value in 63 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7168, 14336, 81, 41984, 480, 79872, 480, 24, 20, 44]
#
# Statue-5 has the best fitness value in 64 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 52, 14336, 41984, 10496, 30, 46, 11264, 656, 53248]
#
# Statue-9 has the best fitness value in 65 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3840, 68608, 86016, 13312, 896, 14336, 3328, 53248, 89088, 41]
#
# Statue-8 has the best fitness value in 66 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4864, 26, 1392, 68608, 17408, 36864, 89088, 1072, 50176, 2048]
#
# Statue-6 has the best fitness value in 67 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2304, 19456, 68608, 1392, 19456, 77824, 68, 14336, 12544, 10]
#
# Statue-5 has the best fitness value in 68 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18432, 83, 68608, 268, 77824, 5120, 14336, 12544, 9216, 31744]
#
# Statue-4 has the best fitness value in 69 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 224, 77824, 12544, 18432, 1152, 256, 36, 3584, 77824]
#
# Statue-2 has the best fitness value in 70 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4864, 2816, 77824, 2112, 3776, 4608, 31744, 300, 896, 47104]
#
# Statue-2 has the best fitness value in 71 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1984, 77824, 2816, 192, 77824, 10496, 576, 2816, 3776, 75]
#
# Statue-1 has the best fitness value in 72 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1216, 656, 16640, 77824, 1152, 7168, 656, 32768, 2624, 34816]
#
# Statue-3 has the best fitness value in 73 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 2048, 66560, 36864, 128, 63488, 34, 51200, 5632, 28]
#
# Statue-2 has the best fitness value in 74 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4160, 50176, 13312, 3072, 41984, 200, 24576, 32768, 51200, 66560]
#
# Statue-9 has the best fitness value in 75 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [50176, 22528, 50176, 24576, 21760, 5376, 24576, 12800, 3072, 204]
#
# Statue-0 has the best fitness value in 76 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 87040, 10240, 3072, 800, 50176, 15872, 2176, 6912, 272]
#
# Statue-1 has the best fitness value in 77 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12, 15872, 68608, 50176, 1728, 640, 15872, 2560, 12, 1792]
#
# Statue-2 has the best fitness value in 78 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7680, 992, 3136, 27648, 1792, 49, 1792, 4160, 4288, 50176]
#
# Statue-9 has the best fitness value in 79 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4288, 7, 4160, 1072, 7680, 1792, 6400, 56, 39936, 2816]
#
# Statue-8 has the best fitness value in 80 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3136, 9216, 25, 23040, 39936, 124, 8192, 7680, 1664, 1040]
#
# Statue-4 has the best fitness value in 81 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [39936, 3136, 96, 0, 2304, 90, 39936, 59, 39936, 768]
#
# Statue-0 has the best fitness value in 82 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34816, 768, 86016, 304, 4608, 90, 39936, 39936, 30720, 90]
#
# Statue-2 has the best fitness value in 83 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [136, 2816, 86016, 336, 86016, 39936, 28672, 768, 34816, 17408]
#
# Statue-2 has the best fitness value in 84 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47104, 21504, 2816, 5120, 86016, 28672, 5, 2048, 68608, 82944]
#
# Statue-4 has the best fitness value in 85 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [86016, 5376, 40, 11776, 1296, 20736, 45056, 21504, 91136, 28]
#
# Statue-8 has the best fitness value in 86 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [928, 512, 47104, 86016, 11264, 5376, 86016, 324, 5376, 82944]
#
# Statue-3 has the best fitness value in 87 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [86016, 320, 21504, 82944, 20480, 15, 18, 184, 11264, 11264]
#
# Statue-0 has the best fitness value in 88 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [45056, 2688, 38912, 176, 21504, 4608, 11, 4160, 82944, 6144]
#
# Statue-8 has the best fitness value in 89 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1088, 2048, 11, 40, 4608, 49, 38912, 82944, 1536, 6]
#
# Statue-7 has the best fitness value in 90 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 5, 20736, 608, 49, 70656, 512, 168, 82944, 1536]
#
# Statue-8 has the best fitness value in 91 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1536, 20736, 56, 82944, 82944, 82944, 1280, 4416, 8, 69]
#
# Statue-3 has the best fitness value in 92 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [276, 6144, 324, 6144, 1296, 384, 13312, 56, 88, 768]
#
# Statue-6 has the best fitness value in 93 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33792, 6, 768, 70656, 7168, 1296, 15360, 312, 1296, 6144]
#
# Statue-3 has the best fitness value in 94 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5184, 33, 82944, 96, 192, 5184, 70656, 6, 160, 1104]
#
# Statue-2 has the best fitness value in 95 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 1104, 69, 59392, 16, 33792, 1104, 1296, 2432, 1296]
#
# Statue-3 has the best fitness value in 96 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1360, 33792, 33792, 48, 1296, 1024, 2112, 1296, 152, 1104]
#
# Statue-1 has the best fitness value in 97 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [38912, 33792, 7680, 33792, 1104, 8448, 81, 192, 10240, 5440]
#
# Statue-0 has the best fitness value in 98 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4416, 7424, 67584, 79872, 1408, 2112, 2432, 3072, 2112, 5440]
#
# Statue-3 has the best fitness value in 99 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4416, 67584, 116, 48, 45056, 7936, 30720, 79872, 4416, 1792]
#
# Statue-7 has the best fitness value in 100 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 38912, 1248, 3072, 3072, 116, 79872, 49, 30720, 70656]
#
# Statue-6 has the best fitness value in 101 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [120, 69632, 3072, 78, 48, 832, 79872, 30, 2048, 24]
#
# Statue-6 has the best fitness value in 102 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [704, 8960, 4992, 30, 11264, 2048, 69632, 832, 80, 69632]
#
# Statue-6 has the best fitness value in 103 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [71680, 5120, 69632, 69632, 11264, 512, 69632, 4096, 68, 832]
#
# Statue-0 has the best fitness value in 104 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34816, 11264, 272, 5120, 9216, 5120, 7168, 10752, 1024, 69632]
#
# Statue-9 has the best fitness value in 105 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [68, 47104, 18688, 4352, 14336, 2688, 69632, 24576, 69632, 1984]
#
# Statue-6 has the best fitness value in 106 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 2496, 6144, 47104, 80896, 1024, 1536, 2944, 47104, 1168]
#
# Statue-4 has the best fitness value in 107 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13, 24, 79, 58368, 68608, 832, 41984, 384, 47104, 184]
#
# Statue-4 has the best fitness value in 108 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4, 3520, 68608, 79, 52, 79, 58368, 29696, 24576, 832]
#
# Statue-2 has the best fitness value in 109 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [912, 3520, 1856, 41984, 52, 1728, 3520, 19200, 34816, 2240]
#
# Statue-3 has the best fitness value in 110 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [512, 34816, 19200, 1200, 8704, 3520, 1728, 3072, 4288, 464]
#
# Statue-1 has the best fitness value in 111 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [75, 2048, 576, 220, 7, 4288, 8192, 8, 82944, 4288]
#
# Statue-8 has the best fitness value in 112 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8, 2048, 32768, 76800, 3008, 220, 320, 4288, 19200, 8192]
#
# Statue-3 has the best fitness value in 113 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [88, 7168, 320, 2176, 76800, 32768, 12288, 32768, 43, 19200]
#
# Statue-4 has the best fitness value in 114 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43, 64, 76800, 79872, 19200, 76800, 2, 76800, 75, 32768]
#
# Statue-3 has the best fitness value in 115 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 7168, 19200, 100, 75, 19968, 4, 19200, 28, 19200]
#
# Statue-5 has the best fitness value in 116 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 288, 112, 14848, 19200, 79872, 8448, 48, 82, 75]
#
# Statue-5 has the best fitness value in 117 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58, 21248, 12288, 288, 328, 79872, 79872, 768, 14848, 3840]
#
# Statue-5 has the best fitness value in 118 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4608, 960, 13312, 12288, 27648, 23552, 79872, 3712, 3968, 35840]
#
# Statue-6 has the best fitness value in 119 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [63488, 4096, 1024, 35840, 560, 1536, 480, 4992, 256, 13312]
#
# Statue-0 has the best fitness value in 120 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 560, 480, 448, 4096, 8192, 10240, 4032, 13312, 13312]
#
# Statue-0 has the best fitness value in 121 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3328, 16128, 5120, 35840, 1280, 1264, 6144, 20480, 13312, 53248]
#
# Statue-9 has the best fitness value in 122 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3328, 4800, 8, 22784, 1536, 15616, 20480, 16384, 576, 53248]
#
# Statue-9 has the best fitness value in 123 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 272, 300, 81920, 80, 256, 14848, 20480, 16384, 16384]
#
# Statue-3 has the best fitness value in 124 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [81920, 16, 320, 236, 80, 81920, 5184, 256, 36, 160]
#
# Statue-0 has the best fitness value in 125 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [704, 41984, 64512, 5184, 320, 74752, 832, 4, 37888, 1232]
#
# Statue-5 has the best fitness value in 126 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 14080, 37888, 21504, 20480, 20, 37888, 51200, 576, 13312]
#
# Statue-7 has the best fitness value in 127 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [576, 4352, 19, 11264, 296, 2304, 18176, 37, 51200, 33]
#
# Statue-8 has the best fitness value in 128 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4352, 64, 39936, 1024, 15, 51200, 720, 20, 10496, 4544]
#
# Statue-5 has the best fitness value in 129 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1536, 4544, 39, 12800, 200, 17408, 1856, 72704, 18432, 10496]
#
# Statue-7 has the best fitness value in 130 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 3072, 51200, 5120, 72704, 80, 72704, 10496, 4544, 35840]
#
# Statue-4 has the best fitness value in 131 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18176, 31744, 672, 4096, 296, 3072, 79, 71, 2048, 72704]
#
# Statue-9 has the best fitness value in 132 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [296, 53248, 72704, 35, 3328, 5120, 62464, 12, 84, 15360]
#
# Statue-2 has the best fitness value in 133 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2880, 62464, 21504, 72704, 72704, 53248, 14336, 13312, 62464, 1024]
#
# Statue-3 has the best fitness value in 134 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13312, 17408, 12288, 62464, 72704, 56, 7168, 62464, 90112, 7168]
#
# Statue-8 has the best fitness value in 135 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72704, 2, 62464, 1088, 17408, 272, 3072, 12288, 1344, 8192]
#
# Statue-0 has the best fitness value in 136 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 3904, 976, 62464, 8192, 58, 62464, 5376, 6144, 1024]
#
# Statue-3 has the best fitness value in 137 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2432, 3072, 23296, 62464, 11264, 62464, 196, 8, 39936, 12288]
#
# Statue-3 has the best fitness value in 138 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 14336, 256, 1024, 48128, 244, 3072, 5120, 20480, 62464]
#
# Statue-9 has the best fitness value in 139 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [192, 61, 48128, 61, 156, 20480, 3904, 36, 57344, 160]
#
# Statue-8 has the best fitness value in 140 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48128, 48128, 2496, 80, 20480, 192, 1280, 21504, 20, 704]
#
# Statue-0 has the best fitness value in 141 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 44, 55296, 1280, 188, 27648, 5120, 192, 81920, 48128]
#
# Statue-8 has the best fitness value in 142 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 44, 5120, 1024, 192, 48128, 192, 27648, 21504, 81920]
#
# Statue-9 has the best fitness value in 143 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [192, 432, 19968, 21504, 200, 14336, 16384, 1728, 4096, 27648]
#
# Statue-9 has the best fitness value in 144 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15104, 90112, 21504, 64, 13056, 1728, 62464, 432, 91136, 2560]
#
# Statue-8 has the best fitness value in 145 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 204, 976, 1344, 91136, 90112, 22528, 86016, 16384, 15104]
#
# Statue-4 has the best fitness value in 146 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22784, 90112, 56320, 16, 36864, 1408, 84, 52224, 25600, 4096]
#
# Statue-1 has the best fitness value in 147 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 5696, 768, 3264, 41, 25600, 55, 4736, 336, 1]
#
# Statue-5 has the best fitness value in 148 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4736, 55, 2560, 1280, 16, 544, 3520, 16, 4, 18432]
#
# Statue-9 has the best fitness value in 149 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [55, 28, 54272, 1152, 56320, 88, 144, 1280, 64, 4736]
#
# Statue-4 has the best fitness value in 150 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [212, 3392, 832, 3, 208, 46, 7168, 1024, 53, 88]
#
# Statue-6 has the best fitness value in 151 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [276, 140, 8, 32, 848, 2048, 512, 832, 212, 256]
#
# Statue-5 has the best fitness value in 152 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 32, 8, 256, 120, 15104, 1024, 6400, 64, 384]
#
# Statue-0 has the best fitness value in 153 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 384, 7168, 560, 256, 35840, 67584, 30720, 4, 1024]
#
# Statue-6 has the best fitness value in 154 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1920, 3072, 30720, 384, 35840, 33792, 560, 112, 1072, 19456]
#
# Statue-4 has the best fitness value in 155 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33792, 2048, 7680, 3072, 30720, 5120, 1536, 30720, 1920, 8192]
#
# Statue-0 has the best fitness value in 156 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 38, 30720, 32, 120, 8192, 30720, 4352, 256, 3072]
#
# Statue-2 has the best fitness value in 157 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30720, 4, 30720, 30720, 512, 55296, 69, 4352, 9472, 17408]
#
# Statue-5 has the best fitness value in 158 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [480, 1920, 480, 120, 30720, 35840, 0, 55296, 55296, 11264]
#
# Statue-7 has the best fitness value in 159 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19, 3456, 71, 35840, 640, 57, 448, 24, 28, 43008]
#
# Statue-9 has the best fitness value in 160 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 35, 3200, 75, 19, 28, 10752, 28, 42, 640]
#
# Statue-6 has the best fitness value in 161 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 75, 2688, 13312, 4608, 50, 316, 640, 2496, 448]
#
# Statue-3 has the best fitness value in 162 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2496, 8, 288, 720, 2176, 112, 208, 16384, 3968, 2048]
#
# Statue-7 has the best fitness value in 163 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 3968, 3072, 16384, 128, 64512, 1520, 1072, 1152, 16384]
#
# Statue-5 has the best fitness value in 164 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [624, 16384, 64, 10240, 1520, 64512, 576, 64512, 4096, 192]
#
# Statue-5 has the best fitness value in 165 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 32, 192, 64512, 58368, 64, 148, 448, 16384, 160]
#
# Statue-3 has the best fitness value in 166 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [672, 43008, 4032, 1472, 16, 16384, 112, 256, 20480, 90]
#
# Statue-1 has the best fitness value in 167 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 1, 1376, 42, 28, 43008, 20480, 43008, 16384, 3072]
#
# Statue-0 has the best fitness value in 168 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [832, 27, 20480, 84992, 208, 20480, 43008, 10752, 5120, 2048]
#
# Statue-3 has the best fitness value in 169 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1216, 1280, 24576, 20480, 1024, 5120, 20480, 1536, 1024, 1920]
#
# Statue-2 has the best fitness value in 170 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 78848, 7680, 420, 128, 384, 400, 63488, 24576, 20480]
#
# Statue-1 has the best fitness value in 171 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [400, 6144, 13, 14592, 24576, 78848, 17408, 71680, 1408, 248]
#
# Statue-5 has the best fitness value in 172 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 17408, 17408, 13312, 6144, 71680, 288, 37888, 1792, 59392]
#
# Statue-5 has the best fitness value in 173 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 128, 43008, 43008, 13, 17408, 2048, 22528, 24576, 17408]
#
# Statue-2 has the best fitness value in 174 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [168, 53, 43008, 91136, 4096, 1408, 4608, 2688, 64, 31744]
#
# Statue-3 has the best fitness value in 175 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 5312, 1408, 61440, 4608, 89, 31744, 42, 10752, 4096]
#
# Statue-3 has the best fitness value in 176 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49152, 61440, 256, 61440, 240, 1984, 4608, 40, 31744, 37]
#
# Statue-1 has the best fitness value in 177 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31, 256, 240, 3072, 2816, 31744, 31744, 49152, 61440, 61440]
#
# Statue-8 has the best fitness value in 178 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [240, 61440, 704, 53248, 2816, 31, 48, 276, 61440, 176]
#
# Statue-1 has the best fitness value in 179 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [832, 240, 384, 15872, 53248, 11264, 480, 332, 13312, 69]
#
# Statue-4 has the best fitness value in 180 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [896, 3968, 63488, 3328, 1408, 6400, 96, 59392, 12544, 16384]
#
# Statue-2 has the best fitness value in 181 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12544, 1536, 192, 59392, 16384, 3968, 4352, 1440, 15872, 19]
#
# Statue-3 has the best fitness value in 182 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [55296, 3712, 4352, 10752, 80, 16384, 4352, 4352, 512, 61]
#
# Statue-0 has the best fitness value in 183 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 16384, 8192, 4352, 10752, 296, 16640, 168, 25, 14]
#
# Statue-0 has the best fitness value in 184 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 128, 16, 65, 3072, 22784, 296, 16, 43008, 2048]
#
# Statue-8 has the best fitness value in 185 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16, 4096, 512, 7680, 356, 18176, 4352, 63488, 368, 60416]
#
# Statue-7 has the best fitness value in 186 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18176, 992, 284, 18176, 7424, 14848, 2112, 24576, 4, 120]
#
# Statue-7 has the best fitness value in 187 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7424, 58, 6144, 59392, 18176, 58, 372, 2048, 18, 6144]
#
# Statue-3 has the best fitness value in 188 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [704, 6144, 72704, 6144, 6144, 48, 21504, 1, 59392, 6144]
#
# Statue-2 has the best fitness value in 189 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73728, 53248, 6144, 3648, 21504, 17920, 96, 6144, 23552, 592]
#
# Statue-0 has the best fitness value in 190 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [27648, 832, 26624, 1536, 5120, 33792, 72, 57344, 53248, 73728]
#
# Statue-9 has the best fitness value in 191 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3584, 28, 33792, 18432, 73728, 57344, 268, 53248, 5120, 8448]
#
# Statue-4 has the best fitness value in 192 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73728, 33792, 38912, 73728, 53248, 8448, 57344, 18432, 14336, 57344]
#
# Statue-0 has the best fitness value in 193 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [57344, 100, 288, 2048, 53248, 116, 13312, 18432, 4608, 53248]
#
# Statue-0 has the best fitness value in 194 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [208, 116, 192, 73728, 74752, 52, 72, 2048, 4608, 832]
#
# Statue-4 has the best fitness value in 195 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73, 18432, 74752, 576, 2624, 9216, 2048, 4608, 18432, 5120]
#
# Statue-2 has the best fitness value in 196 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19968, 21504, 5120, 2048, 4096, 18432, 4608, 2624, 72, 7168]
#
# Statue-1 has the best fitness value in 197 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1280, 18432, 2, 288, 1152, 512, 5376, 16, 512, 19968]
#
# Statue-9 has the best fitness value in 198 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 96, 132, 608, 5184, 18, 19968, 22272, 3072, 18432]
#
# Statue-7 has the best fitness value in 199 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [144, 256, 5376, 21504, 4, 78, 73728, 12288, 1344, 1280]
#
# Statue-6 has the best fitness value in 200 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 21504, 5376, 18432, 384, 1792, 1280, 9216, 21504, 5696]
#
# Statue-1 has the best fitness value in 201 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [192, 5696, 18432, 1600, 17408, 5696, 1280, 15360, 5376, 5120]
#
# Statue-2 has the best fitness value in 202 generation.
# ------------------------------------------------------------------------------------------------------------------------
# ...
# [7936, 51200, 800, 18432, 1456, 46080, 4800, 64512, 1280, 1200]
#
# Statue-7 has the best fitness value in 4933 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46080, 18432, 3072, 24576, 12288, 72, 64512, 18432, 22528, 51200]
#
# Statue-6 has the best fitness value in 4934 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72, 448, 4096, 288, 51200, 13312, 384, 84992, 46080, 46080]
#
# Statue-7 has the best fitness value in 4935 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [84992, 28672, 68608, 2816, 83, 51200, 208, 180, 4096, 800]
#
# Statue-0 has the best fitness value in 4936 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1328, 84992, 1024, 62, 84992, 144, 15360, 45, 50, 2112]
#
# Statue-1 has the best fitness value in 4937 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1344, 960, 3328, 5312, 15872, 4, 256, 20, 1472, 46]
#
# Statue-4 has the best fitness value in 4938 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2, 28, 72, 56, 736, 336, 1040, 14080, 15872, 1728]
#
# Statue-8 has the best fitness value in 4939 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [512, 704, 992, 256, 3, 11776, 2560, 7680, 3712, 4096]
#
# Statue-5 has the best fitness value in 4940 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58, 256, 1536, 11776, 57, 2, 992, 18688, 83968, 992]
#
# Statue-8 has the best fitness value in 4941 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [44, 11776, 74752, 32, 256, 992, 64512, 3840, 224, 784]
#
# Statue-2 has the best fitness value in 4942 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46, 64512, 19456, 74752, 44, 5120, 2816, 21760, 784, 992]
#
# Statue-3 has the best fitness value in 4943 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30, 3072, 4096, 19456, 19456, 64512, 1360, 19, 64512, 5120]
#
# Statue-5 has the best fitness value in 4944 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 45056, 5120, 28, 64512, 16, 64512, 16, 19456, 76800]
#
# Statue-9 has the best fitness value in 4945 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 1200, 45056, 116, 69632, 704, 53248, 91136, 28, 64512]
#
# Statue-7 has the best fitness value in 4946 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 6144, 10240, 45056, 45056, 64512, 37888, 28672, 45056, 64512]
#
# Statue-5 has the best fitness value in 4947 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48128, 45056, 54272, 21504, 67584, 45056, 160, 19456, 64512, 53248]
#
# Statue-4 has the best fitness value in 4948 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [66, 56320, 64512, 1520, 13312, 704, 80896, 53248, 2048, 12032]
#
# Statue-6 has the best fitness value in 4949 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80896, 12032, 64512, 24, 4032, 50, 55, 79, 2624, 56320]
#
# Statue-0 has the best fitness value in 4950 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [800, 79, 2624, 55, 4096, 5056, 11264, 14, 104, 4032]
#
# Statue-6 has the best fitness value in 4951 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [26, 316, 25600, 304, 208, 5056, 176, 160, 1264, 17408]
#
# Statue-2 has the best fitness value in 4952 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [232, 5056, 448, 832, 17408, 17408, 17408, 20224, 5056, 2688]
#
# Statue-7 has the best fitness value in 4953 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [39936, 14, 224, 136, 17408, 2112, 2048, 3, 15360, 13056]
#
# Statue-0 has the best fitness value in 4954 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [528, 4608, 108, 33, 640, 13056, 32, 24576, 224, 69632]
#
# Statue-9 has the best fitness value in 4955 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15360, 12288, 24576, 33, 1536, 85, 29696, 184, 8448, 224]
#
# Statue-6 has the best fitness value in 4956 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 9, 15360, 2048, 5504, 8, 24, 25600, 39936, 64]
#
# Statue-8 has the best fitness value in 4957 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5760, 332, 1600, 88064, 5504, 15360, 48, 15360, 96, 784]
#
# Statue-3 has the best fitness value in 4958 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15360, 44032, 1600, 39936, 15360, 15360, 88064, 304, 46080, 88064]
#
# Statue-6 has the best fitness value in 4959 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176, 46080, 37, 64, 1136, 22016, 2048, 39936, 304, 13824]
#
# Statue-1 has the best fitness value in 4960 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [784, 46080, 7, 2816, 15, 448, 30, 46080, 2496, 864]
#
# Statue-1 has the best fitness value in 4961 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46080, 59392, 7, 30720, 784, 46080, 2496, 44, 46080, 93184]
#
# Statue-9 has the best fitness value in 4962 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1424, 59392, 656, 8192, 4352, 46080, 22528, 46080, 400, 4096]
#
# Statue-1 has the best fitness value in 4963 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46080, 5632, 928, 58, 124, 232, 11264, 288, 22528, 13]
#
# Statue-0 has the best fitness value in 4964 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7168, 47104, 83968, 58, 10496, 22528, 11264, 3008, 46080, 336]
#
# Statue-2 has the best fitness value in 4965 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [82, 47104, 22528, 1312, 2496, 20992, 46080, 69, 2048, 15360]
#
# Statue-1 has the best fitness value in 4966 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [83968, 1376, 23552, 2944, 46080, 10240, 22, 30720, 62464, 33]
#
# Statue-0 has the best fitness value in 4967 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [62464, 33792, 23552, 66560, 62464, 31744, 23552, 30720, 192, 4096]
#
# Statue-3 has the best fitness value in 4968 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [61440, 2048, 28672, 34816, 3072, 15616, 11264, 528, 62464, 31744]
#
# Statue-8 has the best fitness value in 4969 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 112, 544, 31744, 28672, 4992, 3840, 768, 9216, 10240]
#
# Statue-0 has the best fitness value in 4970 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 31744, 31, 74752, 128, 31744, 3840, 9216, 28672, 31744]
#
# Statue-3 has the best fitness value in 4971 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 31744, 2112, 86016, 28672, 18688, 74752, 256, 43008, 18176]
#
# Statue-3 has the best fitness value in 4972 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1168, 74752, 43008, 512, 528, 0, 18176, 31, 43008, 22]
#
# Statue-1 has the best fitness value in 4973 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [528, 256, 1168, 2112, 18688, 84992, 1200, 292, 72704, 10240]
#
# Statue-5 has the best fitness value in 4974 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1136, 72704, 1136, 75, 3520, 512, 3136, 480, 2112, 256]
#
# Statue-1 has the best fitness value in 4975 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2816, 2048, 768, 59392, 18176, 1136, 352, 10240, 2304, 22]
#
# Statue-3 has the best fitness value in 4976 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4544, 5120, 9472, 928, 4992, 1024, 20480, 64, 1136, 448]
#
# Statue-6 has the best fitness value in 4977 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4992, 184, 20, 928, 768, 56320, 19456, 1600, 4, 31744]
#
# Statue-5 has the best fitness value in 4978 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 56320, 19456, 232, 4992, 232, 928, 124, 5, 976]
#
# Statue-1 has the best fitness value in 4979 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5184, 4992, 1280, 56320, 37, 3904, 19456, 432, 56320, 784]
#
# Statue-3 has the best fitness value in 4980 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [82, 2048, 2816, 56320, 5952, 5120, 19456, 384, 832, 220]
#
# Statue-3 has the best fitness value in 4981 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19456, 56320, 5952, 19456, 256, 72, 880, 2432, 5952, 704]
#
# Statue-1 has the best fitness value in 4982 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 19, 176, 3648, 1792, 4864, 3520, 112, 1280, 5952]
#
# Statue-0 has the best fitness value in 4983 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [896, 256, 5952, 24, 176, 304, 880, 1488, 64, 95232]
#
# Statue-9 has the best fitness value in 4984 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [372, 1216, 1488, 880, 31744, 64, 5952, 224, 1488, 560]
#
# Statue-4 has the best fitness value in 4985 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1488, 1488, 64512, 1280, 512, 64, 56320, 79872, 768, 93]
#
# Statue-7 has the best fitness value in 4986 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 4992, 79872, 55, 44, 19968, 2048, 736, 88, 93]
#
# Statue-2 has the best fitness value in 4987 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 13312, 35840, 17408, 3072, 2048, 2048, 93, 56320, 4]
#
# Statue-8 has the best fitness value in 4988 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [85, 140, 288, 56320, 9216, 17408, 10240, 11264, 272, 37888]
#
# Statue-3 has the best fitness value in 4989 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1360, 23, 160, 18432, 83968, 56320, 92160, 0, 37888, 17408]
#
# Statue-6 has the best fitness value in 4990 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 4352, 1104, 56320, 4096, 3072, 2368, 68, 0, 5120]
#
# Statue-3 has the best fitness value in 4991 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 320, 94208, 19712, 51200, 14080, 256, 4096, 5, 268]
#
# Statue-2 has the best fitness value in 4992 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64, 76800, 23552, 56320, 220, 24832, 268, 1024, 21504, 1152]
#
# Statue-1 has the best fitness value in 4993 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4608, 192, 21504, 1408, 80, 4416, 4096, 59, 23552, 56320]
#
# Statue-9 has the best fitness value in 4994 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 1472, 56320, 36, 90112, 56320, 4352, 21504, 23552, 64]
#
# Statue-4 has the best fitness value in 4995 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 5120, 88, 0, 576, 16, 21504, 35840, 5632, 60416]
#
# Statue-9 has the best fitness value in 4996 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22528, 5120, 14336, 5632, 8192, 5120, 320, 21, 1232, 21504]
#
# Statue-0 has the best fitness value in 4997 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51200, 14, 9, 512, 960, 768, 10496, 832, 34, 21504]
#
# Statue-0 has the best fitness value in 4998 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21504, 640, 200, 5632, 384, 70, 384, 11264, 34, 6400]
#
# Statue-0 has the best fitness value in 4999 generation.
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 14.1 s

# %%
print(len(ALL_FITNESS))
# Out:
# 5001

# %%
len(PARAMS)
# Out:
# 5001

# %%
C=PARAMS[0][3]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.23137254901960785, 0.34901960784313724, 0.35294117647058826, 211)'

# %%
print(FACES)
# Out:
# [(1, 3, 7, 8), (0, 1, 4, 5), (4, 0, 1, 3, 7), (3, 0, 1, 6, 7), (3, 0, 1, 4, 6), (0, 1, 4, 5, 7, 8), (2, 1, 3, 4, 5, 6, 8), (1, 0, 2, 3, 5, 6, 7, 8), (0, 2, 3), (0, 3, 4, 5, 6, 7, 8), (1, 0, 2, 3, 4, 5, 6, 7), (1, 0, 2, 6, 7, 8), (4, 3, 5, 7, 8), (0, 1, 5, 8), (2, 0, 1, 6, 7, 8), (2, 0, 1, 3, 4, 7), (1, 4, 5, 6, 8)]

# %%
print(VERTS)
# Out:
# [[0.08669373441687944, 8.652540776714112, 1.462318294421391], [3.7990270957016623, 1.1006707156352735, 5.745581002589876], [3.366735099015826, 1.98278830037405, 1.9527425758410961], [3.8203729144420313, 7.122190195977204, 3.0109038651887747], [5.699347132215658, 7.552186516683364, 6.535916074126287], [5.341757607425777, 8.282854434262894, 3.7161189804588486], [5.700863634313309, 4.762971655569652, 1.9702565128357254], [0.6715894815405759, 3.7234475284805795, 4.214667270098999], [2.6045991822718784, 7.303156413357373, 4.0169764120157145]]

# %%
RO
# Out:
# 4

# %%
with open(f'E:\\Research\\Statue Generator\\OUTPUT_7.txt', 'w') as f:
        f.writelines(str(PARAMS))
