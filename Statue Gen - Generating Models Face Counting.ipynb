# %%
import random
import os
import sys

# %%
from CGen import *
from EA_MC import *

# %%
import subprocess
BLENDER_PATH="C:\\Program Files\\Blender Foundation\\Blender 3.3\\blender.exe"

# %%
OUTPUT_PATH="E:\\Research\\Statue Generator\\Generations"

# %% [markdown]
# ## Basic Parameters for generation

# %%
L,B,H=6,7,9
POPULATION_SIZE=10

# %%
PARAMS=[]

# %% [markdown]
# ## Initial Population

# %%
# %%time

INITIAL_POPULATION=[]

for _ in range(POPULATION_SIZE):
    CH=generate_chromosome(L,B,H,random.random())
    INITIAL_POPULATION.append(CH)
    get_stats(CH)
    print('-'*125)

PARAMS.append(INITIAL_POPULATION)
# Out:
# (R,G,B,A) = (84,144,103,69)
# Roughness Factor = 2
# Number of vertices = 8
# Number of faces = 15
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (173,166,111,45)
# Roughness Factor = 1
# Number of vertices = 13
# Number of faces = 42
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (34,80,25,146)
# Roughness Factor = 1
# Number of vertices = 5
# Number of faces = 4
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (109,167,77,204)
# Roughness Factor = 5
# Number of vertices = 9
# Number of faces = 17
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (163,51,232,251)
# Roughness Factor = 5
# Number of vertices = 13
# Number of faces = 38
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (38,99,100,111)
# Roughness Factor = 2
# Number of vertices = 5
# Number of faces = 3
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (250,35,217,112)
# Roughness Factor = 4
# Number of vertices = 18
# Number of faces = 83
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (172,88,69,146)
# Roughness Factor = 1
# Number of vertices = 13
# Number of faces = 30
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (203,222,148,0)
# Roughness Factor = 3
# Number of vertices = 15
# Number of faces = 51
# -----------------------------------------------------------------------------------------------------------------------------
# (R,G,B,A) = (40,81,48,245)
# Roughness Factor = 5
# Number of vertices = 5
# Number of faces = 3
# -----------------------------------------------------------------------------------------------------------------------------
# Wall time: 8 ms

# %%
ALL_FITNESS=[]
BEST_FITNESS=[]

# %%
# %%time
fitness_0=[]
for i,C in enumerate(PARAMS[0]):

    COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
    VERTS=C[5][0]
    FACES=C[5][1]
    RO=C[4]
    FILE_NUM=str(i)
    fitness_0.append(face_count(FACES,RO))

ALL_FITNESS.append(fitness_0)
BEST_FITNESS.append(max(fitness_0))
# Out:
# Wall time: 0 ns

# %%
ALL_FITNESS
# Out:
# [[240, 168, 16, 17408, 38912, 48, 21248, 120, 3264, 3072]]

# %%
BEST_FITNESS
# Out:
# [38912]

# %% [markdown]
# ## Crossover and Mutation for more generations

# %%
GENERATIONS=5000

# %%
# %%time

GEN_NUM=1

for _ in range(GENERATIONS):
    
    FITNESS=[]
    FITNESS=[face_count(model[5][1],model[4]) for model in PARAMS[GEN_NUM-1]]
    print(FITNESS)
    ALL_FITNESS.append(FITNESS)
    
    BEST_FITNESS.append(FITNESS.index(max(FITNESS)))
    print(f'\nStatue-{FITNESS.index(max(FITNESS))} has the best fitness value in {GEN_NUM-1} generation.')
    
    print("-"*120)
    
    MODELS=[]
    
    for _ in range(int(POPULATION_SIZE/2)):
    
        #selecting 2 random parents from previous generation
        idx1,idx2=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p1=idx1 if FITNESS[idx1]>FITNESS[idx2] else idx2
        
        idx3,idx4=random.randint(0,POPULATION_SIZE-1),random.randint(0,POPULATION_SIZE-1)
        p2=idx3 if FITNESS[idx3]>FITNESS[idx4] else idx4
        
        #perform crossover for the selected parents
        c1,c2=crossover(PARAMS[GEN_NUM-1][p1],PARAMS[GEN_NUM-1][p2])
        
        #mutate the children after crossover
        m1=mutate(c1,L,B,H)
        m2=mutate(c2,L,B,H)
        
        MODELS.append(m1)
        MODELS.append(m2)
        
    #print(len(MODELS))
    #appending the mutated childs to PARAMS array
    PARAMS.append(MODELS)
    
    
    
    GEN_NUM+=1
# Out:
# [240, 168, 16, 17408, 38912, 48, 21248, 120, 3264, 3072]
#
# Statue-4 has the best fitness value in 0 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [232, 2048, 22528, 4352, 83, 6144, 9728, 192, 1328, 0]
#
# Statue-2 has the best fitness value in 1 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [54, 76800, 2432, 1280, 52224, 19456, 9728, 608, 73728, 2752]
#
# Statue-1 has the best fitness value in 2 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9728, 9728, 544, 38, 76800, 19456, 26624, 54272, 1216, 76800]
#
# Statue-4 has the best fitness value in 3 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19456, 45056, 54272, 60416, 54272, 54272, 19456, 76800, 76800, 19456]
#
# Statue-7 has the best fitness value in 4 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14080, 45056, 5120, 54272, 71680, 60416, 67584, 54272, 38, 128]
#
# Statue-4 has the best fitness value in 5 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [848, 76, 128, 2048, 22272, 73728, 0, 67584, 1120, 5120]
#
# Statue-5 has the best fitness value in 6 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5120, 5120, 5120, 17408, 89088, 0, 19200, 46080, 13312, 48128]
#
# Statue-4 has the best fitness value in 7 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [41, 1088, 48128, 48128, 48128, 92160, 48128, 23552, 89088, 47104]
#
# Statue-5 has the best fitness value in 8 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23, 49152, 92160, 60416, 0, 49152, 328, 48128, 89088, 47]
#
# Statue-2 has the best fitness value in 9 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23552, 13, 1312, 90, 4096, 7168, 328, 89088, 48128, 0]
#
# Statue-7 has the best fitness value in 10 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 0, 124, 0, 176, 67584, 4096, 5, 0, 1664]
#
# Statue-5 has the best fitness value in 11 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51200, 256, 4352, 67584, 1152, 96256, 40, 67584, 0, 156]
#
# Statue-5 has the best fitness value in 12 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [96256, 200, 160, 1152, 23552, 7168, 1152, 10, 4224, 66]
#
# Statue-0 has the best fitness value in 13 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 23552, 23552, 1152, 12, 96256, 4224, 40960, 18432, 2]
#
# Statue-5 has the best fitness value in 14 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 30720, 2048, 2304, 23, 4352, 1, 36, 1024, 23552]
#
# Statue-1 has the best fitness value in 15 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 77, 5888, 48128, 38912, 16128, 88064, 30720, 44, 49152]
#
# Statue-6 has the best fitness value in 16 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 208, 77, 30720, 17408, 88064, 88064, 95232, 88064, 3072]
#
# Statue-7 has the best fitness value in 17 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [77, 224, 2048, 64, 11264, 3072, 144, 88064, 22016, 57344]
#
# Statue-7 has the best fitness value in 18 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80, 26624, 344, 11264, 22016, 33792, 848, 336, 49152, 2944]
#
# Statue-8 has the best fitness value in 19 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32768, 41, 132, 48128, 13, 22016, 2944, 192, 224, 212]
#
# Statue-3 has the best fitness value in 20 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48128, 1856, 57344, 16, 224, 41, 35, 784, 8192, 512]
#
# Statue-2 has the best fitness value in 21 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [90, 1856, 8192, 512, 156, 3008, 384, 188, 10752, 832]
#
# Statue-8 has the best fitness value in 22 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 23040, 2688, 3008, 8192, 832, 5376, 156, 1, 384]
#
# Statue-1 has the best fitness value in 23 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [43008, 320, 8192, 17152, 3008, 192, 21504, 2048, 8, 2048]
#
# Statue-0 has the best fitness value in 24 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40960, 8192, 512, 128, 47, 74752, 43008, 384, 67, 8192]
#
# Statue-5 has the best fitness value in 25 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5056, 57344, 64, 1536, 512, 672, 1280, 5888, 43008, 5632]
#
# Statue-1 has the best fitness value in 26 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5632, 1536, 2688, 22528, 1792, 77824, 10752, 57, 640, 72704]
#
# Statue-5 has the best fitness value in 27 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1408, 672, 1, 19456, 1792, 960, 14, 22528, 1792, 6144]
#
# Statue-7 has the best fitness value in 28 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22528, 53, 56, 1792, 960, 304, 7, 19456, 1408, 400]
#
# Statue-0 has the best fitness value in 29 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 864, 640, 0, 1088, 448, 960, 256, 22528, 108]
#
# Statue-8 has the best fitness value in 30 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4672, 1600, 992, 1024, 236, 672, 240, 3392, 22528, 27]
#
# Statue-8 has the best fitness value in 31 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22, 368, 992, 240, 128, 260, 22528, 1600, 3392, 0]
#
# Statue-6 has the best fitness value in 32 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [384, 3264, 848, 960, 2304, 100, 992, 0, 1040, 368]
#
# Statue-1 has the best fitness value in 33 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2304, 15360, 5376, 816, 368, 152, 1040, 2048, 32, 9216]
#
# Statue-1 has the best fitness value in 34 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 768, 4864, 14336, 152, 23552, 52224, 92, 5888, 6656]
#
# Statue-6 has the best fitness value in 35 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6656, 56, 0, 52224, 204, 188, 416, 19456, 816, 8192]
#
# Statue-3 has the best fitness value in 36 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1344, 416, 52224, 56, 26, 816, 1024, 768, 816, 24576]
#
# Statue-2 has the best fitness value in 37 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 28, 13056, 19456, 6144, 52224, 12, 52224, 320, 1344]
#
# Statue-5 has the best fitness value in 38 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 13056, 4864, 16384, 5120, 912, 52224, 976, 21504, 5632]
#
# Statue-6 has the best fitness value in 39 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13056, 5376, 4096, 52224, 62464, 21504, 0, 13056, 256, 0]
#
# Statue-4 has the best fitness value in 40 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13056, 3584, 62464, 52224, 30720, 61, 256, 5888, 9728, 17408]
#
# Statue-2 has the best fitness value in 41 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [864, 9728, 51, 80, 0, 80, 9728, 5888, 12, 4864]
#
# Statue-1 has the best fitness value in 42 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [152, 2304, 9216, 4864, 51, 5632, 80, 0, 3456, 1280]
#
# Statue-2 has the best fitness value in 43 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4864, 152, 6, 3264, 320, 5632, 5632, 152, 4864, 57344]
#
# Statue-9 has the best fitness value in 44 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [5632, 1216, 5632, 5632, 152, 5632, 0, 320, 1088, 50176]
#
# Statue-9 has the best fitness value in 45 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1344, 0, 3136, 152, 74752, 5632, 352, 320, 320, 69632]
#
# Statue-4 has the best fitness value in 46 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [74752, 0, 14336, 4288, 2048, 7168, 38, 60, 1792, 32]
#
# Statue-0 has the best fitness value in 47 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [74752, 14336, 37888, 26, 4288, 128, 34816, 304, 112, 2304]
#
# Statue-0 has the best fitness value in 48 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 86, 256, 34816, 96, 0, 37888, 58368, 112, 59392]
#
# Statue-9 has the best fitness value in 49 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [26, 0, 79872, 66560, 34, 59392, 256, 1024, 0, 704]
#
# Statue-2 has the best fitness value in 50 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4608, 704, 0, 59392, 44, 79872, 11264, 30, 36864, 2624]
#
# Statue-5 has the best fitness value in 51 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [78, 14848, 73728, 4992, 58, 79872, 96, 79872, 46080, 52224]
#
# Statue-5 has the best fitness value in 52 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 312, 4, 89088, 78, 52224, 1376, 79872, 976, 204]
#
# Statue-3 has the best fitness value in 53 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1280, 104, 52224, 52224, 64, 34816, 7168, 79872, 1376, 384]
#
# Statue-7 has the best fitness value in 54 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7168, 7, 1440, 336, 30720, 13, 13056, 512, 52224, 3072]
#
# Statue-8 has the best fitness value in 55 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4928, 39936, 51, 11264, 30720, 6656, 120, 0, 5376, 512]
#
# Statue-1 has the best fitness value in 56 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [30, 1280, 84, 3264, 480, 11264, 11776, 47104, 1728, 4608]
#
# Statue-7 has the best fitness value in 57 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11776, 4608, 92, 960, 4608, 288, 1280, 11776, 4608, 1280]
#
# Statue-0 has the best fitness value in 58 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 960, 320, 1536, 47104, 11776, 2880, 10496, 1280, 4608]
#
# Statue-4 has the best fitness value in 59 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47104, 2752, 960, 15872, 37888, 37888, 14848, 148, 2048, 2944]
#
# Statue-0 has the best fitness value in 60 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1792, 37888, 148, 47104, 1152, 43, 31, 15872, 37888, 0]
#
# Statue-3 has the best fitness value in 61 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2368, 36864, 10240, 37888, 14848, 208, 12288, 19712, 2944, 37888]
#
# Statue-3 has the best fitness value in 62 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 37888, 2048, 15360, 4864, 2816, 9472, 78848, 37888, 640]
#
# Statue-7 has the best fitness value in 63 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12288, 308, 0, 13824, 37888, 15360, 5120, 37888, 68, 1120]
#
# Statue-4 has the best fitness value in 64 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 12288, 15360, 17664, 7936, 2048, 12288, 14080, 9472, 320]
#
# Statue-0 has the best fitness value in 65 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 55, 14080, 56320, 2816, 7936, 76800, 3968, 4608, 37888]
#
# Statue-6 has the best fitness value in 66 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4800, 3968, 1536, 55, 192, 56320, 55, 3520, 56320, 76800]
#
# Statue-9 has the best fitness value in 67 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [960, 90112, 1984, 79872, 19200, 1792, 228, 56320, 3968, 24576]
#
# Statue-1 has the best fitness value in 68 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1408, 24576, 76800, 90112, 308, 1536, 144, 39936, 128, 75]
#
# Statue-3 has the best fitness value in 69 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [352, 39936, 1200, 1200, 320, 352, 9216, 73, 156, 50176]
#
# Statue-9 has the best fitness value in 70 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [60, 1792, 9216, 50176, 50176, 76800, 156, 1408, 80, 196]
#
# Statue-5 has the best fitness value in 71 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 50176, 768, 9216, 48, 800, 50176, 4800, 36, 5120]
#
# Statue-1 has the best fitness value in 72 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [196, 4800, 50176, 50176, 84992, 50176, 0, 7168, 832, 4800]
#
# Statue-4 has the best fitness value in 73 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [76800, 168, 19, 12544, 4800, 30720, 50176, 768, 0, 50176]
#
# Statue-0 has the best fitness value in 74 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19, 7680, 23, 1024, 30720, 43, 768, 50176, 120, 43008]
#
# Statue-7 has the best fitness value in 75 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49152, 7680, 43, 14, 1472, 50176, 75776, 1024, 38, 19968]
#
# Statue-6 has the best fitness value in 76 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [74, 7168, 4, 3072, 1024, 49152, 50176, 75776, 3072, 30720]
#
# Statue-7 has the best fitness value in 77 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [50176, 54, 512, 52, 16640, 83968, 20480, 896, 4, 1472]
#
# Statue-5 has the best fitness value in 78 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [83968, 64512, 1312, 3328, 50176, 0, 1008, 21504, 5248, 6144]
#
# Statue-0 has the best fitness value in 79 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [88064, 22528, 304, 22528, 98304, 2176, 21504, 192, 1312, 1312]
#
# Statue-4 has the best fitness value in 80 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [992, 256, 88064, 2176, 15360, 27648, 1312, 15360, 22016, 64]
#
# Statue-2 has the best fitness value in 81 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [172, 512, 688, 1376, 3840, 1312, 88064, 3584, 15360, 108]
#
# Statue-6 has the best fitness value in 82 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13056, 1232, 88064, 15360, 448, 140, 88064, 4096, 2048, 1312]
#
# Statue-2 has the best fitness value in 83 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47104, 3584, 108, 4, 0, 52224, 1232, 8, 52224, 5888]
#
# Statue-5 has the best fitness value in 84 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [58368, 36864, 720, 13056, 15360, 2, 15360, 1728, 52224, 51]
#
# Statue-0 has the best fitness value in 85 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [248, 0, 23552, 2816, 14592, 14336, 204, 31744, 32, 816]
#
# Statue-7 has the best fitness value in 86 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 31744, 42, 2560, 112, 204, 1472, 69632, 13312, 3]
#
# Statue-7 has the best fitness value in 87 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2560, 112, 10240, 2560, 69632, 33792, 1536, 204, 31, 64512]
#
# Statue-4 has the best fitness value in 88 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [81920, 10240, 4352, 5696, 74752, 96, 8, 59, 53248, 2304]
#
# Statue-0 has the best fitness value in 89 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [356, 18688, 22784, 80, 53248, 4352, 3072, 61440, 3776, 2112]
#
# Statue-7 has the best fitness value in 90 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 832, 8192, 17408, 2048, 62464, 28672, 18688, 5696, 4352]
#
# Statue-5 has the best fitness value in 91 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [384, 15360, 28672, 512, 7168, 2048, 28672, 64, 62464, 18688]
#
# Statue-8 has the best fitness value in 92 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6144, 1792, 7168, 28672, 30720, 90, 256, 448, 7168, 18688]
#
# Statue-4 has the best fitness value in 93 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8704, 1536, 112, 48128, 112, 20480, 7168, 30720, 30720, 30720]
#
# Statue-3 has the best fitness value in 94 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [752, 2688, 15360, 90112, 96, 8704, 20480, 184, 91136, 3840]
#
# Statue-8 has the best fitness value in 95 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2688, 2688, 91136, 5248, 19968, 1408, 1152, 1536, 192, 75776]
#
# Statue-2 has the best fitness value in 96 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2688, 5248, 4096, 22528, 128, 1536, 2048, 168, 1408, 5248]
#
# Statue-3 has the best fitness value in 97 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2, 256, 4416, 5248, 83968, 83968, 5248, 83968, 1536, 128]
#
# Statue-4 has the best fitness value in 98 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [81920, 640, 61440, 4352, 83968, 328, 256, 4416, 4416, 83968]
#
# Statue-4 has the best fitness value in 99 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65, 15360, 81920, 43008, 328, 1792, 69, 320, 23808, 2560]
#
# Statue-2 has the best fitness value in 100 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 372, 10496, 23808, 128, 9216, 1856, 0, 2048, 80]
#
# Statue-3 has the best fitness value in 101 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [656, 20992, 0, 176, 10496, 13056, 3072, 60, 18944, 5952]
#
# Statue-1 has the best fitness value in 102 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10496, 10240, 928, 256, 432, 93, 2624, 6080, 1168, 10496]
#
# Statue-0 has the best fitness value in 103 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [78, 10496, 10496, 352, 18432, 10496, 40960, 2560, 10240, 34816]
#
# Statue-6 has the best fitness value in 104 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34816, 33792, 18432, 12288, 1024, 0, 29, 10496, 34816, 10240]
#
# Statue-0 has the best fitness value in 105 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2432, 12288, 12288, 10, 4608, 6144, 46080, 48, 30, 3072]
#
# Statue-6 has the best fitness value in 106 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13312, 192, 4608, 83, 768, 20480, 12288, 49152, 768, 12288]
#
# Statue-7 has the best fitness value in 107 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [768, 4608, 256, 1024, 0, 48, 12288, 12288, 12288, 6144]
#
# Statue-6 has the best fitness value in 108 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 192, 12288, 2240, 15872, 1, 3072, 8192, 12288, 384]
#
# Statue-4 has the best fitness value in 109 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 44, 3968, 2560, 3008, 76, 64512, 1024, 50176, 6]
#
# Statue-6 has the best fitness value in 110 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2560, 704, 1024, 3008, 736, 4096, 128, 47104, 10, 768]
#
# Statue-7 has the best fitness value in 111 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4864, 16, 1024, 10240, 15104, 0, 34816, 3200, 16, 16]
#
# Statue-6 has the best fitness value in 112 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19, 2560, 34, 40, 960, 6144, 10240, 3264, 50, 88064]
#
# Statue-9 has the best fitness value in 113 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40, 13, 90112, 10, 1344, 816, 1, 43, 3328, 2560]
#
# Statue-2 has the best fitness value in 114 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [352, 3328, 1600, 1664, 40, 1024, 2560, 12288, 13, 7168]
#
# Statue-7 has the best fitness value in 115 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 2560, 18432, 3712, 272, 352, 6400, 640, 2560, 3904]
#
# Statue-2 has the best fitness value in 116 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [25, 4544, 448, 1088, 8960, 640, 2048, 2048, 2560, 4608]
#
# Statue-4 has the best fitness value in 117 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4608, 128, 19712, 768, 1792, 0, 2048, 960, 2048, 8192]
#
# Statue-2 has the best fitness value in 118 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1536, 0, 8192, 208, 3072, 7168, 4608, 1408, 54, 2048]
#
# Statue-2 has the best fitness value in 119 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7, 1536, 1152, 11776, 8192, 18432, 1, 17664, 11520, 228]
#
# Statue-5 has the best fitness value in 120 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18432, 1536, 12032, 96, 64512, 18432, 7424, 32768, 720, 1536]
#
# Statue-4 has the best fitness value in 121 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [12032, 816, 18432, 0, 32768, 4032, 0, 2304, 512, 64512]
#
# Statue-9 has the best fitness value in 122 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1600, 64512, 1360, 12032, 63, 88, 1520, 752, 82944, 0]
#
# Statue-8 has the best fitness value in 123 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [752, 64512, 1520, 0, 1360, 1360, 2176, 73, 67584, 64512]
#
# Statue-8 has the best fitness value in 124 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [64512, 67584, 340, 32, 34816, 4544, 64512, 12, 5, 26624]
#
# Statue-1 has the best fitness value in 125 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67584, 26624, 26624, 512, 78848, 1008, 192, 388, 80, 16128]
#
# Statue-4 has the best fitness value in 126 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [23, 5120, 1344, 59392, 2816, 67584, 77824, 1008, 388, 16128]
#
# Statue-6 has the best fitness value in 127 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [77824, 1024, 22272, 7168, 32768, 4096, 27648, 0, 16, 264]
#
# Statue-0 has the best fitness value in 128 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 32768, 1392, 71680, 77824, 19456, 216, 7168, 27648, 77824]
#
# Statue-4 has the best fitness value in 129 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [19456, 37888, 2048, 71680, 37888, 70656, 71680, 27648, 77824, 32]
#
# Statue-8 has the best fitness value in 130 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32768, 768, 24064, 592, 19456, 37888, 23296, 16640, 1536, 27648]
#
# Statue-5 has the best fitness value in 131 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [27648, 0, 24064, 77824, 16, 304, 16640, 82944, 2048, 9472]
#
# Statue-7 has the best fitness value in 132 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1216, 27648, 77824, 27648, 256, 1504, 5120, 2048, 6912, 27]
#
# Statue-2 has the best fitness value in 133 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47104, 21504, 2048, 27648, 77824, 5120, 5, 864, 27, 432]
#
# Statue-4 has the best fitness value in 134 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [47104, 47104, 864, 5, 14336, 47104, 128, 15, 5120, 1216]
#
# Statue-0 has the best fitness value in 135 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2560, 5, 32768, 47104, 0, 54, 1008, 22528, 1280, 216]
#
# Statue-3 has the best fitness value in 136 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [46, 60416, 512, 5632, 32768, 54, 352, 32768, 32768, 54]
#
# Statue-1 has the best fitness value in 137 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32768, 32768, 3456, 1024, 1024, 5632, 13824, 0, 5632, 944]
#
# Statue-0 has the best fitness value in 138 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1, 32768, 352, 4, 8192, 0, 64512, 32768, 368, 132]
#
# Statue-6 has the best fitness value in 139 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 216, 26624, 63, 128, 82944, 45056, 132, 9216, 25600]
#
# Statue-5 has the best fitness value in 140 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1296, 45056, 216, 45056, 0, 0, 26624, 528, 13824, 11264]
#
# Statue-1 has the best fitness value in 141 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 768, 176, 1296, 104, 20, 432, 20736, 132, 704]
#
# Statue-7 has the best fitness value in 142 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1296, 22, 32, 1296, 1280, 44032, 176, 40, 176, 20736]
#
# Statue-5 has the best fitness value in 143 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176, 32, 7424, 4864, 1296, 20736, 2816, 608, 144, 44032]
#
# Statue-9 has the best fitness value in 144 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1296, 4864, 21, 1024, 7424, 29696, 44032, 44032, 4864, 464]
#
# Statue-6 has the best fitness value in 145 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 128, 4096, 7, 576, 11264, 2048, 44032, 29696, 116]
#
# Statue-7 has the best fitness value in 146 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [8, 7424, 32, 11008, 11264, 22528, 64, 120, 12032, 576]
#
# Statue-5 has the best fitness value in 147 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [576, 22272, 960, 2752, 44, 2816, 5120, 47104, 60, 11008]
#
# Statue-7 has the best fitness value in 148 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [51200, 35840, 16, 2816, 3840, 24576, 15616, 22272, 17664, 44032]
#
# Statue-0 has the best fitness value in 149 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15616, 3072, 35840, 35, 62464, 51200, 17664, 1024, 720, 24576]
#
# Statue-4 has the best fitness value in 150 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 16, 15616, 48, 17664, 864, 4480, 38912, 56320, 0]
#
# Statue-8 has the best fitness value in 151 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 9728, 61, 38912, 864, 71680, 77824, 880, 56320, 1280]
#
# Statue-6 has the best fitness value in 152 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9728, 77824, 56320, 71680, 240, 608, 2048, 3520, 7168, 864]
#
# Statue-1 has the best fitness value in 153 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 220, 77824, 77824, 28, 56320, 38912, 14080, 880, 192]
#
# Statue-2 has the best fitness value in 154 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 19456, 38912, 1792, 880, 384, 61440, 74752, 56320, 1024]
#
# Statue-7 has the best fitness value in 155 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [55, 61440, 74752, 56320, 960, 7168, 880, 11264, 74752, 384]
#
# Statue-2 has the best fitness value in 156 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [55, 74752, 11264, 928, 2816, 960, 1024, 61440, 2048, 61440]
#
# Statue-1 has the best fitness value in 157 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7424, 0, 176, 15616, 18432, 2048, 25600, 1200, 4672, 35840]
#
# Statue-9 has the best fitness value in 158 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15616, 3840, 7424, 76800, 34816, 100, 8, 284, 6400, 4]
#
# Statue-3 has the best fitness value in 159 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [25600, 1136, 512, 2304, 15, 2176, 15616, 6144, 1024, 284]
#
# Statue-0 has the best fitness value in 160 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [284, 1136, 25600, 512, 8192, 1136, 1024, 384, 34, 6144]
#
# Statue-2 has the best fitness value in 161 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 6144, 3584, 136, 59392, 1136, 256, 1280, 96, 6144]
#
# Statue-4 has the best fitness value in 162 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [80, 41984, 8192, 384, 320, 1536, 0, 1280, 34816, 18944]
#
# Statue-1 has the best fitness value in 163 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [18944, 0, 320, 1536, 608, 41, 8192, 384, 75776, 80]
#
# Statue-8 has the best fitness value in 164 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [24, 5696, 1328, 75776, 75776, 1536, 75776, 12544, 672, 544]
#
# Statue-3 has the best fitness value in 165 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20, 2624, 116, 75776, 5696, 12, 5696, 24576, 75776, 74]
#
# Statue-3 has the best fitness value in 166 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [464, 1184, 0, 116, 336, 1536, 9, 11264, 22784, 91136]
#
# Statue-9 has the best fitness value in 167 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [44, 2304, 112, 29, 74, 336, 18176, 0, 1536, 11264]
#
# Statue-6 has the best fitness value in 168 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [7, 1536, 544, 592, 336, 11, 11264, 48, 1360, 0]
#
# Statue-6 has the best fitness value in 169 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65, 1536, 48, 48, 4096, 12, 44, 52, 384, 192]
#
# Statue-4 has the best fitness value in 170 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [44032, 1536, 192, 384, 4160, 24, 20480, 1536, 1488, 65]
#
# Statue-0 has the best fitness value in 171 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [65, 2752, 2, 0, 384, 12288, 80, 704, 20224, 48]
#
# Statue-8 has the best fitness value in 172 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 4544, 3008, 20224, 688, 24576, 13056, 48, 84, 704]
#
# Statue-5 has the best fitness value in 173 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [84, 204, 24576, 10496, 752, 97, 316, 172, 24576, 384]
#
# Statue-2 has the best fitness value in 174 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1536, 0, 16, 24576, 3584, 24576, 52224, 10496, 0, 4864]
#
# Statue-6 has the best fitness value in 175 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [384, 52224, 77824, 52224, 76, 56320, 256, 10496, 84992, 4864]
#
# Statue-8 has the best fitness value in 176 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [56320, 1440, 6144, 7680, 304, 83, 10496, 52224, 4672, 84992]
#
# Statue-9 has the best fitness value in 177 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [53248, 52224, 0, 66, 512, 24, 1168, 84992, 33792, 22528]
#
# Statue-7 has the best fitness value in 178 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40960, 512, 3264, 58368, 12288, 3264, 2560, 53248, 49152, 24]
#
# Statue-3 has the best fitness value in 179 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [53248, 2048, 3072, 53248, 20, 24, 12, 1024, 3264, 192]
#
# Statue-0 has the best fitness value in 180 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1, 3072, 204, 4608, 8192, 14336, 32, 11264, 704, 3072]
#
# Statue-5 has the best fitness value in 181 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [16384, 128, 8192, 35840, 1792, 356, 3072, 512, 5120, 3]
#
# Statue-3 has the best fitness value in 182 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1088, 0, 0, 2048, 3072, 87040, 512, 140, 29696, 44]
#
# Statue-5 has the best fitness value in 183 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [152, 4096, 1536, 29696, 63488, 87040, 32768, 5760, 0, 1344]
#
# Statue-5 has the best fitness value in 184 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [63488, 448, 116, 1440, 4096, 64, 32768, 0, 32768, 72704]
#
# Statue-9 has the best fitness value in 185 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 36864, 44, 72704, 13312, 72704, 72704, 640, 76800, 63488]
#
# Statue-8 has the best fitness value in 186 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72704, 240, 44032, 10240, 18176, 2560, 72704, 76800, 18176, 72704]
#
# Statue-7 has the best fitness value in 187 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40, 116, 14592, 284, 58368, 72704, 72704, 15360, 284, 72704]
#
# Statue-5 has the best fitness value in 188 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [72704, 71, 1136, 30720, 44032, 72704, 63488, 768, 28672, 960]
#
# Statue-0 has the best fitness value in 189 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [120, 7168, 0, 21504, 15360, 43, 21504, 6144, 64512, 1328]
#
# Statue-8 has the best fitness value in 190 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6400, 7, 15360, 22528, 12, 28672, 768, 53248, 24, 16128]
#
# Statue-7 has the best fitness value in 191 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52, 63, 6400, 180, 240, 88, 252, 768, 9216, 0]
#
# Statue-8 has the best fitness value in 192 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [36, 768, 80, 184, 64512, 36864, 9984, 12, 0, 0]
#
# Statue-4 has the best fitness value in 193 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [67, 184, 0, 92160, 65536, 960, 68608, 36864, 4096, 48]
#
# Statue-3 has the best fitness value in 194 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [272, 400, 256, 11776, 17408, 576, 69, 1072, 4096, 64]
#
# Statue-4 has the best fitness value in 195 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 256, 272, 640, 11776, 1536, 11776, 224, 11520, 2048]
#
# Statue-0 has the best fitness value in 196 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [640, 11776, 6144, 11520, 11776, 2560, 24576, 2944, 11520, 3840]
#
# Statue-6 has the best fitness value in 197 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1200, 15360, 11520, 3840, 11520, 192, 3200, 38912, 2816, 5120]
#
# Statue-7 has the best fitness value in 198 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [40, 16, 13568, 11520, 20480, 128, 960, 5120, 2816, 9472]
#
# Statue-4 has the best fitness value in 199 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [32, 1792, 3392, 40, 20480, 272, 3584, 1024, 20480, 0]
#
# Statue-4 has the best fitness value in 200 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [464, 20480, 20480, 0, 5, 9216, 16384, 1280, 3584, 19456]
#
# Statue-1 has the best fitness value in 201 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [9216, 192, 19456, 11776, 43008, 1280, 20480, 8, 20480, 20480]
#
# Statue-4 has the best fitness value in 202 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11776, 10752, 20480, 64, 20480, 1216, 576, 512, 20480, 168]
#
# Statue-2 has the best fitness value in 203 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4096, 2048, 256, 4864, 19, 448, 7, 80, 1024, 15104]
#
# ...
# [288, 384, 24064, 2048, 21504, 53248, 80896, 53248, 77824, 50176]
#
# Statue-6 has the best fitness value in 4933 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [77824, 53248, 53248, 3008, 43008, 53248, 5120, 80896, 12288, 53248]
#
# Statue-7 has the best fitness value in 4934 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4, 53248, 53248, 20224, 52224, 672, 36864, 53248, 528, 74752]
#
# Statue-9 has the best fitness value in 4935 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 5056, 53248, 13312, 13312, 576, 53248, 19200, 3456, 40960]
#
# Statue-2 has the best fitness value in 4936 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2496, 832, 5056, 47104, 11776, 1984, 53248, 13312, 7936, 40]
#
# Statue-6 has the best fitness value in 4937 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [288, 11776, 8704, 13312, 172, 184, 53248, 2624, 80896, 30]
#
# Statue-8 has the best fitness value in 4938 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [48, 6, 4096, 8704, 47104, 16, 7936, 78848, 34816, 10496]
#
# Statue-7 has the best fitness value in 4939 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 10496, 47104, 20, 2560, 8704, 544, 7936, 1, 1232]
#
# Statue-2 has the best fitness value in 4940 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [34816, 112, 8704, 416, 80, 10496, 90112, 1024, 47104, 35840]
#
# Statue-6 has the best fitness value in 4941 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [13056, 544, 1184, 5184, 10496, 34816, 10496, 90112, 2048, 1024]
#
# Statue-7 has the best fitness value in 4942 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10496, 34816, 90112, 2048, 90112, 64, 13056, 1184, 34816, 41]
#
# Statue-2 has the best fitness value in 4943 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10240, 10496, 656, 1184, 2048, 27648, 34, 34816, 352, 30720]
#
# Statue-7 has the best fitness value in 4944 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [176, 10496, 23552, 0, 656, 18944, 88064, 10496, 49152, 30]
#
# Statue-6 has the best fitness value in 4945 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [10496, 23, 116, 656, 39936, 768, 192, 49152, 88064, 160]
#
# Statue-8 has the best fitness value in 4946 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [88064, 86, 0, 10496, 344, 88064, 896, 192, 22016, 16]
#
# Statue-0 has the best fitness value in 4947 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [41984, 64, 2624, 5504, 3584, 22016, 86, 152, 88064, 1216]
#
# Statue-8 has the best fitness value in 4948 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [164, 4096, 152, 2624, 4480, 88064, 80, 344, 5504, 12288]
#
# Statue-5 has the best fitness value in 4949 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [52, 19968, 22016, 4096, 86, 31744, 832, 88064, 5504, 88064]
#
# Statue-7 has the best fitness value in 4950 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [22016, 49152, 344, 0, 6144, 1, 0, 156, 3520, 88064]
#
# Statue-9 has the best fitness value in 4951 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2304, 49152, 56, 0, 0, 640, 78848, 880, 3, 344]
#
# Statue-6 has the best fitness value in 4952 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [31744, 36, 848, 880, 36, 768, 14336, 49152, 896, 81]
#
# Statue-7 has the best fitness value in 4953 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [49152, 7168, 31744, 0, 72, 31744, 31744, 14336, 56320, 212]
#
# Statue-8 has the best fitness value in 4954 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [96256, 1024, 0, 576, 320, 3584, 31744, 3840, 56320, 19456]
#
# Statue-0 has the best fitness value in 4955 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [15360, 2560, 9216, 6016, 31744, 3840, 56320, 80896, 192, 20]
#
# Statue-7 has the best fitness value in 4956 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2240, 16384, 376, 80896, 96256, 576, 79, 3840, 5, 48128]
#
# Statue-4 has the best fitness value in 4957 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1280, 94, 4, 832, 1280, 58368, 57344, 24576, 3456, 188]
#
# Statue-5 has the best fitness value in 4958 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11264, 62464, 1, 6144, 1280, 57344, 336, 4544, 58368, 24576]
#
# Statue-1 has the best fitness value in 4959 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 75, 4096, 24576, 1280, 84992, 3456, 62464, 80, 40960]
#
# Statue-5 has the best fitness value in 4960 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1376, 38912, 40960, 20, 84992, 2560, 62464, 83, 11008, 19456]
#
# Statue-4 has the best fitness value in 4961 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [21248, 40, 17408, 40960, 38912, 13312, 21504, 38, 2560, 50176]
#
# Statue-9 has the best fitness value in 4962 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 4352, 2304, 1, 21248, 20992, 21248, 44, 78, 13312]
#
# Statue-4 has the best fitness value in 4963 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 13312, 20992, 21760, 20992, 11264, 4352, 5248, 1328, 768]
#
# Statue-3 has the best fitness value in 4964 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [20992, 82, 7680, 328, 256, 83968, 4672, 20992, 112, 12544]
#
# Statue-5 has the best fitness value in 4965 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4672, 21760, 17920, 7680, 88, 0, 18688, 39, 83968, 328]
#
# Statue-8 has the best fitness value in 4966 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [14336, 5248, 5888, 4, 88, 1312, 37, 3072, 1360, 26624]
#
# Statue-9 has the best fitness value in 4967 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 592, 464, 32768, 5888, 1472, 656, 5888, 88, 9472]
#
# Statue-0 has the best fitness value in 4968 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 37888, 4096, 87040, 896, 4096, 1120, 0, 11008, 37888]
#
# Statue-3 has the best fitness value in 4969 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [37888, 64512, 37888, 37888, 22016, 1024, 37888, 37888, 9216, 4096]
#
# Statue-1 has the best fitness value in 4970 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [592, 37888, 148, 37888, 9472, 1536, 64512, 37, 37888, 37888]
#
# Statue-6 has the best fitness value in 4971 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [2048, 8192, 37888, 37888, 0, 92, 4032, 864, 37888, 9472]
#
# Statue-2 has the best fitness value in 4972 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [704, 52, 37888, 240, 4, 2368, 4096, 8192, 512, 37888]
#
# Statue-2 has the best fitness value in 4973 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [576, 512, 37888, 256, 11, 1200, 37888, 512, 37888, 1024]
#
# Statue-2 has the best fitness value in 4974 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [256, 37888, 2048, 592, 52, 37888, 512, 48, 176, 148]
#
# Statue-1 has the best fitness value in 4975 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [11008, 37888, 37, 28672, 68, 1, 2048, 1024, 992, 1984]
#
# Statue-1 has the best fitness value in 4976 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [128, 512, 43, 4352, 2048, 48, 68, 9472, 28672, 320]
#
# Statue-8 has the best fitness value in 4977 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [320, 320, 0, 1792, 2048, 69632, 6400, 128, 1536, 28672]
#
# Statue-5 has the best fitness value in 4978 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [74752, 5504, 6400, 50, 17408, 6400, 69632, 1536, 4544, 27]
#
# Statue-0 has the best fitness value in 4979 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [6400, 69632, 69632, 69632, 800, 73, 74752, 116, 17408, 3072]
#
# Statue-6 has the best fitness value in 4980 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [69632, 31, 26624, 25600, 2560, 17408, 6144, 4352, 2048, 52224]
#
# Statue-0 has the best fitness value in 4981 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [0, 20480, 11264, 52224, 25, 18432, 6144, 384, 6144, 69632]
#
# Statue-9 has the best fitness value in 4982 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [73728, 83968, 6144, 5120, 4352, 82944, 3328, 86016, 816, 2816]
#
# Statue-7 has the best fitness value in 4983 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [17408, 20992, 0, 4608, 60416, 6144, 45056, 1088, 20992, 10240]
#
# Statue-4 has the best fitness value in 4984 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [60416, 704, 44, 384, 48, 96, 45056, 67584, 352, 3648]
#
# Statue-7 has the best fitness value in 4985 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [704, 3968, 60416, 60416, 67584, 29696, 176, 48, 3648, 48]
#
# Statue-4 has the best fitness value in 4986 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [248, 236, 1408, 35840, 912, 176, 56320, 63488, 116, 192]
#
# Statue-7 has the best fitness value in 4987 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [336, 3072, 4160, 112, 0, 3072, 248, 176, 4736, 4]
#
# Statue-8 has the best fitness value in 4988 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [3072, 7168, 1184, 3072, 3072, 3072, 83, 2880, 3264, 192]
#
# Statue-1 has the best fitness value in 4989 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [136, 3584, 0, 9472, 1792, 3072, 4672, 1280, 3072, 3072]
#
# Statue-3 has the best fitness value in 4990 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4288, 224, 9472, 3584, 9472, 272, 21504, 7168, 976, 64]
#
# Statue-6 has the best fitness value in 4991 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [272, 3840, 6080, 4288, 15616, 35840, 15616, 8704, 9472, 21504]
#
# Statue-5 has the best fitness value in 4992 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [35840, 9216, 15616, 8704, 4288, 9472, 68608, 1024, 35840, 14336]
#
# Statue-6 has the best fitness value in 4993 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [4288, 35840, 32768, 7424, 2240, 68608, 21760, 35840, 35840, 39]
#
# Statue-5 has the best fitness value in 4994 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [33792, 2560, 35840, 88, 35840, 32768, 3, 54272, 7, 3072]
#
# Statue-7 has the best fitness value in 4995 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [54272, 32768, 35840, 160, 4544, 228, 88, 2240, 0, 32]
#
# Statue-0 has the best fitness value in 4996 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [340, 32768, 35840, 54272, 3, 59392, 140, 9216, 5120, 35840]
#
# Statue-5 has the best fitness value in 4997 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [59392, 14848, 0, 128, 35840, 13568, 35840, 77, 9216, 560]
#
# Statue-0 has the best fitness value in 4998 generation.
# ------------------------------------------------------------------------------------------------------------------------
# [1024, 12, 59392, 49152, 58368, 35840, 140, 560, 23552, 34816]
#
# Statue-2 has the best fitness value in 4999 generation.
# ------------------------------------------------------------------------------------------------------------------------
# Wall time: 14 s

# %%
print(len(ALL_FITNESS))
# Out:
# 5001

# %%
len(PARAMS)
# Out:
# 5001

# %%
C=PARAMS[5000][2]

# %%
COLOUR=str((C[0]/255,C[1]/255,C[2]/255,C[3]))
VERTS=C[5][0]
FACES=C[5][1]
RO=C[4]

# %%
COLOUR
# Out:
# '(0.6392156862745098, 0.2, 0.9098039215686274, 251)'

# %%
print(FACES)
# Out:
# [(5, 2, 4, 6, 9, 10, 12), (0, 5, 7), (3, 1, 5, 6, 7, 8, 9, 11), (5, 4, 6, 10, 12), (0, 1, 3, 4, 5), (0, 3, 12), (1, 0, 3, 4, 5, 6, 7, 9, 11, 12), (1, 0, 2, 3, 4, 5, 9, 10), (4, 0, 1, 6, 8, 10, 12), (5, 1, 6, 8, 9, 10, 12), (7, 0, 1, 4, 5, 9, 10, 12), (1, 0, 4, 5, 6, 7, 8, 11, 12), (2, 0, 4, 6, 8, 9, 10, 12), (9, 0, 1, 2, 3, 4, 6, 10), (1, 2, 3, 4, 5, 6, 7, 8, 10, 11), (4, 3, 5, 7, 11, 12), (10, 2, 4, 7, 8), (1, 2, 3, 4, 6, 8, 9, 10, 12), (10, 1, 3, 4, 6, 8, 11, 12), (1, 0, 2, 9), (4, 0, 5, 7, 11, 12), (1, 0, 2, 5, 6, 7, 8, 9), (4, 1, 5, 6, 7, 12), (6, 3, 4, 5, 9, 11, 12), (3, 6, 7, 8, 9), (0, 3, 6, 7, 8, 9, 10, 12), (9, 6, 7, 10, 11, 12), (2, 5, 7, 8, 9, 12), (2, 8, 9, 11), (4, 0, 2, 5, 9, 11), (4, 2, 3, 6, 7, 9, 11, 12), (6, 2, 9, 11), (2, 0, 1, 4, 5, 7, 8, 10, 12), (8, 1, 2, 3, 4, 5, 6, 9, 12), (6, 2, 3, 8, 12), (7, 3, 5, 6, 9, 12), (0, 7, 8, 12), (3, 4, 6, 7, 9, 10, 11)]

# %%
print(VERTS)
# Out:
# [[4.4027881887037665, 5.2997441434248795, 3.17591190666594], [4.145916560976637, 1.1331045929556778, 4.86137380809178], [2.9306727311691008, 1.615224536429696, 1.167802631136164], [1.1592936521250272, 7.094152187400553, 3.401188099923602], [4.828828887951404, 7.7256911249173505, 3.334980651705204], [5.90348359014349, 0.3001753533367989, 6.957239618250559], [4.916795391122859, 0.2998064110037595, 2.004637362173926], [4.55448527548645, 2.1334398697544046, 3.8500663355541302], [0.4849523434664025, 2.8567923195255203, 3.6128146182973158], [3.787102305116894, 6.1516876068748, 4.855348810615467], [3.211129485334326, 6.48451238812632, 6.39887318737781], [5.6210840407106435, 4.188431535864094, 6.636569829737368], [5.669541124294211, 4.844712560294202, 0.8691703373793607]]

# %%
RO
# Out:
# 5

# %%
with open(f'E:\\Research\\Statue Generator\\OUTPUT_8.txt', 'w') as f:
        f.writelines(str(PARAMS))
